# %%
import sys
sys.path.extend(['/Users/prajayshah/OneDrive/PycharmProjects/AllOpticalSeizure/_sz_processing'])
sys.path.extend(['/Users/prajayshah/OneDrive/PycharmProjects/AllOpticalSeizure/'])
# print(sys.path)


import _utils_.io as _io
# %matplotlib notebook
# %matplotlib inline
from mpl_point_clicker import clicker
from _sz_processing.temporal_delay_to_sz_invasion import *
# Out:
# importing resultsobj from: /Users/prajayshah/OneDrive/UTPhD/2022/OXFORD/expobj/alloptical_results_superobject.pkl ...
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# ...
# No module named 'cellpose'
# cannot use anatomical mode, but otherwise suite2p will run normally
#
# importing resultsobj from: /Users/prajayshah/OneDrive/UTPhD/2022/OXFORD/expobj/alloptical_results_superobject.pkl ...
# |-DONE IMPORT of <class 'alloptical_utils_pj.AllOpticalResults'> resultsobj
#
#
# |-DONE IMPORT of <class 'alloptical_utils_pj.AllOpticalResults'> resultsobj
#
#
# |- Loaded RL109 t-016 (/Users/prajayshah/OneDrive/UTPhD/2022/OXFORD/expobj/2020-12-19_t-016.pkl) .. DONE
#
#  .......... INITIATING FOR LOOP ACROSS EXPS ..........
#
#
#  .......... [2] INITIATING FOR LOOP ACROSS EXPS ..........
#
#
#  .......... INITIATING FOR LOOP ACROSS EXPS ..........
#
#
#  .......... [2] INITIATING FOR LOOP ACROSS EXPS ..........

# %%
expobj: Post4ap = _io.import_expobj(pkl_path='/Users/prajayshah/OneDrive/UTPhD/2022/OXFORD/expobj/2020-12-19_t-021.pkl')

    
print(f"Total targets: {expobj.n_targets_total}, Total seizures: {expobj.numSeizures}")

_columns = [f"time_del_sz{num}" for num in range(expobj.numSeizures)]
slmtargets_time_delay_sz = pd.DataFrame(index=range(expobj.n_targets_total), columns=_columns)
# Out:
# |- Loaded RL109 t-021 (/Users/prajayshah/OneDrive/UTPhD/2022/OXFORD/expobj/2020-12-19_t-021.pkl) .. DONE
# Total targets: 50, Total seizures: 2

# %%
rg0 = 0
rg1 = 10
ax_measure = plot_slmtargets_flu_lfp(expobj=expobj, rg=(rg0,rg1), title='', figsize=(10,13))

labels = [f"target{i}" for i in range(rg0, rg1)]
klicker = clicker(ax_measure, classes=labels, markers=['o']*10)
# Out:
# len=10
# len of array: 10
# <img src="data:image/png;base64,..." width="1000">

# %%
print(klicker.get_positions())

slm_targets_sz_framestamps = {}
for target in [*klicker.get_positions()]:
    slm_targets_sz_framestamps[target] = klicker.get_positions()[target]
# Out:
# {'target40': array([[ 5360.20112903, 10426.18103359],
#        [12978.4333871 , 10402.45842873]]), 'target41': array([[ 5334.3766129 ,  9311.21860544],
#        [13004.25790323,  9323.07990787]]), 'target42': array([[ 5515.14822581,  8291.14659672],
#        [13107.55596774,  8397.89831856]]), 'target43': array([[ 5334.3766129 ,  7437.13282197],
#        [13055.90693548,  7520.16193896]]), 'target44': array([[ 5566.79725806,  6369.61560354],
#        [13081.73145161,  6381.47690596]]), 'target45': array([[ 5386.02564516,  5385.12750209],
#        [13055.90693548,  5420.71140937]]), 'target46': array([[ 5437.67467742,  4329.47158608],
#        [13107.55596774,  4365.05549336]]), 'target47': array([[ 5489.32370968,  3344.98348464],
#        [13159.205     ,  3356.84478707]]), 'target48': array([[ 5618.44629032,  2289.32756863],
#        [13185.02951613,  2301.18887106]]), 'target49': array([[ 5437.67467742,  1281.11686233],
#        [13081.73145161,  1328.56207204]])}

# %%
slmtargets_time_delay_sz = evaluate_clicks_sz(expobj, klicker, slmtargets_time_delay_sz)

# %%
slmtargets_time_delay_sz
# Out:
#    time_del_sz0 time_del_sz1 time_del_sz2 time_del_sz3
# 0           NaN       79.647       36.175          NaN
# 1           NaN      102.028       45.644          NaN
# 2           NaN       114.08       50.809          NaN
# 3           NaN       85.673       37.896          NaN
# 4           NaN       96.863       53.391          NaN
# 5           NaN      120.105       55.973          NaN
# 6           NaN      115.801       54.252          NaN
# 7           NaN      123.549       55.973          NaN
# 8           NaN      123.549       55.113          NaN
# 9           NaN      123.549       55.113          NaN
# 10          NaN       62.431       24.984          NaN
# 11          NaN       86.533       37.896          NaN
# 12          NaN        61.57       23.262          NaN
# 13          NaN       99.446       43.922          NaN
# 14          NaN      100.307       45.644          NaN
# 15          NaN       98.585       47.365          NaN
# ...

# %%
export_to_csv(slmtargets_time_delay_sz, exp_name=f"slmtargets_time_delay_sz__{expobj.prep}_{expobj.trial}")
# Out:
# saved dataframe to /Users/prajayshah/OneDrive/UTPhD/2022/OXFORD/export/slmtargets_time_delay_sz__RL109_t-020.csv
