# %% [markdown]
# # Processing - PS07 - 2021-01-19

# %%
import sys; sys.path.append('/home/pshah/Documents/code/PackerLab_pycharm/')
import os
import pickle
import alloptical_utils_pj as aoutils
import alloptical_plotting_utils as aoplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import utils.funcs_pj as pj
import tifffile as tf
# Out:
# importing resultsobj from: /home/pshah/mnt/qnap/Analysis/alloptical_results_superobject.pkl ...
# |-DONE IMPORT of <class 'alloptical_utils_pj.AllOpticalResults'> resultsobj

# %%
to_suite2p = ['t-002', 't-006', 't-007', 't-008', 't-009', 't-011', 't-016', 't-017'] # specify all trials that were used in the suite2p runtotal_frames_stitched = 0
baseline_trials = ['t-002', 't-006'] # specify which trials to use as spont baseline
# note ^^^ this only works currently when the spont baseline trials all come first, and also back to back

# %% [markdown]
# ### pre4ap

# %%
trials = ['t-007', 't-008', 't-009']

trials = ['']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    prep = 'PS07'
    
    expobj, experiment = aoutils.import_expobj(trial=trial, prep=prep)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/%s/suite2p/alloptical-2p-0_8x-alltrials/plane0' % (date, prep)
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-42b6ca84371d> in <module>
#       7     prep = 'PS07'
#       8
# ----> 9     expobj, experiment = aoutils.import_expobj(trial=trial, prep=prep)
#      10     expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/%s/suite2p/alloptical-2p-0_8x-alltrials/plane0' % (date, prep)
#      11     aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
#
# ~/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py in import_expobj(aoresults_map_id, trial, prep, date, pkl_path, exp_prep, verbose, do_processing)
#      79         if date is None:
#      80             try:
# ---> 81                 date = allopticalResults.metainfo.loc[
#      82                     allopticalResults.metainfo['prep_trial'] == f"{prep} {trial}", 'date'].values[0]
#      83             except ValueError:
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %% [markdown]
# ### post4ap

# %%
trials = ['t-011', 't-016', 't-017']

trials = ['t-017']
for trial in trials:
    ###### IMPORT pkl file containing expobj
    prep = 'PS07'
    date = '2021-01-19'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/%s/%s_%s/%s_%s.pkl" % (date, prep, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/%s/suite2p/alloptical-2p-0_8x-alltrials/plane0' % (date, prep)
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# |- loading /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-017/2021-01-19_t-017.pkl .. DONE
#
# Running alloptical_processing_photostim for PS07, t-017 ------------------------------
#
# -----Loading up target coordinates...
# Number of targets: 54
# spiral size: 15.0um
# pix sz x: 1.36536549540337um
# radius (in pixels): 8.19px
# radius of target exclusion zone (in pixels): 10.92px
# Number of targets (in SLM group 1):  18
# Number of targets (in SLM group 2):  18
# Number of targets (in SLM group 3):  18
# FIN. -----Loading up target coordinates-----
#
#  ..... plotting function \ ...
# 	 \- PLOTTING mean raw flu trace ...
# ** res during print_start_end_plot None
#
#  ..... plotting function \ END
#
#  ..... plotting function \ ...
# 	 \- PLOTTING LFP stims trace ...
#
#  ..... plotting function \ ...
# 	 \- PLOTTING LFP Signal trace ...
# ** res during print_start_end_plot (<Figure size 720x216 with 1 Axes>, <AxesSubplot:title={'center':'LFP trace - post 4ap 2p all optical PS07 t-017'}, xlabel='paq clock', ylabel='Voltage'>)
#
#  ..... plotting function \ END
# ** res during print_start_end_plot AxesSubplot(0.0746528,0.226852;0.900347x0.615741)
#
#  ..... plotting function \ END
# re-collecting subset frames of current trial
# baseline frames:  [0, 22535]
# current trial frames:  [99513, 114987]
# \- Saving expobj saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-017/2021-01-19_t-017.pkl --
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file049_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file050_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file051_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file052_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file053_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file054_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file055_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file056_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file057_chan0.tif
# \- Saving expobj saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-017/2021-01-19_t-017.pkl --
#
# ---------- Collecting trace raw stim trace snippets of SLM targets for post 4ap 2p all optical PS07 t-017 [1.] ----------
# |- returning targets stims array of shape: 54 targets, 100 stims, 72 frames
#
# ---------- Collecting trace dFF stim trace snippets of SLM targets for post 4ap 2p all optical PS07 t-017 [1.] ----------
# |- returning targets stims array of shape: 54 targets, 100 stims, 72 frames
#
# ---------- Collecting trace raw stim trace snippets of SLM targets for post 4ap 2p all optical PS07 t-017 [1.] ----------
# |- returning targets stims array of shape: 54 targets, 100 stims, 72 frames
#
# ---------- Collecting trace dFF stim trace snippets of SLM targets for post 4ap 2p all optical PS07 t-017 [1.] ----------
# |- returning targets stims array of shape: 54 targets, 100 stims, 72 frames
#
# ---------- Collecting trace raw stim trace snippets of SLM targets for post 4ap 2p all optical PS07 t-017 [1.] ----------
# |-filter_sz active
# |- WARNING: classifying of sz boundaries not completed for this expobj, not collecting any stim trace snippets PS07 t-017
# |- returning targets stims array of shape: 54 targets, 100 stims, 72 frames
#
# ---------- Collecting trace dFF stim trace snippets of SLM targets for post 4ap 2p all optical PS07 t-017 [1.] ----------
# |-filter_sz active
# |- WARNING: classifying of sz boundaries not completed for this expobj, not collecting any stim trace snippets PS07 t-017
# |- returning targets stims array of shape: 54 targets, 100 stims, 72 frames
# |- calculating stim responses (all trials) - 100 stims [2.2.1]
#
# ---------- Calculating dF/stdF stim evoked responses (of SLM targets) [.1] ----------
#
# ---------- Calculating dF/prestimF stim evoked responses (of SLM targets) [.1] ----------
#
# ---------- Calculating trace dFF stim evoked responses (of SLM targets) [.1] ----------
# |- calculating stim responses (outsz) - 80 stims [2.2.1]
#
# ---------- Calculating dF/stdF stim evoked responses (of SLM targets) [.1] ----------
#
# ---------- Calculating dF/prestimF stim evoked responses (of SLM targets) [.1] ----------
#
# ---------- Calculating trace dFF stim evoked responses (of SLM targets) [.1] ----------
# |- calculating stim success rates (outsz) - 80 stims [2.2.0]
#
# ---------- Calculating dF/stdF stim success rates, and separating stims into successes and failures (of SLM targets) [1.] ----------
#
# ---------- Calculating dF/prestimF stim success rates, and separating stims into successes and failures (of SLM targets) [1.] ----------
#
# ---------- Calculating trace dFF stim success rates, and separating stims into successes and failures (of SLM targets) [1.] ----------
# ******* No slmtargets_szboundary_stim (sz boundary classification not done) for: PS07 t-017  [*2.3]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-acbd86bb941d> in <module>
#      10     expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
#      11     expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/%s/suite2p/alloptical-2p-0_8x-alltrials/plane0' % (date, prep)
# ---> 12     aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
#
# ~/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py in run_alloptical_processing_photostim(expobj, to_suite2p, baseline_trials, plots, force_redo)
#    5464                     expobj.metainfo['animal prep.'], expobj.metainfo['trial']), ' [*2.3] ')
#    5465
# -> 5466         expobj.avgResponseSzStims_SLMtargets()
#    5467
#    5468     expobj.save()
#
# ~/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py in avgResponseSzStims_SLMtargets(self, save)
#    4075             df.loc[stim_idx, 'avg targets response'] = self.responses_SLMtargets_tracedFF_outsz.loc[:, stim_idx].mean()
#    4076
# -> 4077         for stim_idx in self.responses_SLMtargets_tracedFF_insz.columns:
#    4078             df.loc[stim_idx, 'stim_group'] = 'ictal'
#    4079             df.loc[stim_idx, 'avg targets response'] = self.responses_SLMtargets_tracedFF_insz.loc[:, stim_idx].mean()
#
# AttributeError: 'Post4ap' object has no attribute 'responses_SLMtargets_tracedFF_insz'
