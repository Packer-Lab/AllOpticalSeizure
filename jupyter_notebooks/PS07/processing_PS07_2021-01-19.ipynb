# %% [markdown]
# # Processing - PS07 - 2021-01-19

# %%
import sys; sys.path.append('/home/pshah/Documents/code/PackerLab_pycharm/')
import os
import pickle
import alloptical_utils_pj as aoutils
import alloptical_plotting_utils as aoplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import utils.funcs_pj as pj
import tifffile as tf
# Out:
# importing resultsobj from: /home/pshah/mnt/qnap/Analysis/alloptical_results_superobject.pkl
#
#
# DONE IMPORT of <class 'alloptical_utils_pj.AllOpticalResults'> resultsobj

# %%
to_suite2p = ['t-002', 't-006', 't-007', 't-008', 't-009', 't-011', 't-016', 't-017'] # specify all trials that were used in the suite2p runtotal_frames_stitched = 0
baseline_trials = ['t-002', 't-006'] # specify which trials to use as spont baseline
# note ^^^ this only works currently when the spont baseline trials all come first, and also back to back

# %% [markdown]
# ### pre4ap

# %%
trials = ['t-007', 't-008', 't-009']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    prep = 'PS07'
    date = '2021-01-19'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/%s/%s_%s/%s_%s.pkl" % (date, prep, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/%s/suite2p/alloptical-2p-0_8x-alltrials/plane0' % (date, prep)
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-01-19, t-007" from: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-007/2021-01-19_t-007.pkl
#
#
# DONE IMPORT of PS07: t-007, pre 4ap 2p all optical, 18 cells x 3 groups; 7mW per cell; 250ms stim multi_interleaved (prot. #3); good number of photostimmed cells; the spirals seemed to have ended early before the end of the 250ms stim. not sure what the bug is exactly, because the naparm setup looks correct
# re-collecting subset frames of current trial
# baseline frames:  [0, 22535]
# current trial frames:  [22535, 38009]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-007/2021-01-19_t-007.pkl
#
# Loading 1648 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-007/2021-01-19_t-007.pkl
#
#
# searching for targeted cells...
# (456, 266)
# (626, 686)
# (448, 252)
# (596, 816)
# (338, 212)
# (322, 530)
# (578, 536)
# (452, 240)
# (570, 572)
# (494, 278)
# (478, 832)
# (372, 396)
# (508, 582)
# (372, 374)
# (426, 778)
# (700, 812)
# (594, 766)
# (334, 418)
# (578, 550)
# (570, 552)
# (632, 916)
# (680, 826)
# (540, 664)
# (680, 826)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-007/2021-01-19_t-007.pkl
#
# Number of targeted cells found suite2p:  23
#
# Target cells found in suite2p:  [19, 82, 92, 174, 180, 191, 240, 254, 255, 313, 486, 565, 658, 794, 1063, 1379, 1510, 1593, 2051, 2344, 2586, 2788, 2850]  -- 23 cells (out of 54 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-007/2021-01-19_t-007.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-007/2021-01-19_t-007_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file011_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file012_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file013_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file014_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file015_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file016_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file017_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file018_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file019_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-007/2021-01-19_t-007.pkl
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-007/2021-01-19_t-007.pkl
#
# collecting stim traces for cell # 1 out of 54
# collecting stim traces for cell # 2 out of 54
# collecting stim traces for cell # 3 out of 54
# collecting stim traces for cell # 4 out of 54
# collecting stim traces for cell # 5 out of 54
# collecting stim traces for cell # 6 out of 54
# collecting stim traces for cell # 7 out of 54
# collecting stim traces for cell # 8 out of 54
# collecting stim traces for cell # 9 out of 54
# collecting stim traces for cell # 10 out of 54
# collecting stim traces for cell # 11 out of 54
# collecting stim traces for cell # 12 out of 54
# collecting stim traces for cell # 13 out of 54
# collecting stim traces for cell # 14 out of 54
# collecting stim traces for cell # 15 out of 54
# collecting stim traces for cell # 16 out of 54
# collecting stim traces for cell # 17 out of 54
# collecting stim traces for cell # 18 out of 54
# collecting stim traces for cell # 19 out of 54
# collecting stim traces for cell # 20 out of 54
# collecting stim traces for cell # 21 out of 54
# collecting stim traces for cell # 22 out of 54
# collecting stim traces for cell # 23 out of 54
# collecting stim traces for cell # 24 out of 54
# collecting stim traces for cell # 25 out of 54
# collecting stim traces for cell # 26 out of 54
# collecting stim traces for cell # 27 out of 54
# collecting stim traces for cell # 28 out of 54
# collecting stim traces for cell # 29 out of 54
# collecting stim traces for cell # 30 out of 54
# collecting stim traces for cell # 31 out of 54
# collecting stim traces for cell # 32 out of 54
# collecting stim traces for cell # 33 out of 54
# collecting stim traces for cell # 34 out of 54
# collecting stim traces for cell # 35 out of 54
# collecting stim traces for cell # 36 out of 54
# collecting stim traces for cell # 37 out of 54
# collecting stim traces for cell # 38 out of 54
# collecting stim traces for cell # 39 out of 54
# collecting stim traces for cell # 40 out of 54
# collecting stim traces for cell # 41 out of 54
# collecting stim traces for cell # 42 out of 54
# collecting stim traces for cell # 43 out of 54
# collecting stim traces for cell # 44 out of 54
# collecting stim traces for cell # 45 out of 54
# collecting stim traces for cell # 46 out of 54
# collecting stim traces for cell # 47 out of 54
# collecting stim traces for cell # 48 out of 54
# collecting stim traces for cell # 49 out of 54
# collecting stim traces for cell # 50 out of 54
# collecting stim traces for cell # 51 out of 54
# collecting stim traces for cell # 52 out of 54
# collecting stim traces for cell # 53 out of 54
# collecting stim traces for cell # 54 out of 54
# (54, 64)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 63.0 percent hits over 100 stims
# |- Target # 1: 83.0 percent hits over 100 stims
# |- Target # 2: 53.0 percent hits over 100 stims
# |- Target # 3: 95.0 percent hits over 100 stims
# |- Target # 4: 100.0 percent hits over 100 stims
# |- Target # 5: 100.0 percent hits over 100 stims
# |- Target # 6: 81.0 percent hits over 100 stims
# |- Target # 7: 75.0 percent hits over 100 stims
# |- Target # 8: 91.0 percent hits over 100 stims
# |- Target # 9: 89.0 percent hits over 100 stims
# |- Target # 10: 100.0 percent hits over 100 stims
# |- Target # 11: 82.0 percent hits over 100 stims
# |- Target # 12: 70.0 percent hits over 100 stims
# |- Target # 13: 100.0 percent hits over 100 stims
# |- Target # 14: 79.0 percent hits over 100 stims
# |- Target # 15: 70.0 percent hits over 100 stims
# |- Target # 16: 62.0 percent hits over 100 stims
# |- Target # 17: 42.0 percent hits over 100 stims
# |- Target # 18: 72.0 percent hits over 100 stims
# |- Target # 19: 85.0 percent hits over 100 stims
# |- Target # 20: 94.0 percent hits over 100 stims
# |- Target # 21: 79.0 percent hits over 100 stims
# |- Target # 22: 85.0 percent hits over 100 stims
# |- Target # 23: 99.0 percent hits over 100 stims
# |- Target # 24: 98.0 percent hits over 100 stims
# |- Target # 25: 90.0 percent hits over 100 stims
# |- Target # 26: 100.0 percent hits over 100 stims
# |- Target # 27: 100.0 percent hits over 100 stims
# |- Target # 28: 73.0 percent hits over 100 stims
# |- Target # 29: 92.0 percent hits over 100 stims
# |- Target # 30: 99.0 percent hits over 100 stims
# |- Target # 31: 79.0 percent hits over 100 stims
# |- Target # 32: 76.0 percent hits over 100 stims
# |- Target # 33: 85.0 percent hits over 100 stims
# |- Target # 34: 93.0 percent hits over 100 stims
# |- Target # 35: 94.0 percent hits over 100 stims
# |- Target # 36: 73.0 percent hits over 100 stims
# |- Target # 37: 81.0 percent hits over 100 stims
# |- Target # 38: 44.0 percent hits over 100 stims
# |- Target # 39: 60.0 percent hits over 100 stims
# |- Target # 40: 43.0 percent hits over 100 stims
# |- Target # 41: 89.0 percent hits over 100 stims
# |- Target # 42: 90.0 percent hits over 100 stims
# |- Target # 43: 100.0 percent hits over 100 stims
# |- Target # 44: 98.0 percent hits over 100 stims
# |- Target # 45: 100.0 percent hits over 100 stims
# |- Target # 46: 93.0 percent hits over 100 stims
# |- Target # 47: 92.0 percent hits over 100 stims
# |- Target # 48: 99.0 percent hits over 100 stims
# |- Target # 49: 98.0 percent hits over 100 stims
# |- Target # 50: 95.0 percent hits over 100 stims
# |- Target # 51: 71.0 percent hits over 100 stims
# |- Target # 52: 90.0 percent hits over 100 stims
# |- Target # 53: 98.0 percent hits over 100 stims
#
# avg photostim. success rate is: 84.11 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-007/2021-01-19_t-007.pkl
#
#
# importing expobj for "2021-01-19, t-008" from: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-008/2021-01-19_t-008.pkl
#
#
# DONE IMPORT of PS07: t-008, pre 4ap 2p all optical, 18 cells x 3 groups; 7mW per cell; 250ms stim multi group (prot. #2); the markpoints2packio signal seems to be somehow missing the second out of three pulses.?? but the responses seem to be okay for two groups (not sure if the third group is less effective because of a missing markpoints pulse?)
# updated expobj.pkl_path  /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-008/2021-01-19_t-008.pkl
# updated expobj.analysis_save_path  /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-008/
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-008/2021-01-19_t-008.pkl
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-008/2021-01-19_t-008.pkl
#
# re-collecting subset frames of current trial
# baseline frames:  [0, 22535]
# current trial frames:  [38009, 53483]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-008/2021-01-19_t-008.pkl
#
# Loading 1648 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-008/2021-01-19_t-008.pkl
#
#
# searching for targeted cells...
# (456, 266)
# (626, 686)
# (448, 252)
# (596, 816)
# (338, 212)
# (322, 530)
# (578, 536)
# (452, 240)
# (570, 572)
# (494, 278)
# (478, 832)
# (372, 396)
# (508, 582)
# (372, 374)
# (426, 778)
# (700, 812)
# (594, 766)
# (334, 418)
# (578, 550)
# (570, 552)
# (632, 916)
# (680, 826)
# (540, 664)
# (680, 826)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-008/2021-01-19_t-008.pkl
#
# Number of targeted cells found suite2p:  23
#
# Target cells found in suite2p:  [19, 82, 92, 174, 180, 191, 240, 254, 255, 313, 486, 565, 658, 794, 1063, 1379, 1510, 1593, 2051, 2344, 2586, 2788, 2850]  -- 23 cells (out of 54 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-008/2021-01-19_t-008.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-008/2021-01-19_t-008_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file019_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file020_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file021_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file022_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file023_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file024_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file025_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file026_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-008/2021-01-19_t-008.pkl
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-008/2021-01-19_t-008.pkl
#
# collecting stim traces for cell # 1 out of 54
# collecting stim traces for cell # 2 out of 54
# collecting stim traces for cell # 3 out of 54
# collecting stim traces for cell # 4 out of 54
# collecting stim traces for cell # 5 out of 54
# collecting stim traces for cell # 6 out of 54
# collecting stim traces for cell # 7 out of 54
# collecting stim traces for cell # 8 out of 54
# collecting stim traces for cell # 9 out of 54
# collecting stim traces for cell # 10 out of 54
# collecting stim traces for cell # 11 out of 54
# collecting stim traces for cell # 12 out of 54
# collecting stim traces for cell # 13 out of 54
# collecting stim traces for cell # 14 out of 54
# collecting stim traces for cell # 15 out of 54
# collecting stim traces for cell # 16 out of 54
# collecting stim traces for cell # 17 out of 54
# collecting stim traces for cell # 18 out of 54
# collecting stim traces for cell # 19 out of 54
# collecting stim traces for cell # 20 out of 54
# collecting stim traces for cell # 21 out of 54
# collecting stim traces for cell # 22 out of 54
# collecting stim traces for cell # 23 out of 54
# collecting stim traces for cell # 24 out of 54
# collecting stim traces for cell # 25 out of 54
# collecting stim traces for cell # 26 out of 54
# collecting stim traces for cell # 27 out of 54
# collecting stim traces for cell # 28 out of 54
# collecting stim traces for cell # 29 out of 54
# collecting stim traces for cell # 30 out of 54
# collecting stim traces for cell # 31 out of 54
# collecting stim traces for cell # 32 out of 54
# collecting stim traces for cell # 33 out of 54
# collecting stim traces for cell # 34 out of 54
# collecting stim traces for cell # 35 out of 54
# collecting stim traces for cell # 36 out of 54
# collecting stim traces for cell # 37 out of 54
# collecting stim traces for cell # 38 out of 54
# collecting stim traces for cell # 39 out of 54
# collecting stim traces for cell # 40 out of 54
# collecting stim traces for cell # 41 out of 54
# collecting stim traces for cell # 42 out of 54
# collecting stim traces for cell # 43 out of 54
# collecting stim traces for cell # 44 out of 54
# collecting stim traces for cell # 45 out of 54
# collecting stim traces for cell # 46 out of 54
# collecting stim traces for cell # 47 out of 54
# collecting stim traces for cell # 48 out of 54
# collecting stim traces for cell # 49 out of 54
# collecting stim traces for cell # 50 out of 54
# collecting stim traces for cell # 51 out of 54
# collecting stim traces for cell # 52 out of 54
# collecting stim traces for cell # 53 out of 54
# collecting stim traces for cell # 54 out of 54
# (54, 64)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 29.5 percent hits over 200 stims
# |- Target # 1: 29.0 percent hits over 200 stims
# |- Target # 2: 22.5 percent hits over 200 stims
# |- Target # 3: 34.5 percent hits over 200 stims
# |- Target # 4: 39.0 percent hits over 200 stims
# |- Target # 5: 33.0 percent hits over 200 stims
# |- Target # 6: 19.0 percent hits over 200 stims
# |- Target # 7: 20.5 percent hits over 200 stims
# |- Target # 8: 29.0 percent hits over 200 stims
# |- Target # 9: 28.0 percent hits over 200 stims
# |- Target # 10: 23.5 percent hits over 200 stims
# |- Target # 11: 16.0 percent hits over 200 stims
# |- Target # 12: 17.0 percent hits over 200 stims
# |- Target # 13: 23.0 percent hits over 200 stims
# |- Target # 14: 16.5 percent hits over 200 stims
# |- Target # 15: 16.5 percent hits over 200 stims
# |- Target # 16: 19.5 percent hits over 200 stims
# |- Target # 17: 18.5 percent hits over 200 stims
# |- Target # 18: 44.5 percent hits over 200 stims
# |- Target # 19: 39.5 percent hits over 200 stims
# |- Target # 20: 46.5 percent hits over 200 stims
# |- Target # 21: 44.0 percent hits over 200 stims
# |- Target # 22: 43.0 percent hits over 200 stims
# |- Target # 23: 37.0 percent hits over 200 stims
# |- Target # 24: 43.0 percent hits over 200 stims
# |- Target # 25: 42.5 percent hits over 200 stims
# |- Target # 26: 53.0 percent hits over 200 stims
# |- Target # 27: 42.0 percent hits over 200 stims
# |- Target # 28: 53.5 percent hits over 200 stims
# |- Target # 29: 54.0 percent hits over 200 stims
# |- Target # 30: 52.5 percent hits over 200 stims
# |- Target # 31: 45.0 percent hits over 200 stims
# |- Target # 32: 39.5 percent hits over 200 stims
# |- Target # 33: 44.5 percent hits over 200 stims
# |- Target # 34: 47.0 percent hits over 200 stims
# |- Target # 35: 50.0 percent hits over 200 stims
# |- Target # 36: 28.5 percent hits over 200 stims
# |- Target # 37: 46.0 percent hits over 200 stims
# |- Target # 38: 20.5 percent hits over 200 stims
# |- Target # 39: 24.5 percent hits over 200 stims
# |- Target # 40: 24.5 percent hits over 200 stims
# |- Target # 41: 37.5 percent hits over 200 stims
# |- Target # 42: 23.5 percent hits over 200 stims
# |- Target # 43: 35.0 percent hits over 200 stims
# |- Target # 44: 28.5 percent hits over 200 stims
# |- Target # 45: 32.0 percent hits over 200 stims
# |- Target # 46: 39.5 percent hits over 200 stims
# |- Target # 47: 31.0 percent hits over 200 stims
# |- Target # 48: 52.5 percent hits over 200 stims
# |- Target # 49: 24.0 percent hits over 200 stims
# |- Target # 50: 50.0 percent hits over 200 stims
# |- Target # 51: 28.5 percent hits over 200 stims
# |- Target # 52: 48.0 percent hits over 200 stims
# |- Target # 53: 47.5 percent hits over 200 stims
#
# avg photostim. success rate is: 34.76 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-008/2021-01-19_t-008.pkl
#
#
# importing expobj for "2021-01-19, t-009" from: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-009/2021-01-19_t-009.pkl
#
#
# DONE IMPORT of PS07: t-009, pre 4ap 2p all optical, 18 cells x 3 groups; 5mW per cell; 100ms stim multi group (prot. #3b); seem to get less cells responding as compared to t007. spirals are similarly affected here as in t007.
# updated expobj.pkl_path  /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-009/2021-01-19_t-009.pkl
# updated expobj.analysis_save_path  /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-009/
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-009/2021-01-19_t-009.pkl
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-009/2021-01-19_t-009.pkl
#
# re-collecting subset frames of current trial
# baseline frames:  [0, 22535]
# current trial frames:  [53483, 68957]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-009/2021-01-19_t-009.pkl
#
# Loading 1648 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-009/2021-01-19_t-009.pkl
#
#
# searching for targeted cells...
# (456, 266)
# (626, 686)
# (448, 252)
# (596, 816)
# (338, 212)
# (322, 530)
# (578, 536)
# (452, 240)
# (570, 572)
# (494, 278)
# (478, 832)
# (372, 396)
# (508, 582)
# (372, 374)
# (426, 778)
# (700, 812)
# (594, 766)
# (334, 418)
# (578, 550)
# (570, 552)
# (632, 916)
# (680, 826)
# (540, 664)
# (680, 826)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-009/2021-01-19_t-009.pkl
#
# Number of targeted cells found suite2p:  23
#
# Target cells found in suite2p:  [19, 82, 92, 174, 180, 191, 240, 254, 255, 313, 486, 565, 658, 794, 1063, 1379, 1510, 1593, 2051, 2344, 2586, 2788, 2850]  -- 23 cells (out of 54 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-009/2021-01-19_t-009.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-009/2021-01-19_t-009_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file026_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file027_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file028_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file029_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file030_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file031_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file032_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file033_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file034_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-009/2021-01-19_t-009.pkl
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-009/2021-01-19_t-009.pkl
#
# collecting stim traces for cell # 1 out of 54
# collecting stim traces for cell # 2 out of 54
# collecting stim traces for cell # 3 out of 54
# collecting stim traces for cell # 4 out of 54
# collecting stim traces for cell # 5 out of 54
# collecting stim traces for cell # 6 out of 54
# collecting stim traces for cell # 7 out of 54
# collecting stim traces for cell # 8 out of 54
# collecting stim traces for cell # 9 out of 54
# collecting stim traces for cell # 10 out of 54
# collecting stim traces for cell # 11 out of 54
# collecting stim traces for cell # 12 out of 54
# collecting stim traces for cell # 13 out of 54
# collecting stim traces for cell # 14 out of 54
# collecting stim traces for cell # 15 out of 54
# collecting stim traces for cell # 16 out of 54
# collecting stim traces for cell # 17 out of 54
# collecting stim traces for cell # 18 out of 54
# collecting stim traces for cell # 19 out of 54
# collecting stim traces for cell # 20 out of 54
# collecting stim traces for cell # 21 out of 54
# collecting stim traces for cell # 22 out of 54
# collecting stim traces for cell # 23 out of 54
# collecting stim traces for cell # 24 out of 54
# collecting stim traces for cell # 25 out of 54
# collecting stim traces for cell # 26 out of 54
# collecting stim traces for cell # 27 out of 54
# collecting stim traces for cell # 28 out of 54
# collecting stim traces for cell # 29 out of 54
# collecting stim traces for cell # 30 out of 54
# collecting stim traces for cell # 31 out of 54
# collecting stim traces for cell # 32 out of 54
# collecting stim traces for cell # 33 out of 54
# collecting stim traces for cell # 34 out of 54
# collecting stim traces for cell # 35 out of 54
# collecting stim traces for cell # 36 out of 54
# collecting stim traces for cell # 37 out of 54
# collecting stim traces for cell # 38 out of 54
# collecting stim traces for cell # 39 out of 54
# collecting stim traces for cell # 40 out of 54
# collecting stim traces for cell # 41 out of 54
# collecting stim traces for cell # 42 out of 54
# collecting stim traces for cell # 43 out of 54
# collecting stim traces for cell # 44 out of 54
# collecting stim traces for cell # 45 out of 54
# collecting stim traces for cell # 46 out of 54
# collecting stim traces for cell # 47 out of 54
# collecting stim traces for cell # 48 out of 54
# collecting stim traces for cell # 49 out of 54
# collecting stim traces for cell # 50 out of 54
# collecting stim traces for cell # 51 out of 54
# collecting stim traces for cell # 52 out of 54
# collecting stim traces for cell # 53 out of 54
# collecting stim traces for cell # 54 out of 54
# (54, 57)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 48.0 percent hits over 100 stims
# |- Target # 1: 47.0 percent hits over 100 stims
# |- Target # 2: 47.0 percent hits over 100 stims
# |- Target # 3: 66.0 percent hits over 100 stims
# |- Target # 4: 91.0 percent hits over 100 stims
# |- Target # 5: 74.0 percent hits over 100 stims
# |- Target # 6: 41.0 percent hits over 100 stims
# |- Target # 7: 44.0 percent hits over 100 stims
# |- Target # 8: 63.0 percent hits over 100 stims
# |- Target # 9: 63.0 percent hits over 100 stims
# |- Target # 10: 67.0 percent hits over 100 stims
# |- Target # 11: 66.0 percent hits over 100 stims
# |- Target # 12: 60.0 percent hits over 100 stims
# |- Target # 13: 85.0 percent hits over 100 stims
# |- Target # 14: 49.0 percent hits over 100 stims
# |- Target # 15: 38.0 percent hits over 100 stims
# |- Target # 16: 47.0 percent hits over 100 stims
# |- Target # 17: 47.0 percent hits over 100 stims
# |- Target # 18: 43.0 percent hits over 100 stims
# |- Target # 19: 42.0 percent hits over 100 stims
# |- Target # 20: 61.0 percent hits over 100 stims
# |- Target # 21: 55.0 percent hits over 100 stims
# |- Target # 22: 46.0 percent hits over 100 stims
# |- Target # 23: 51.0 percent hits over 100 stims
# |- Target # 24: 60.0 percent hits over 100 stims
# |- Target # 25: 53.0 percent hits over 100 stims
# |- Target # 26: 85.0 percent hits over 100 stims
# |- Target # 27: 45.0 percent hits over 100 stims
# |- Target # 28: 54.0 percent hits over 100 stims
# |- Target # 29: 63.0 percent hits over 100 stims
# |- Target # 30: 49.0 percent hits over 100 stims
# |- Target # 31: 48.0 percent hits over 100 stims
# |- Target # 32: 43.0 percent hits over 100 stims
# |- Target # 33: 41.0 percent hits over 100 stims
# |- Target # 34: 48.0 percent hits over 100 stims
# |- Target # 35: 44.0 percent hits over 100 stims
# |- Target # 36: 60.0 percent hits over 100 stims
# |- Target # 37: 62.0 percent hits over 100 stims
# |- Target # 38: 47.0 percent hits over 100 stims
# |- Target # 39: 43.0 percent hits over 100 stims
# |- Target # 40: 38.0 percent hits over 100 stims
# |- Target # 41: 68.0 percent hits over 100 stims
# |- Target # 42: 61.0 percent hits over 100 stims
# |- Target # 43: 95.0 percent hits over 100 stims
# |- Target # 44: 70.0 percent hits over 100 stims
# |- Target # 45: 78.0 percent hits over 100 stims
# |- Target # 46: 71.0 percent hits over 100 stims
# |- Target # 47: 57.0 percent hits over 100 stims
# |- Target # 48: 83.0 percent hits over 100 stims
# |- Target # 49: 80.0 percent hits over 100 stims
# |- Target # 50: 66.0 percent hits over 100 stims
# |- Target # 51: 44.0 percent hits over 100 stims
# |- Target # 52: 53.0 percent hits over 100 stims
# |- Target # 53: 54.0 percent hits over 100 stims
#
# avg photostim. success rate is: 57.48 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-009/2021-01-19_t-009.pkl

# %% [markdown]
# ### post4ap

# %%
trials = ['t-011', 't-016', 't-017']

trials = ['t-011']
for trial in trials:
    ###### IMPORT pkl file containing expobj
    prep = 'PS07'
    date = '2021-01-19'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/%s/%s_%s/%s_%s.pkl" % (date, prep, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/%s/suite2p/alloptical-2p-0_8x-alltrials/plane0' % (date, prep)
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-01-19, t-011" from: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-011/2021-01-19_t-011.pkl
#
#
# DONE IMPORT of PS07: t-011, post 4ap 2p all optical, 18 cells x 3 groups; 7mW per cell; 250ms stim multi_interleaved (prot. #3);  photostim responses seem to be more like the prot 3b pre 4ap 100ms stim. definitely there are dF responders short seizures
#
# -----Loading up target coordinates...
# Number of targets: 54
# Number of targets (in SLM group 1):  18
# Number of targets (in SLM group 2):  18
# Number of targets (in SLM group 3):  18
# Got targets...
# re-collecting subset frames of current trial
# baseline frames:  [0, 22535]
# current trial frames:  [68957, 84039]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-011/2021-01-19_t-011.pkl
#
# Loading 1648 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# |- Loaded 1648 cells, recorded for 990.66 secs
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-011/2021-01-19_t-011.pkl
#
#
# searching for targeted cells...
# (456, 266)
# (626, 686)
# (448, 252)
# (596, 816)
# (338, 212)
# (322, 530)
# (578, 536)
# (452, 240)
# (570, 572)
# (494, 278)
# (478, 832)
# (372, 396)
# (508, 582)
# (372, 374)
# (426, 778)
# (700, 812)
# (594, 766)
# (334, 418)
# (578, 550)
# (570, 552)
# (632, 916)
# (680, 826)
# (540, 664)
# (680, 826)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-011/2021-01-19_t-011.pkl
#
# Number of targeted cells found suite2p:  23
#
# Target cells found in suite2p:  [19, 82, 92, 174, 180, 191, 240, 254, 255, 313, 486, 565, 658, 794, 1063, 1379, 1510, 1593, 2051, 2344, 2586, 2788, 2850]  -- 23 cells (out of 54 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-011/2021-01-19_t-011.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-011/2021-01-19_t-011_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file034_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file035_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file036_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file037_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file038_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file039_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file040_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file041_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file042_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-011/2021-01-19_t-011.pkl
#
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-011/2021-01-19_t-011.pkl
#
# (54, 64)
# (54, 64)
#
#  -- working on getting stim traces for cells inside sz boundary --
# (54, 64)
#
#  Calculating stim success rates and response magnitudes (of SLM targets) *********** [2.1]
# |- calculating stim success rates (outsz) - 76 stims [2.2]
# |- calculating stim success rates (insz) - 24 stims [2.3]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-19/PS07/2021-01-19_t-011/2021-01-19_t-011.pkl
