# %% [markdown]
# # Processing - RL109 - 2020-12-19

# %%
import sys; sys.path.append('/home/pshah/Documents/code/PackerLab_pycharm/')
import os
import pickle
import alloptical_utils_pj as aoutils
import alloptical_plotting_utils as aoplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import utils.funcs_pj as pj
import tifffile as tf
# Out:
# importing resultsobj from: /home/pshah/mnt/qnap/Analysis/alloptical_results_superobject.pkl ...
# |-DONE IMPORT of <class 'alloptical_utils_pj.AllOpticalResults'> resultsobj

# %%
to_suite2p = ['t-005', 't-006', 't-007', 't-008', 't-011', 't-012', 't-013', 't-014', 't-016',
              't-017', 't-018', 't-019', 't-020', 't-021']
baseline_trials = ['t-005', 't-006'] # specify which trials to use as spont baseline
# note ^^^ this only works currently when the spont baseline trials all come first, and also back to back

# %% [markdown]
# ### pre4ap

# %%
trials = ['t-007', 't-008', 't-011', 't-012', 't-013', 't-014']

trials = ['t-013']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2020-12-19'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/RL109/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0'
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# -----------------------------------------------------------------------------------------------------------
# importing expobj for "2020-12-19, t-013" from: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl ...
# |- DONE IMPORT of RL109: t-013, pre 4ap 2p all optical, photostim: 9 cells x 4 groups; 5mW per cell; preset: 2020-11-25_PS_250ms-stim-50hz (approach #1); same targets and protocol as t011 but random vs ekmeans group assignment
#
# -----Loading up target coordinates...
# Number of targets: 36
# spiral size: 10.0um
# pix sz x: 2.18458479264539um
# radius (in pixels): 6.55px
# radius of target exclusion zone (in pixels): 8.74px
# Number of targets (in SLM group 1):  9
# Number of targets (in SLM group 2):  9
# Number of targets (in SLM group 3):  9
# Number of targets (in SLM group 4):  9
# Got targets...
# re-collecting subset frames of current trial
# baseline frames:  [0, 38053]
# current trial frames:  [103525, 119893]
#
# 	 -- pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl --
# Loading 640 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# |- Loaded 640 cells, recorded for 542.17 secs
#
# 	 -- pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl --
#
# ----------------------------------------------------------------
# running finding of good cells for suite2p ROIs
# ----------------------------------------------------------------
# # of good cells found:  316  (out of  640  ROIs)
# searching for targeted cells... [Rob version]
# ------- Search completed.
#
# 	 -- pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl --
# Number of targeted cells:  37
# ------- Search completed.
#
# 	 -- pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl --
# Number of exclude cells: 42
# Number of good, s2p non_targets: 286
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file051_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file052_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file053_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file054_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file055_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file056_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file057_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file058_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file059_chan0.tif
#
# 	 -- pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl --
#
# 	 -- pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl --
# (36, 151)
#
#  Calculating stim success rates and response magnitudes (of SLM targets) *********** [3.]
# /home/pshah/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py:3988: RuntimeWarning: Mean of empty slice.
#   mean_ = arr[arr < a].mean()
# /home/pshah/anaconda3/envs/2021/lib/python3.8/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# Completed collecting pre to post stim traces -- normalized to pre-stim period -- for 290 cells
#
# 	 -- pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl --

# %% [markdown]
# ## post4ap

# %%
trial = 't-020'
date = '2020-12-19'
pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/RL109/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)

expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path, do_processing=False)
# Out:
# importing expobj for "2020-12-19, t-020" from: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
#
#
# DONE IMPORT of RL109: t-020, post 4ap 2p all optical, 4 sz, trial ends mid sz

# %%
# trials = ['t-016', 't-017', 't-018', 't-019', 't-020', 't-021']
trials = ['t-020']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2020-12-19'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/RL109/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path, do_processing=False)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0'
    
    
    expobj.pre_stim = int(0.5 * expobj.fps)  # length of pre stim trace collected
    expobj.post_stim = int(3 * expobj.fps)  # length of post stim trace collected
    expobj.post_stim_response_window_msec = 500  # msec
    expobj.post_stim_response_frames_window = int(expobj.fps * expobj.post_stim_response_window_msec / 1000)
    
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2020-12-19, t-020" from: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
#
#
# DONE IMPORT of RL109: t-020, post 4ap 2p all optical, 4 sz, trial ends mid sz
#
# -----Loading up target coordinates...
# Number of targets: 50
# Number of targets (in SLM group 1):  10
# Number of targets (in SLM group 2):  10
# Number of targets (in SLM group 3):  10
# Number of targets (in SLM group 4):  10
# Number of targets (in SLM group 5):  10
# Got targets...
# re-collecting subset frames of current trial
# baseline frames:  [0, 38053]
# current trial frames:  [212369, 232384]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
#
# Loading 640 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# |- Loaded 640 cells, recorded for 663.03 secs
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
#
#
# searching for targeted cells...
# (350, 136)
# (255, 242)
# (243, 312)
# (261, 418)
# (237, 221)
# (320, 148)
# (330, 127)
# (341, 74)
# (482, 115)
# (227, 221)
# (410, 245)
# (191, 278)
# (301, 95)
# (262, 135)
# (263, 305)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
#
# Number of targeted cells found suite2p:  15
#
# Target cells found in suite2p:  [28, 69, 84, 162, 165, 178, 266, 271, 304, 397, 415, 416, 590, 769, 862]  -- 15 cells (out of 50 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file106_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file107_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file108_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file109_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file110_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file111_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file112_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file113_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file114_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file115_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file116_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
#
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
#
# (50, 143)
# (50, 143)
#
#  -- working on getting stim traces for cells inside sz boundary --
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# classifying of sz boundaries not completed for this expobj RL109 t-020
# (50, 143)
#
#  Calculating stim success rates and response magnitudes (of SLM targets) *********** [2.1]
# |- calculating stim success rates (outsz) - 23 stims [2.2]
# No slmtargets_sz_stim (sz boundary classification not done) for: RL109 t-020  [2.4]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
