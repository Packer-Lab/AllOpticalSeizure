# %% [markdown]
# # Processing - PS11 - 2021-01-24

# %%
import sys; sys.path.append('/home/pshah/Documents/code/PackerLab_pycharm/')
import os
import pickle
import alloptical_utils_pj as aoutils
import alloptical_plotting_utils as aoplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import utils.funcs_pj as pj
import tifffile as tf

# %%
to_suite2p = ['t-003', 't-006', 't-007', 't-008', 't-010', 't-011', 't-016'] # specify all trials that were used in the suite2p runtotal_frames_stitched = 0
baseline_trials = ['t-003', 't-006'] # specify which trials to use as spont baseline
# note ^^^ this only works currently when the spont baseline trials all come first, and also back to back

# %% [markdown]
# ### pre4ap

# %%
trials = ['t-007', 't-008', 't-010']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    prep = 'PS11'
    date = '2021-01-24'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/%s/%s_%s/%s_%s.pkl" % (date, prep, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/%s/suite2p/alloptical-2p-0_8x-alltrials/plane0' % (date, prep)
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-01-24, t-007" from: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-007/2021-01-24_t-007.pkl
#
#
# DONE IMPORT of PS11: t-007, pre 4ap 2p all optical, 12 cells x 4 groups; 7mW per cell; 250 ms stim multi group (prot #2)
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-007/2021-01-24_t-007.pkl
#
# re-collecting subset frames of current trial
# baseline frames:  [0, 25841]
# current trial frames:  [25841, 41315]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-007/2021-01-24_t-007.pkl
#
# Loading 2429 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-007/2021-01-24_t-007.pkl
#
#
# searching for targeted cells...
# (160, 218)
# (434, 776)
# (458, 812)
# (492, 796)
# (568, 778)
# (476, 448)
# (522, 728)
# (272, 732)
# (508, 424)
# (284, 714)
# (308, 300)
# (444, 494)
# (306, 518)
# (156, 188)
# (174, 194)
# (326, 272)
# (414, 322)
# (470, 748)
# (270, 474)
# (452, 472)
# (416, 344)
# (254, 600)
# (470, 396)
# (572, 464)
# (420, 808)
# (222, 624)
# (568, 778)
# (252, 164)
# (300, 710)
# (290, 208)
# (452, 304)
# (226, 600)
# (270, 230)
# (254, 140)
# (202, 138)
# (272, 732)
# (210, 124)
# (326, 272)
# (498, 358)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-007/2021-01-24_t-007.pkl
#
# Number of targeted cells found suite2p:  39
#
# Target cells found in suite2p:  [4, 5, 8, 75, 86, 89, 98, 134, 135, 165, 169, 198, 207, 210, 216, 223, 288, 300, 303, 322, 340, 373, 455, 469, 522, 750, 770, 819, 926, 1004, 1079, 1127, 1478, 2250, 2455, 3118, 3292, 3409, 4195]  -- 39 cells (out of 48 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-007/2021-01-24_t-007.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-007/2021-01-24_t-007_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file012_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file013_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file014_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file015_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file016_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file017_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file018_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file019_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file020_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-007/2021-01-24_t-007.pkl
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-007/2021-01-24_t-007.pkl
#
# collecting stim traces for cell # 1 out of 48
# collecting stim traces for cell # 2 out of 48
# collecting stim traces for cell # 3 out of 48
# collecting stim traces for cell # 4 out of 48
# collecting stim traces for cell # 5 out of 48
# collecting stim traces for cell # 6 out of 48
# collecting stim traces for cell # 7 out of 48
# collecting stim traces for cell # 8 out of 48
# collecting stim traces for cell # 9 out of 48
# collecting stim traces for cell # 10 out of 48
# collecting stim traces for cell # 11 out of 48
# collecting stim traces for cell # 12 out of 48
# collecting stim traces for cell # 13 out of 48
# collecting stim traces for cell # 14 out of 48
# collecting stim traces for cell # 15 out of 48
# collecting stim traces for cell # 16 out of 48
# collecting stim traces for cell # 17 out of 48
# collecting stim traces for cell # 18 out of 48
# collecting stim traces for cell # 19 out of 48
# collecting stim traces for cell # 20 out of 48
# collecting stim traces for cell # 21 out of 48
# collecting stim traces for cell # 22 out of 48
# collecting stim traces for cell # 23 out of 48
# collecting stim traces for cell # 24 out of 48
# collecting stim traces for cell # 25 out of 48
# collecting stim traces for cell # 26 out of 48
# collecting stim traces for cell # 27 out of 48
# collecting stim traces for cell # 28 out of 48
# collecting stim traces for cell # 29 out of 48
# collecting stim traces for cell # 30 out of 48
# collecting stim traces for cell # 31 out of 48
# collecting stim traces for cell # 32 out of 48
# collecting stim traces for cell # 33 out of 48
# collecting stim traces for cell # 34 out of 48
# collecting stim traces for cell # 35 out of 48
# collecting stim traces for cell # 36 out of 48
# collecting stim traces for cell # 37 out of 48
# collecting stim traces for cell # 38 out of 48
# collecting stim traces for cell # 39 out of 48
# collecting stim traces for cell # 40 out of 48
# collecting stim traces for cell # 41 out of 48
# collecting stim traces for cell # 42 out of 48
# collecting stim traces for cell # 43 out of 48
# collecting stim traces for cell # 44 out of 48
# collecting stim traces for cell # 45 out of 48
# collecting stim traces for cell # 46 out of 48
# collecting stim traces for cell # 47 out of 48
# collecting stim traces for cell # 48 out of 48
# (48, 68)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 27.5 percent hits over 200 stims
# |- Target # 1: 22.5 percent hits over 200 stims
# |- Target # 2: 25.5 percent hits over 200 stims
# |- Target # 3: 20.5 percent hits over 200 stims
# |- Target # 4: 32.0 percent hits over 200 stims
# |- Target # 5: 24.5 percent hits over 200 stims
# |- Target # 6: 30.0 percent hits over 200 stims
# |- Target # 7: 32.0 percent hits over 200 stims
# |- Target # 8: 31.0 percent hits over 200 stims
# |- Target # 9: 23.0 percent hits over 200 stims
# |- Target # 10: 25.5 percent hits over 200 stims
# |- Target # 11: 39.0 percent hits over 200 stims
# |- Target # 12: 32.5 percent hits over 200 stims
# |- Target # 13: 31.0 percent hits over 200 stims
# |- Target # 14: 32.0 percent hits over 200 stims
# |- Target # 15: 40.0 percent hits over 200 stims
# |- Target # 16: 34.5 percent hits over 200 stims
# |- Target # 17: 32.5 percent hits over 200 stims
# |- Target # 18: 28.5 percent hits over 200 stims
# |- Target # 19: 32.5 percent hits over 200 stims
# |- Target # 20: 37.5 percent hits over 200 stims
# |- Target # 21: 40.0 percent hits over 200 stims
# |- Target # 22: 37.0 percent hits over 200 stims
# |- Target # 23: 35.5 percent hits over 200 stims
# |- Target # 24: 37.0 percent hits over 200 stims
# |- Target # 25: 37.5 percent hits over 200 stims
# |- Target # 26: 30.0 percent hits over 200 stims
# |- Target # 27: 27.5 percent hits over 200 stims
# |- Target # 28: 36.0 percent hits over 200 stims
# |- Target # 29: 41.0 percent hits over 200 stims
# |- Target # 30: 39.0 percent hits over 200 stims
# |- Target # 31: 43.0 percent hits over 200 stims
# |- Target # 32: 43.0 percent hits over 200 stims
# |- Target # 33: 19.0 percent hits over 200 stims
# |- Target # 34: 41.5 percent hits over 200 stims
# |- Target # 35: 42.0 percent hits over 200 stims
# |- Target # 36: 36.5 percent hits over 200 stims
# |- Target # 37: 37.5 percent hits over 200 stims
# |- Target # 38: 39.0 percent hits over 200 stims
# |- Target # 39: 34.0 percent hits over 200 stims
# |- Target # 40: 38.5 percent hits over 200 stims
# |- Target # 41: 42.5 percent hits over 200 stims
# |- Target # 42: 32.0 percent hits over 200 stims
# |- Target # 43: 42.0 percent hits over 200 stims
# |- Target # 44: 29.0 percent hits over 200 stims
# |- Target # 45: 48.0 percent hits over 200 stims
# |- Target # 46: 47.5 percent hits over 200 stims
# |- Target # 47: 48.0 percent hits over 200 stims
#
# avg photostim. success rate is: 34.53 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-007/2021-01-24_t-007.pkl
#
#
# importing expobj for "2021-01-24, t-008" from: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-008/2021-01-24_t-008.pkl
#
#
# DONE IMPORT of PS11: t-008, pre 4ap 2p all optical, 12 cells x 4 groups; 7mW per cell; 250 ms stim interleaved (prot #3)
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-008/2021-01-24_t-008.pkl
#
# re-collecting subset frames of current trial
# baseline frames:  [0, 25841]
# current trial frames:  [41315, 48977]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-008/2021-01-24_t-008.pkl
#
# Loading 2429 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-008/2021-01-24_t-008.pkl
#
#
# searching for targeted cells...
# (160, 218)
# (434, 776)
# (458, 812)
# (492, 796)
# (568, 778)
# (476, 448)
# (522, 728)
# (272, 732)
# (508, 424)
# (284, 714)
# (308, 300)
# (444, 494)
# (306, 518)
# (156, 188)
# (174, 194)
# (326, 272)
# (414, 322)
# (470, 748)
# (270, 474)
# (452, 472)
# (416, 344)
# (254, 600)
# (470, 396)
# (572, 464)
# (420, 808)
# (222, 624)
# (568, 778)
# (252, 164)
# (300, 710)
# (290, 208)
# (452, 304)
# (226, 600)
# (270, 230)
# (254, 140)
# (202, 138)
# (272, 732)
# (210, 124)
# (326, 272)
# (498, 358)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-008/2021-01-24_t-008.pkl
#
# Number of targeted cells found suite2p:  39
#
# Target cells found in suite2p:  [4, 5, 8, 75, 86, 89, 98, 134, 135, 165, 169, 198, 207, 210, 216, 223, 288, 300, 303, 322, 340, 373, 455, 469, 522, 750, 770, 819, 926, 1004, 1079, 1127, 1478, 2250, 2455, 3118, 3292, 3409, 4195]  -- 39 cells (out of 48 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-008/2021-01-24_t-008.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-008/2021-01-24_t-008_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file020_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file021_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file022_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file023_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file024_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-008/2021-01-24_t-008.pkl
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-008/2021-01-24_t-008.pkl
#
# collecting stim traces for cell # 1 out of 48
# collecting stim traces for cell # 2 out of 48
# collecting stim traces for cell # 3 out of 48
# collecting stim traces for cell # 4 out of 48
# collecting stim traces for cell # 5 out of 48
# collecting stim traces for cell # 6 out of 48
# collecting stim traces for cell # 7 out of 48
# collecting stim traces for cell # 8 out of 48
# collecting stim traces for cell # 9 out of 48
# collecting stim traces for cell # 10 out of 48
# collecting stim traces for cell # 11 out of 48
# collecting stim traces for cell # 12 out of 48
# collecting stim traces for cell # 13 out of 48
# collecting stim traces for cell # 14 out of 48
# collecting stim traces for cell # 15 out of 48
# collecting stim traces for cell # 16 out of 48
# collecting stim traces for cell # 17 out of 48
# collecting stim traces for cell # 18 out of 48
# collecting stim traces for cell # 19 out of 48
# collecting stim traces for cell # 20 out of 48
# collecting stim traces for cell # 21 out of 48
# collecting stim traces for cell # 22 out of 48
# collecting stim traces for cell # 23 out of 48
# collecting stim traces for cell # 24 out of 48
# collecting stim traces for cell # 25 out of 48
# collecting stim traces for cell # 26 out of 48
# collecting stim traces for cell # 27 out of 48
# collecting stim traces for cell # 28 out of 48
# collecting stim traces for cell # 29 out of 48
# collecting stim traces for cell # 30 out of 48
# collecting stim traces for cell # 31 out of 48
# collecting stim traces for cell # 32 out of 48
# collecting stim traces for cell # 33 out of 48
# collecting stim traces for cell # 34 out of 48
# collecting stim traces for cell # 35 out of 48
# collecting stim traces for cell # 36 out of 48
# collecting stim traces for cell # 37 out of 48
# collecting stim traces for cell # 38 out of 48
# collecting stim traces for cell # 39 out of 48
# collecting stim traces for cell # 40 out of 48
# collecting stim traces for cell # 41 out of 48
# collecting stim traces for cell # 42 out of 48
# collecting stim traces for cell # 43 out of 48
# collecting stim traces for cell # 44 out of 48
# collecting stim traces for cell # 45 out of 48
# collecting stim traces for cell # 46 out of 48
# collecting stim traces for cell # 47 out of 48
# collecting stim traces for cell # 48 out of 48
# (48, 65)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 18.0 percent hits over 50 stims
# |- Target # 1: 2.0 percent hits over 50 stims
# |- Target # 2: 10.0 percent hits over 50 stims
# |- Target # 3: 4.0 percent hits over 50 stims
# |- Target # 4: 12.0 percent hits over 50 stims
# |- Target # 5: 16.0 percent hits over 50 stims
# |- Target # 6: 18.0 percent hits over 50 stims
# |- Target # 7: 10.0 percent hits over 50 stims
# |- Target # 8: 26.0 percent hits over 50 stims
# |- Target # 9: 0.0 percent hits over 50 stims
# |- Target # 10: 6.0 percent hits over 50 stims
# |- Target # 11: 2.0 percent hits over 50 stims
# |- Target # 12: 2.0 percent hits over 50 stims
# |- Target # 13: 2.0 percent hits over 50 stims
# |- Target # 14: 16.0 percent hits over 50 stims
# |- Target # 15: 16.0 percent hits over 50 stims
# |- Target # 16: 0.0 percent hits over 50 stims
# |- Target # 17: 2.0 percent hits over 50 stims
# |- Target # 18: 8.0 percent hits over 50 stims
# |- Target # 19: 18.0 percent hits over 50 stims
# |- Target # 20: 8.0 percent hits over 50 stims
# |- Target # 21: 2.0 percent hits over 50 stims
# |- Target # 22: 0.0 percent hits over 50 stims
# |- Target # 23: 4.0 percent hits over 50 stims
# |- Target # 24: 4.0 percent hits over 50 stims
# |- Target # 25: 6.0 percent hits over 50 stims
# |- Target # 26: 12.0 percent hits over 50 stims
# |- Target # 27: 8.0 percent hits over 50 stims
# |- Target # 28: 4.0 percent hits over 50 stims
# |- Target # 29: 6.0 percent hits over 50 stims
# |- Target # 30: 0.0 percent hits over 50 stims
# |- Target # 31: 0.0 percent hits over 50 stims
# |- Target # 32: 6.0 percent hits over 50 stims
# |- Target # 33: 16.0 percent hits over 50 stims
# |- Target # 34: 0.0 percent hits over 50 stims
# |- Target # 35: 4.0 percent hits over 50 stims
# |- Target # 36: 2.0 percent hits over 50 stims
# |- Target # 37: 0.0 percent hits over 50 stims
# |- Target # 38: 12.0 percent hits over 50 stims
# |- Target # 39: 4.0 percent hits over 50 stims
# |- Target # 40: 4.0 percent hits over 50 stims
# |- Target # 41: 10.0 percent hits over 50 stims
# |- Target # 42: 6.0 percent hits over 50 stims
# |- Target # 43: 6.0 percent hits over 50 stims
# |- Target # 44: 4.0 percent hits over 50 stims
# |- Target # 45: 16.0 percent hits over 50 stims
# |- Target # 46: 18.0 percent hits over 50 stims
# |- Target # 47: 16.0 percent hits over 50 stims
#
# avg photostim. success rate is: 7.62 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-008/2021-01-24_t-008.pkl
#
#
# importing expobj for "2021-01-24, t-010" from: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-010/2021-01-24_t-010.pkl
#
#
# DONE IMPORT of PS11: t-010, pre 4ap 2p all optical, 12 cells x 4 groups; 5mW per cell; 100 ms stim interleaved (prot #3b)
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-010/2021-01-24_t-010.pkl
#
# re-collecting subset frames of current trial
# baseline frames:  [0, 25841]
# current trial frames:  [48977, 64451]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-010/2021-01-24_t-010.pkl
#
# Loading 2429 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-010/2021-01-24_t-010.pkl
#
#
# searching for targeted cells...
# (160, 218)
# (434, 776)
# (458, 812)
# (492, 796)
# (568, 778)
# (476, 448)
# (522, 728)
# (272, 732)
# (508, 424)
# (284, 714)
# (308, 300)
# (444, 494)
# (306, 518)
# (156, 188)
# (174, 194)
# (326, 272)
# (414, 322)
# (470, 748)
# (270, 474)
# (452, 472)
# (416, 344)
# (254, 600)
# (470, 396)
# (572, 464)
# (420, 808)
# (222, 624)
# (568, 778)
# (252, 164)
# (300, 710)
# (290, 208)
# (452, 304)
# (226, 600)
# (270, 230)
# (254, 140)
# (202, 138)
# (272, 732)
# (210, 124)
# (326, 272)
# (498, 358)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-010/2021-01-24_t-010.pkl
#
# Number of targeted cells found suite2p:  39
#
# Target cells found in suite2p:  [4, 5, 8, 75, 86, 89, 98, 134, 135, 165, 169, 198, 207, 210, 216, 223, 288, 300, 303, 322, 340, 373, 455, 469, 522, 750, 770, 819, 926, 1004, 1079, 1127, 1478, 2250, 2455, 3118, 3292, 3409, 4195]  -- 39 cells (out of 48 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-010/2021-01-24_t-010.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-010/2021-01-24_t-010_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file024_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file025_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file026_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file027_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file028_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file029_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file030_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file031_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file032_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-010/2021-01-24_t-010.pkl
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-010/2021-01-24_t-010.pkl
#
# collecting stim traces for cell # 1 out of 48
# collecting stim traces for cell # 2 out of 48
# collecting stim traces for cell # 3 out of 48
# collecting stim traces for cell # 4 out of 48
# collecting stim traces for cell # 5 out of 48
# collecting stim traces for cell # 6 out of 48
# collecting stim traces for cell # 7 out of 48
# collecting stim traces for cell # 8 out of 48
# collecting stim traces for cell # 9 out of 48
# collecting stim traces for cell # 10 out of 48
# collecting stim traces for cell # 11 out of 48
# collecting stim traces for cell # 12 out of 48
# collecting stim traces for cell # 13 out of 48
# collecting stim traces for cell # 14 out of 48
# collecting stim traces for cell # 15 out of 48
# collecting stim traces for cell # 16 out of 48
# collecting stim traces for cell # 17 out of 48
# collecting stim traces for cell # 18 out of 48
# collecting stim traces for cell # 19 out of 48
# collecting stim traces for cell # 20 out of 48
# collecting stim traces for cell # 21 out of 48
# collecting stim traces for cell # 22 out of 48
# collecting stim traces for cell # 23 out of 48
# collecting stim traces for cell # 24 out of 48
# collecting stim traces for cell # 25 out of 48
# collecting stim traces for cell # 26 out of 48
# collecting stim traces for cell # 27 out of 48
# collecting stim traces for cell # 28 out of 48
# collecting stim traces for cell # 29 out of 48
# collecting stim traces for cell # 30 out of 48
# collecting stim traces for cell # 31 out of 48
# collecting stim traces for cell # 32 out of 48
# collecting stim traces for cell # 33 out of 48
# collecting stim traces for cell # 34 out of 48
# collecting stim traces for cell # 35 out of 48
# collecting stim traces for cell # 36 out of 48
# collecting stim traces for cell # 37 out of 48
# collecting stim traces for cell # 38 out of 48
# collecting stim traces for cell # 39 out of 48
# collecting stim traces for cell # 40 out of 48
# collecting stim traces for cell # 41 out of 48
# collecting stim traces for cell # 42 out of 48
# collecting stim traces for cell # 43 out of 48
# collecting stim traces for cell # 44 out of 48
# collecting stim traces for cell # 45 out of 48
# collecting stim traces for cell # 46 out of 48
# collecting stim traces for cell # 47 out of 48
# collecting stim traces for cell # 48 out of 48
# (48, 57)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 97.0 percent hits over 100 stims
# |- Target # 1: 99.0 percent hits over 100 stims
# |- Target # 2: 97.0 percent hits over 100 stims
# |- Target # 3: 96.0 percent hits over 100 stims
# |- Target # 4: 93.0 percent hits over 100 stims
# |- Target # 5: 92.0 percent hits over 100 stims
# |- Target # 6: 93.0 percent hits over 100 stims
# |- Target # 7: 93.0 percent hits over 100 stims
# |- Target # 8: 74.0 percent hits over 100 stims
# |- Target # 9: 96.0 percent hits over 100 stims
# |- Target # 10: 96.0 percent hits over 100 stims
# |- Target # 11: 96.0 percent hits over 100 stims
# |- Target # 12: 98.0 percent hits over 100 stims
# |- Target # 13: 86.0 percent hits over 100 stims
# |- Target # 14: 91.0 percent hits over 100 stims
# |- Target # 15: 86.0 percent hits over 100 stims
# |- Target # 16: 100.0 percent hits over 100 stims
# |- Target # 17: 93.0 percent hits over 100 stims
# |- Target # 18: 82.0 percent hits over 100 stims
# |- Target # 19: 81.0 percent hits over 100 stims
# |- Target # 20: 95.0 percent hits over 100 stims
# |- Target # 21: 99.0 percent hits over 100 stims
# |- Target # 22: 100.0 percent hits over 100 stims
# |- Target # 23: 99.0 percent hits over 100 stims
# |- Target # 24: 100.0 percent hits over 100 stims
# |- Target # 25: 97.0 percent hits over 100 stims
# |- Target # 26: 93.0 percent hits over 100 stims
# |- Target # 27: 88.0 percent hits over 100 stims
# |- Target # 28: 98.0 percent hits over 100 stims
# |- Target # 29: 100.0 percent hits over 100 stims
# |- Target # 30: 98.0 percent hits over 100 stims
# |- Target # 31: 100.0 percent hits over 100 stims
# |- Target # 32: 96.0 percent hits over 100 stims
# |- Target # 33: 78.0 percent hits over 100 stims
# |- Target # 34: 100.0 percent hits over 100 stims
# |- Target # 35: 100.0 percent hits over 100 stims
# |- Target # 36: 100.0 percent hits over 100 stims
# |- Target # 37: 99.0 percent hits over 100 stims
# |- Target # 38: 92.0 percent hits over 100 stims
# |- Target # 39: 100.0 percent hits over 100 stims
# |- Target # 40: 97.0 percent hits over 100 stims
# |- Target # 41: 95.0 percent hits over 100 stims
# |- Target # 42: 100.0 percent hits over 100 stims
# |- Target # 43: 95.0 percent hits over 100 stims
# |- Target # 44: 97.0 percent hits over 100 stims
# |- Target # 45: 91.0 percent hits over 100 stims
# |- Target # 46: 94.0 percent hits over 100 stims
# |- Target # 47: 93.0 percent hits over 100 stims
#
# avg photostim. success rate is: 94.44 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-010/2021-01-24_t-010.pkl

# %% [markdown]
# ### post4ap

# %%
trials = ['t-011', 't-016']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    prep = 'PS11'
    date = '2021-01-24'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/%s/%s_%s/%s_%s.pkl" % (date, prep, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/%s/suite2p/alloptical-2p-0_8x-alltrials/plane0' % (date, prep)
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-01-24, t-011" from: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-011/2021-01-24_t-011.pkl
#
#
# DONE IMPORT of PS11: t-011, post 4ap 2p all optical, 12 cells x 4 groups; 5mW per cell; 100 ms stim interleaved (prot #3b); 15 sz events, small ones that get longer progressively; 1 sz after end of trial
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-011/2021-01-24_t-011.pkl
#
# re-collecting subset frames of current trial
# baseline frames:  [0, 25841]
# current trial frames:  [64451, 79925]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-011/2021-01-24_t-011.pkl
#
# Loading 2429 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-011/2021-01-24_t-011.pkl
#
#
# searching for targeted cells...
# (160, 218)
# (434, 776)
# (458, 812)
# (492, 796)
# (568, 778)
# (476, 448)
# (522, 728)
# (272, 732)
# (508, 424)
# (284, 714)
# (308, 300)
# (444, 494)
# (306, 518)
# (156, 188)
# (174, 194)
# (326, 272)
# (414, 322)
# (470, 748)
# (270, 474)
# (452, 472)
# (416, 344)
# (254, 600)
# (470, 396)
# (572, 464)
# (420, 808)
# (222, 624)
# (568, 778)
# (252, 164)
# (300, 710)
# (290, 208)
# (452, 304)
# (226, 600)
# (270, 230)
# (254, 140)
# (202, 138)
# (272, 732)
# (210, 124)
# (326, 272)
# (498, 358)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-011/2021-01-24_t-011.pkl
#
# Number of targeted cells found suite2p:  39
#
# Target cells found in suite2p:  [4, 5, 8, 75, 86, 89, 98, 134, 135, 165, 169, 198, 207, 210, 216, 223, 288, 300, 303, 322, 340, 373, 455, 469, 522, 750, 770, 819, 926, 1004, 1079, 1127, 1478, 2250, 2455, 3118, 3292, 3409, 4195]  -- 39 cells (out of 48 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-011/2021-01-24_t-011.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-011/2021-01-24_t-011_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file032_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file033_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file034_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file035_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file036_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file037_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file038_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file039_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-011/2021-01-24_t-011.pkl
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-011/2021-01-24_t-011.pkl
#
# collecting stim traces for cell # 1 out of 48
# collecting stim traces for cell # 2 out of 48
# collecting stim traces for cell # 3 out of 48
# collecting stim traces for cell # 4 out of 48
# collecting stim traces for cell # 5 out of 48
# collecting stim traces for cell # 6 out of 48
# collecting stim traces for cell # 7 out of 48
# collecting stim traces for cell # 8 out of 48
# collecting stim traces for cell # 9 out of 48
# collecting stim traces for cell # 10 out of 48
# collecting stim traces for cell # 11 out of 48
# collecting stim traces for cell # 12 out of 48
# collecting stim traces for cell # 13 out of 48
# collecting stim traces for cell # 14 out of 48
# collecting stim traces for cell # 15 out of 48
# collecting stim traces for cell # 16 out of 48
# collecting stim traces for cell # 17 out of 48
# collecting stim traces for cell # 18 out of 48
# collecting stim traces for cell # 19 out of 48
# collecting stim traces for cell # 20 out of 48
# collecting stim traces for cell # 21 out of 48
# collecting stim traces for cell # 22 out of 48
# collecting stim traces for cell # 23 out of 48
# collecting stim traces for cell # 24 out of 48
# collecting stim traces for cell # 25 out of 48
# collecting stim traces for cell # 26 out of 48
# collecting stim traces for cell # 27 out of 48
# collecting stim traces for cell # 28 out of 48
# collecting stim traces for cell # 29 out of 48
# collecting stim traces for cell # 30 out of 48
# collecting stim traces for cell # 31 out of 48
# collecting stim traces for cell # 32 out of 48
# collecting stim traces for cell # 33 out of 48
# collecting stim traces for cell # 34 out of 48
# collecting stim traces for cell # 35 out of 48
# collecting stim traces for cell # 36 out of 48
# collecting stim traces for cell # 37 out of 48
# collecting stim traces for cell # 38 out of 48
# collecting stim traces for cell # 39 out of 48
# collecting stim traces for cell # 40 out of 48
# collecting stim traces for cell # 41 out of 48
# collecting stim traces for cell # 42 out of 48
# collecting stim traces for cell # 43 out of 48
# collecting stim traces for cell # 44 out of 48
# collecting stim traces for cell # 45 out of 48
# collecting stim traces for cell # 46 out of 48
# collecting stim traces for cell # 47 out of 48
# collecting stim traces for cell # 48 out of 48
# (48, 57)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 74.0 percent hits over 100 stims
# |- Target # 1: 75.0 percent hits over 100 stims
# |- Target # 2: 76.0 percent hits over 100 stims
# |- Target # 3: 69.0 percent hits over 100 stims
# |- Target # 4: 74.0 percent hits over 100 stims
# |- Target # 5: 64.0 percent hits over 100 stims
# |- Target # 6: 69.0 percent hits over 100 stims
# |- Target # 7: 79.0 percent hits over 100 stims
# |- Target # 8: 63.0 percent hits over 100 stims
# |- Target # 9: 78.0 percent hits over 100 stims
# |- Target # 10: 84.0 percent hits over 100 stims
# |- Target # 11: 80.0 percent hits over 100 stims
# |- Target # 12: 83.0 percent hits over 100 stims
# |- Target # 13: 70.0 percent hits over 100 stims
# |- Target # 14: 69.0 percent hits over 100 stims
# |- Target # 15: 70.0 percent hits over 100 stims
# |- Target # 16: 81.0 percent hits over 100 stims
# |- Target # 17: 75.0 percent hits over 100 stims
# |- Target # 18: 70.0 percent hits over 100 stims
# |- Target # 19: 74.0 percent hits over 100 stims
# |- Target # 20: 79.0 percent hits over 100 stims
# |- Target # 21: 79.0 percent hits over 100 stims
# |- Target # 22: 84.0 percent hits over 100 stims
# |- Target # 23: 84.0 percent hits over 100 stims
# |- Target # 24: 81.0 percent hits over 100 stims
# |- Target # 25: 79.0 percent hits over 100 stims
# |- Target # 26: 78.0 percent hits over 100 stims
# |- Target # 27: 80.0 percent hits over 100 stims
# |- Target # 28: 84.0 percent hits over 100 stims
# |- Target # 29: 86.0 percent hits over 100 stims
# |- Target # 30: 82.0 percent hits over 100 stims
# |- Target # 31: 84.0 percent hits over 100 stims
# |- Target # 32: 74.0 percent hits over 100 stims
# |- Target # 33: 70.0 percent hits over 100 stims
# |- Target # 34: 85.0 percent hits over 100 stims
# |- Target # 35: 74.0 percent hits over 100 stims
# |- Target # 36: 84.0 percent hits over 100 stims
# |- Target # 37: 83.0 percent hits over 100 stims
# |- Target # 38: 73.0 percent hits over 100 stims
# |- Target # 39: 82.0 percent hits over 100 stims
# |- Target # 40: 81.0 percent hits over 100 stims
# |- Target # 41: 86.0 percent hits over 100 stims
# |- Target # 42: 73.0 percent hits over 100 stims
# |- Target # 43: 73.0 percent hits over 100 stims
# |- Target # 44: 71.0 percent hits over 100 stims
# |- Target # 45: 68.0 percent hits over 100 stims
# |- Target # 46: 61.0 percent hits over 100 stims
# |- Target # 47: 74.0 percent hits over 100 stims
#
# avg photostim. success rate is: 76.44 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-011/2021-01-24_t-011.pkl
#
#
# importing expobj for "2021-01-24, t-016" from: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-016/2021-01-24_t-016.pkl
#
#
# DONE IMPORT of PS11: t-016, post 4ap 2p all optical, 12 cells x 4 groups; 7mW per cell; 250 ms stim multi group (prot #2); 2 sz events - trial starts just after onset of 1st
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-016/2021-01-24_t-016.pkl
#
# re-collecting subset frames of current trial
# baseline frames:  [0, 25841]
# current trial frames:  [79925, 95399]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-016/2021-01-24_t-016.pkl
#
# Loading 2429 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-016/2021-01-24_t-016.pkl
#
#
# searching for targeted cells...
# (160, 218)
# (434, 776)
# (458, 812)
# (492, 796)
# (568, 778)
# (476, 448)
# (522, 728)
# (272, 732)
# (508, 424)
# (284, 714)
# (308, 300)
# (444, 494)
# (306, 518)
# (156, 188)
# (174, 194)
# (326, 272)
# (414, 322)
# (470, 748)
# (270, 474)
# (452, 472)
# (416, 344)
# (254, 600)
# (470, 396)
# (572, 464)
# (420, 808)
# (222, 624)
# (568, 778)
# (252, 164)
# (300, 710)
# (290, 208)
# (452, 304)
# (226, 600)
# (270, 230)
# (254, 140)
# (202, 138)
# (272, 732)
# (210, 124)
# (326, 272)
# (498, 358)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-016/2021-01-24_t-016.pkl
#
# Number of targeted cells found suite2p:  39
#
# Target cells found in suite2p:  [4, 5, 8, 75, 86, 89, 98, 134, 135, 165, 169, 198, 207, 210, 216, 223, 288, 300, 303, 322, 340, 373, 455, 469, 522, 750, 770, 819, 926, 1004, 1079, 1127, 1478, 2250, 2455, 3118, 3292, 3409, 4195]  -- 39 cells (out of 48 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-016/2021-01-24_t-016.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-016/2021-01-24_t-016_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file039_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file040_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file041_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file042_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file043_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file044_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file045_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file046_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file047_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-016/2021-01-24_t-016.pkl
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-016/2021-01-24_t-016.pkl
#
# collecting stim traces for cell # 1 out of 48
# collecting stim traces for cell # 2 out of 48
# collecting stim traces for cell # 3 out of 48
# collecting stim traces for cell # 4 out of 48
# collecting stim traces for cell # 5 out of 48
# collecting stim traces for cell # 6 out of 48
# collecting stim traces for cell # 7 out of 48
# collecting stim traces for cell # 8 out of 48
# collecting stim traces for cell # 9 out of 48
# collecting stim traces for cell # 10 out of 48
# collecting stim traces for cell # 11 out of 48
# collecting stim traces for cell # 12 out of 48
# collecting stim traces for cell # 13 out of 48
# collecting stim traces for cell # 14 out of 48
# collecting stim traces for cell # 15 out of 48
# collecting stim traces for cell # 16 out of 48
# collecting stim traces for cell # 17 out of 48
# collecting stim traces for cell # 18 out of 48
# collecting stim traces for cell # 19 out of 48
# collecting stim traces for cell # 20 out of 48
# collecting stim traces for cell # 21 out of 48
# collecting stim traces for cell # 22 out of 48
# collecting stim traces for cell # 23 out of 48
# collecting stim traces for cell # 24 out of 48
# collecting stim traces for cell # 25 out of 48
# collecting stim traces for cell # 26 out of 48
# collecting stim traces for cell # 27 out of 48
# collecting stim traces for cell # 28 out of 48
# collecting stim traces for cell # 29 out of 48
# collecting stim traces for cell # 30 out of 48
# collecting stim traces for cell # 31 out of 48
# collecting stim traces for cell # 32 out of 48
# collecting stim traces for cell # 33 out of 48
# collecting stim traces for cell # 34 out of 48
# collecting stim traces for cell # 35 out of 48
# collecting stim traces for cell # 36 out of 48
# collecting stim traces for cell # 37 out of 48
# collecting stim traces for cell # 38 out of 48
# collecting stim traces for cell # 39 out of 48
# collecting stim traces for cell # 40 out of 48
# collecting stim traces for cell # 41 out of 48
# collecting stim traces for cell # 42 out of 48
# collecting stim traces for cell # 43 out of 48
# collecting stim traces for cell # 44 out of 48
# collecting stim traces for cell # 45 out of 48
# collecting stim traces for cell # 46 out of 48
# collecting stim traces for cell # 47 out of 48
# collecting stim traces for cell # 48 out of 48
# (48, 68)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 34.64 percent hits over 179 stims
# |- Target # 1: 33.52 percent hits over 179 stims
# |- Target # 2: 34.64 percent hits over 179 stims
# |- Target # 3: 31.28 percent hits over 179 stims
# |- Target # 4: 31.28 percent hits over 179 stims
# |- Target # 5: 21.79 percent hits over 179 stims
# |- Target # 6: 32.4 percent hits over 179 stims
# |- Target # 7: 30.17 percent hits over 179 stims
# |- Target # 8: 29.61 percent hits over 179 stims
# /home/pshah/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py:3327: UserWarning: the seizure filtering by *cells* functionality is only available for s2p defined cell targets as of now
#   warnings.warn(
# |- Target # 9: 35.75 percent hits over 179 stims
# |- Target # 10: 35.75 percent hits over 179 stims
# |- Target # 11: 20.67 percent hits over 179 stims
# |- Target # 12: 30.17 percent hits over 179 stims
# |- Target # 13: 30.17 percent hits over 179 stims
# |- Target # 14: 22.91 percent hits over 179 stims
# |- Target # 15: 18.99 percent hits over 179 stims
# |- Target # 16: 24.58 percent hits over 179 stims
# |- Target # 17: 22.35 percent hits over 179 stims
# |- Target # 18: 20.67 percent hits over 179 stims
# |- Target # 19: 20.67 percent hits over 179 stims
# |- Target # 20: 18.44 percent hits over 179 stims
# |- Target # 21: 13.97 percent hits over 179 stims
# |- Target # 22: 16.76 percent hits over 179 stims
# |- Target # 23: 25.7 percent hits over 179 stims
# |- Target # 24: 21.23 percent hits over 179 stims
# |- Target # 25: 21.79 percent hits over 179 stims
# |- Target # 26: 29.61 percent hits over 179 stims
# |- Target # 27: 31.84 percent hits over 179 stims
# |- Target # 28: 19.55 percent hits over 179 stims
# |- Target # 29: 22.91 percent hits over 179 stims
# |- Target # 30: 24.02 percent hits over 179 stims
# |- Target # 31: 21.79 percent hits over 179 stims
# |- Target # 32: 23.46 percent hits over 179 stims
# |- Target # 33: 37.99 percent hits over 179 stims
# |- Target # 34: 18.99 percent hits over 179 stims
# |- Target # 35: 20.11 percent hits over 179 stims
# |- Target # 36: 21.23 percent hits over 179 stims
# |- Target # 37: 24.02 percent hits over 179 stims
# |- Target # 38: 21.23 percent hits over 179 stims
# |- Target # 39: 35.75 percent hits over 179 stims
# |- Target # 40: 20.67 percent hits over 179 stims
# |- Target # 41: 21.23 percent hits over 179 stims
# |- Target # 42: 33.52 percent hits over 179 stims
# |- Target # 43: 28.49 percent hits over 179 stims
# |- Target # 44: 42.46 percent hits over 179 stims
# |- Target # 45: 21.79 percent hits over 179 stims
# |- Target # 46: 21.23 percent hits over 179 stims
# |- Target # 47: 18.44 percent hits over 179 stims
#
# avg photostim. success rate is: 25.84 pct.
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 42.86 percent hits over 21 stims
# |- Target # 1: 47.62 percent hits over 21 stims
# |- Target # 2: 47.62 percent hits over 21 stims
# |- Target # 3: 52.38 percent hits over 21 stims
# |- Target # 4: 38.1 percent hits over 21 stims
# |- Target # 5: 42.86 percent hits over 21 stims
# |- Target # 6: 52.38 percent hits over 21 stims
# |- Target # 7: 42.86 percent hits over 21 stims
# |- Target # 8: 42.86 percent hits over 21 stims
# |- Target # 9: 42.86 percent hits over 21 stims
# |- Target # 10: 33.33 percent hits over 21 stims
# |- Target # 11: 33.33 percent hits over 21 stims
# |- Target # 12: 42.86 percent hits over 21 stims
# |- Target # 13: 47.62 percent hits over 21 stims
# |- Target # 14: 28.57 percent hits over 21 stims
# |- Target # 15: 33.33 percent hits over 21 stims
# |- Target # 16: 38.1 percent hits over 21 stims
# |- Target # 17: 23.81 percent hits over 21 stims
# |- Target # 18: 23.81 percent hits over 21 stims
# |- Target # 19: 28.57 percent hits over 21 stims
# |- Target # 20: 33.33 percent hits over 21 stims
# |- Target # 21: 23.81 percent hits over 21 stims
# |- Target # 22: 52.38 percent hits over 21 stims
# |- Target # 23: 52.38 percent hits over 21 stims
# |- Target # 24: 38.1 percent hits over 21 stims
# |- Target # 25: 42.86 percent hits over 21 stims
# |- Target # 26: 42.86 percent hits over 21 stims
# |- Target # 27: 38.1 percent hits over 21 stims
# |- Target # 28: 38.1 percent hits over 21 stims
# |- Target # 29: 57.14 percent hits over 21 stims
# |- Target # 30: 57.14 percent hits over 21 stims
# |- Target # 31: 52.38 percent hits over 21 stims
# |- Target # 32: 61.9 percent hits over 21 stims
# |- Target # 33: 57.14 percent hits over 21 stims
# |- Target # 34: 47.62 percent hits over 21 stims
# |- Target # 35: 52.38 percent hits over 21 stims
# |- Target # 36: 52.38 percent hits over 21 stims
# |- Target # 37: 57.14 percent hits over 21 stims
# |- Target # 38: 52.38 percent hits over 21 stims
# |- Target # 39: 66.67 percent hits over 21 stims
# |- Target # 40: 57.14 percent hits over 21 stims
# |- Target # 41: 61.9 percent hits over 21 stims
# |- Target # 42: 57.14 percent hits over 21 stims
# |- Target # 43: 71.43 percent hits over 21 stims
# |- Target # 44: 57.14 percent hits over 21 stims
# |- Target # 45: 52.38 percent hits over 21 stims
# |- Target # 46: 57.14 percent hits over 21 stims
# |- Target # 47: 57.14 percent hits over 21 stims
#
# avg photostim. success rate is: 46.53 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-24/PS11/2021-01-24_t-016/2021-01-24_t-016.pkl
