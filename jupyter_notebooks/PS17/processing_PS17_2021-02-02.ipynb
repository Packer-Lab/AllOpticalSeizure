# %% [markdown]
# # Processing - PS17 - 2021-02-02
#
# run on: 2021-06-09

# %%
import sys; sys.path.append('/home/pshah/Documents/code/PackerLab_pycharm/')
import os
import pickle
import alloptical_utils_pj as aoutils
import alloptical_plotting_utils as aoplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import utils.funcs_pj as pj
import tifffile as tf
# Out:
# importing resultsobj from: /home/pshah/mnt/qnap/Analysis/alloptical_results_superobject.pkl
#
#
# DONE IMPORT of <class 'alloptical_utils_pj.AllOpticalResults'> resultsobj

# %%
to_suite2p = ['t-002', 't-004', 't-005', 't-006', 't-007', 't-009', 't-011'] # specify all trials that were used in the suite2p runtotal_frames_stitched = 0
baseline_trials = ['t-002', 't-004'] # specify which trials to use as spont baseline
# note ^^^ this only works currently when the spont baseline trials all come first, and also back to back

# %% [markdown]
# ### pre4ap

# %%
trial='t-006'
prep = 'PS17'
date = '2021-02-02'
pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/%s/%s_%s/%s_%s.pkl" % (date, prep, date, trial, date, trial)

expobj, experiment = aoutils.import_expobj(trial='t-006', date=date, pkl_path=pkl_path)
# Out:
# importing expobj for "2021-02-02, t-006" from: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS17/2021-02-02_t-006/2021-02-02_t-006.pkl
#
#
# DONE IMPORT of PS17: t-006, pre 4ap 2p all optical, 10 cells x 4 groups; 5mW per cell; 250ms stim multi_interleaved (prot. #3)
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS17/2021-02-02_t-006/2021-02-02_t-006.pkl
#
# Loading 2163 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# |- Loaded 2163 cells, recorded for 564.13 secs
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS17/2021-02-02_t-006/2021-02-02_t-006.pkl

# %%
# trials = ['t-005', 't-006', 't-007']
trials = ['t-006', 't-007']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    prep = 'PS17'
    date = '2021-02-02'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/%s/%s_%s/%s_%s.pkl" % (date, prep, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/%s/suite2p/alloptical-2p-0_8x-alltrials/plane0' % (date, prep)
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-02-02, t-005" from: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS17/2021-02-02_t-005/2021-02-02_t-005.pkl
#
#
# DONE IMPORT of PS17: t-005, pre 4ap 2p all optical, 10 cells x 4 groups; 5mW per cell; 100ms stim multi_interleaved (prot. #3b)
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS17/2021-02-02_t-005/2021-02-02_t-005.pkl
#
# re-collecting subset frames of current trial
# baseline frames:  [0, 23331]
# current trial frames:  [23331, 38805]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS17/2021-02-02_t-005/2021-02-02_t-005.pkl
#
# Loading 2117 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS17/2021-02-02_t-005/2021-02-02_t-005.pkl
#
#
# searching for targeted cells...
# (480, 502)
# (416, 632)
# (572, 484)
# (572, 382)
# (422, 660)
# (492, 548)
# (302, 420)
# (530, 574)
# (376, 606)
# (516, 586)
# (550, 422)
# (512, 674)
# (492, 628)
# ...

# %% [markdown]
# ### post4ap

# %%
trials = ['t-009', 't-011']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    prep = 'PS17'
    date = '2021-02-02'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/%s/%s_%s/%s_%s.pkl" % (date, prep, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/%s/suite2p/alloptical-2p-0_8x-alltrials/plane0' % (date, prep)
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-02-02, t-009" from: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS17/2021-02-02_t-009/2021-02-02_t-009.pkl
#
#
# DONE IMPORT of PS17: t-009, post 4ap 2p all optical, 10 cells x 4 groups; 5mW per cell; 250ms stim multi_interleaved (prot. #3); 4 seizures, trials ends mid last sz
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS17/2021-02-02_t-009/2021-02-02_t-009.pkl
#
# re-collecting subset frames of current trial
# baseline frames:  [0, 23331]
# current trial frames:  [55243, 63206]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS17/2021-02-02_t-009/2021-02-02_t-009.pkl
#
# Loading 2117 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS17/2021-02-02_t-009/2021-02-02_t-009.pkl
#
#
# searching for targeted cells...
# (480, 502)
# (416, 632)
# (572, 484)
# (572, 382)
# (422, 660)
# (492, 548)
# (302, 420)
# (530, 574)
# (376, 606)
# (516, 586)
# ...
