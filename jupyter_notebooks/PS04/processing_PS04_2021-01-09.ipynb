# %% [markdown]
# # Processing - PS04 - 2021-01-09

# %%
import sys; sys.path.append('/home/pshah/Documents/code/PackerLab_pycharm/')
import os
import pickle
import alloptical_utils_pj as aoutils
import alloptical_plotting_utils as aoplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import utils.funcs_pj as pj
import tifffile as tf
# Out:
# importing resultsobj from: /home/pshah/mnt/qnap/Analysis/alloptical_results_superobject.pkl
#
#
# DONE IMPORT of <class 'alloptical_utils_pj.AllOpticalResults'> resultsobj

# %%
to_suite2p = ['t-004', 't-006', 't-012', 't-013', 't-014', 't-015', 't-017', 't-018'
                  ] # specify all trials that were used in the suite2p runtotal_frames_stitched = 0
baseline_trials = ['t-004', 't-006'] # specify which trials to use as spont baseline
# note ^^^ this only works currently when the spont baseline trials all come first, and also back to back

# %% [markdown]
# ### pre4ap

# %%
trials = ['t-012', 't-013', 't-014', 't-015', 't-017']

trials = ['t-014']


for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2021-01-09'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/PS04/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path, do_processing=False)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/suite2p/alloptical-2p-1_25x-alltrials/plane0' % date
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-01-09, t-014" from: /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-014/2021-01-09_t-014.pkl
#
#
# DONE IMPORT of PS04: t-014, pre 4ap 2p all optical, 14 cells x 2 groups; 7mW per cell preset: 250ms multi_interleaved 30 trials
#
# -----Loading up target coordinates...
# Number of targets: 28
# Number of targets (in SLM group 1):  14
# Number of targets (in SLM group 2):  14
# Got targets...
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-014/2021-01-09_t-014.pkl
#
# re-collecting subset frames of current trial
# baseline frames:  [0, 27094]
# current trial frames:  [36577, 41545]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-014/2021-01-09_t-014.pkl
#
# Loading 1314 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# |- Loaded 1314 cells, recorded for 325.27 secs
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-014/2021-01-09_t-014.pkl
#
#
# searching for targeted cells...
# (888, 642)
# (196, 494)
# (238, 412)
# (372, 368)
# (928, 722)
# (526, 220)
# (430, 726)
# (854, 662)
# (862, 462)
# (848, 626)
# (110, 472)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-014/2021-01-09_t-014.pkl
#
# Number of targeted cells found suite2p:  11
#
# Target cells found in suite2p:  [78, 84, 150, 188, 237, 260, 298, 878, 1004, 1017, 1363]  -- 11 cells (out of 28 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-014/2021-01-09_t-014.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-014/2021-01-09_t-014_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file018_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file019_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file020_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-014/2021-01-09_t-014.pkl
#
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-014/2021-01-09_t-014.pkl
#
# (28, 60)
#
#  Calculating stim success rates and response magnitudes (of SLM targets) *********** [3.]
#
# Completed collecting pre to post stim traces -- normalized to pre-stim stdF -- for 1303 cells
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-014/2021-01-09_t-014.pkl

# %% [markdown]
# ### post4ap

# %%
trials = ['t-018']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2021-01-09'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/PS04/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path, do_processing=False)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/suite2p/alloptical-2p-1_25x-alltrials/plane0' % date
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-01-09, t-018" from: /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-018/2021-01-09_t-018.pkl
#
#
# DONE IMPORT of PS04: t-018, post 4ap 2p all optical, 6 events, starts mid sz and 1 sz after end of photostim; FOV had moved - check carefully; 14 cells x 2 groups; 7mW per cell preset: 250ms multi_interleaved 30 trials
#
# -----Loading up target coordinates...
# Number of targets: 28
# Number of targets (in SLM group 1):  14
# Number of targets (in SLM group 2):  14
# Got targets...
# re-collecting subset frames of current trial
# baseline frames:  [0, 27094]
# current trial frames:  [51481, 56449]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-018/2021-01-09_t-018.pkl
#
# Loading 1314 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
# |- Loaded 1314 cells, recorded for 330.05 secs
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-018/2021-01-09_t-018.pkl
#
#
# searching for targeted cells...
# (888, 642)
# (196, 494)
# (238, 412)
# (372, 368)
# (928, 722)
# (526, 220)
# (430, 726)
# (854, 662)
# (862, 462)
# (848, 626)
# (110, 472)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-018/2021-01-09_t-018.pkl
#
# Number of targeted cells found suite2p:  11
#
# Target cells found in suite2p:  [78, 84, 150, 188, 237, 260, 298, 878, 1004, 1017, 1363]  -- 11 cells (out of 28 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-018/2021-01-09_t-018.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-018/2021-01-09_t-018_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file025_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file026_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file027_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file028_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-018/2021-01-09_t-018.pkl
#
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-018/2021-01-09_t-018.pkl
#
# (28, 60)
#
#  -- working on getting stim traces for cells inside sz boundary --
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# classifying of sz boundaries not completed for this expobj PS04 t-018
# (28, 60)
#
#  Calculating stim success rates and response magnitudes (of SLM targets) *********** [2.1]
# |- calculating stim success rates (outsz) - 7 stims [2.2]
# No slmtargets_sz_stim (sz boundary classification not done) for: PS04 t-018  [2.4]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-018/2021-01-09_t-018.pkl
