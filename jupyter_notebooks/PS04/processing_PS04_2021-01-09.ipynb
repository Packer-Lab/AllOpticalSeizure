# %% [markdown]
# # Processing - PS04 - 2021-01-09

# %%
import sys; sys.path.append('/home/pshah/Documents/code/PackerLab_pycharm/')
import os
import pickle
import alloptical_utils_pj as aoutils
import alloptical_plotting_utils as aoplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import utils.funcs_pj as pj
import tifffile as tf
# Out:
# importing resultsobj from: /home/pshah/mnt/qnap/Analysis/alloptical_results_superobject.pkl ...
# |-DONE IMPORT of <class 'alloptical_utils_pj.AllOpticalResults'> resultsobj

# %%
to_suite2p = ['t-004', 't-006', 't-012', 't-013', 't-014', 't-015', 't-017', 't-018'
                  ] # specify all trials that were used in the suite2p runtotal_frames_stitched = 0
baseline_trials = ['t-004', 't-006'] # specify which trials to use as spont baseline
# note ^^^ this only works currently when the spont baseline trials all come first, and also back to back

# %% [markdown]
# ### pre4ap

# %%
trials = ['t-012', 't-013', 't-014', 't-015', 't-017']

# trials = ['t-014']


for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2021-01-09'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/PS04/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path, do_processing=False)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/suite2p/alloptical-2p-1_25x-alltrials/plane0' % date
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# |- loading /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-012/2021-01-09_t-012.pkl .. DONE
#
# Running alloptical_processing_photostim for PS04, t-012 ------------------------------
#
# -----Loading up target coordinates...
# Number of targets: 28
# spiral size: 10.0um
# pix sz x: 0.873833917058156um
# radius (in pixels): 5.24px
# radius of target exclusion zone (in pixels): 7.86px
# Number of targets (in SLM group 1):  14
# Number of targets (in SLM group 2):  14
# FIN. -----Loading up target coordinates-----
#
#  ..... plotting function \ ...
# 	 \- PLOTTING mean raw flu trace ...
# ** return elements during print_start_end_plot: None
#
#  ..... plotting function \ END
#
#  ..... plotting function \ ...
# 	 \- PLOTTING LFP stims trace ...
#
#  ..... plotting function \ ...
# 	 \- PLOTTING LFP Signal trace ...
# ** return elements during print_start_end_plot: (<Figure size 720x216 with 1 Axes>, <AxesSubplot:title={'center':'LFP trace - pre 4ap 2p all optical PS04 t-012'}, xlabel='paq clock', ylabel='Voltage'>)
#
#  ..... plotting function \ END
# ** return elements during print_start_end_plot: AxesSubplot(0.0746528,0.226852;0.900347x0.615741)
#
#  ..... plotting function \ END
# re-collecting subset frames of current trial
# baseline frames:  [0, 27094]
# current trial frames:  [27094, 31609]
# \- Saving expobj saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-012/2021-01-09_t-012.pkl --
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file013_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file014_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file015_chan0.tif
# \- Saving expobj saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-012/2021-01-09_t-012.pkl --
#
# ---------- Collecting trace raw stim trace snippets of SLM targets for pre 4ap 2p all optical PS04 t-012 [1.] ----------
# |- returning targets stims array of shape: 28 targets, 30 stims, 67 frames
#
# ---------- Collecting trace dFF stim trace snippets of SLM targets for pre 4ap 2p all optical PS04 t-012 [1.] ----------
# |- returning targets stims array of shape: 28 targets, 30 stims, 67 frames
#
# ---------- Calculating dF/stdF stim evoked responses (of SLM targets) [.1] ----------
#
# ---------- Calculating dF/prestimF stim evoked responses (of SLM targets) [.1] ----------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-330e4c2f919b> in <module>
#      11     expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path, do_processing=False)
#      12     expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/suite2p/alloptical-2p-1_25x-alltrials/plane0' % date
# ---> 13     aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
#
# ~/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py in run_alloptical_processing_photostim(expobj, to_suite2p, baseline_trials, plots, force_redo)
#    5374                                                stims_to_use=expobj.stim_start_frames)
#    5375         # dF/stdF
# -> 5376         expobj.stims_idx = [expobj.stim_start_frames.index(stim) for stim in expobj.stim_start_frames]
#    5377         expobj.StimSuccessRate_SLMtargets_dfstdf, expobj.traces_SLMtargets_successes_avg_dfstdf, expobj.traces_SLMtargets_failures_avg_dfstdf = \
#    5378             expobj.calculate_SLMTarget_SuccessStims(process='dF/stdF', hits_slmtargets_df=expobj.hits_SLMtargets,
#
# AttributeError: can't set attribute

# %% [markdown]
# ### post4ap

# %%
trials = ['t-018']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2021-01-09'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/PS04/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path, do_processing=False)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/suite2p/alloptical-2p-1_25x-alltrials/plane0' % date
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# |- loading /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-018/2021-01-09_t-018.pkl .. DONE
#
# Running alloptical_processing_photostim for PS04, t-018 ------------------------------
#
# -----Loading up target coordinates...
# Number of targets: 28
# spiral size: 10.0um
# pix sz x: 0.873833917058156um
# radius (in pixels): 5.24px
# radius of target exclusion zone (in pixels): 7.86px
# Number of targets (in SLM group 1):  14
# Number of targets (in SLM group 2):  14
# FIN. -----Loading up target coordinates-----
#
#  ..... plotting function \ ...
# 	 \- PLOTTING mean raw flu trace ...
# ** return elements during print_start_end_plot: None
#
#  ..... plotting function \ END
#
#  ..... plotting function \ ...
# 	 \- PLOTTING LFP stims trace ...
#
#  ..... plotting function \ ...
# 	 \- PLOTTING LFP Signal trace ...
# ** return elements during print_start_end_plot: (<Figure size 720x216 with 1 Axes>, <AxesSubplot:title={'center':'LFP trace - post 4ap 2p all optical PS04 t-018'}, xlabel='paq clock', ylabel='Voltage'>)
#
#  ..... plotting function \ END
# ** return elements during print_start_end_plot: AxesSubplot(0.0835069,0.226852;0.891493x0.615741)
#
#  ..... plotting function \ END
# re-collecting subset frames of current trial
# baseline frames:  [0, 27094]
# current trial frames:  [51481, 56449]
# \- Saving expobj saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-018/2021-01-09_t-018.pkl --
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file025_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file026_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file027_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file028_chan0.tif
# \- Saving expobj saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-018/2021-01-09_t-018.pkl --
#
# ---------- Collecting trace raw stim trace snippets of SLM targets for post 4ap 2p all optical PS04 t-018 [1.] ----------
# |- returning targets stims array of shape: 28 targets, 30 stims, 68 frames
#
# ---------- Collecting trace dFF stim trace snippets of SLM targets for post 4ap 2p all optical PS04 t-018 [1.] ----------
# |- returning targets stims array of shape: 28 targets, 30 stims, 68 frames
#
# ---------- Collecting trace raw stim trace snippets of SLM targets for post 4ap 2p all optical PS04 t-018 [1.] ----------
# |- returning targets stims array of shape: 28 targets, 30 stims, 68 frames
#
# ---------- Collecting trace dFF stim trace snippets of SLM targets for post 4ap 2p all optical PS04 t-018 [1.] ----------
# |- returning targets stims array of shape: 28 targets, 30 stims, 68 frames
#
# ---------- Collecting trace raw stim trace snippets of SLM targets for post 4ap 2p all optical PS04 t-018 [1.] ----------
# |-filter_sz active
# |- returning targets stims array of shape: 28 targets, 30 stims, 68 frames
#
# ---------- Collecting trace dFF stim trace snippets of SLM targets for post 4ap 2p all optical PS04 t-018 [1.] ----------
# |-filter_sz active
# |- returning targets stims array of shape: 28 targets, 30 stims, 68 frames
# |- calculating stim responses (all trials) - 30 stims [2.2.1]
#
# ---------- Calculating dF/stdF stim evoked responses (of SLM targets) [.1] ----------
#
# ---------- Calculating dF/prestimF stim evoked responses (of SLM targets) [.1] ----------
#
# ---------- Calculating trace dFF stim evoked responses (of SLM targets) [.1] ----------
# |- calculating stim responses (outsz) - 7 stims [2.2.1]
#
# ---------- Calculating dF/stdF stim evoked responses (of SLM targets) [.1] ----------
#
# ---------- Calculating dF/prestimF stim evoked responses (of SLM targets) [.1] ----------
#
# ---------- Calculating trace dFF stim evoked responses (of SLM targets) [.1] ----------
# |- calculating stim success rates (outsz) - 7 stims [2.2.0]
#
# ---------- Calculating dF/stdF stim success rates, and separating stims into successes and failures (of SLM targets) [1.] ----------
#
# ---------- Calculating dF/prestimF stim success rates, and separating stims into successes and failures (of SLM targets) [1.] ----------
#
# ---------- Calculating trace dFF stim success rates, and separating stims into successes and failures (of SLM targets) [1.] ----------
# |- calculating stim responses (insz) - 23 stims [2.3.1]
#
# ---------- Calculating dF/stdF stim evoked responses (of SLM targets) [.1] ----------
#
# ---------- Calculating dF/prestimF stim evoked responses (of SLM targets) [.1] ----------
#
# ---------- Calculating trace dFF stim evoked responses (of SLM targets) [.1] ----------
# |- calculating stim success rates (insz) - 23 stims [2.3.0]
#
# ---------- Calculating dF/stdF stim success rates, and separating stims into successes and failures (of SLM targets) [1.] ----------
#
# ---------- Calculating dF/prestimF stim success rates, and separating stims into successes and failures (of SLM targets) [1.] ----------
#
# ---------- Calculating trace dFF stim success rates, and separating stims into successes and failures (of SLM targets) [1.] ----------
# \- Saving expobj saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/PS04/2021-01-09_t-018/2021-01-09_t-018.pkl --
#
# FINISHED alloptical_processing_photostim for PS04, t-018 ------------------------------
