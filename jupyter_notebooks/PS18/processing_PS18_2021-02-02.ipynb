# %% [markdown]
# # Processing - PS18 - 2021-02-02

# %%
import sys; sys.path.append('/home/pshah/Documents/code/PackerLab_pycharm/')
import os
import pickle
import alloptical_utils_pj as aoutils
import alloptical_plotting_utils as aoplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import utils.funcs_pj as pj
import tifffile as tf

# %%
to_suite2p = ['t-002', 't-004', 't-005', 't-006', 't-008'] # specify all trials that were used in the suite2p runtotal_frames_stitched = 0
baseline_trials = ['t-002', 't-004'] # specify which trials to use as spont baseline
# note ^^^ this only works currently when the spont baseline trials all come first, and also back to back

# %% [markdown]
# ### pre4ap

# %%
trials = ['t-005', 't-006']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    prep = 'PS18'
    date = '2021-02-02'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/%s/%s_%s/%s_%s.pkl" % (date, prep, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/%s/suite2p/alloptical-2p-0_8x-alltrials/plane0' % (date, prep)
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-02-02, t-005" from: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-005/2021-02-02_t-005.pkl
#
#
# DONE IMPORT of PS18: t-005, pre 4ap 2p all optical, 7 cells x 4 groups; 5mW per cell; 100ms-stim multi_interleaved (prot. #3b)
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-005/2021-02-02_t-005.pkl
#
# re-collecting subset frames of current trial
# baseline frames:  [0, 23317]
# current trial frames:  [23317, 38791]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-005/2021-02-02_t-005.pkl
#
# Loading 230 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-005/2021-02-02_t-005.pkl
#
#
# searching for targeted cells...
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-005/2021-02-02_t-005.pkl
#
# Number of targeted cells found suite2p:  0
#
# Target cells found in suite2p:  []  -- 0 cells (out of 28 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-005/2021-02-02_t-005.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-005/2021-02-02_t-005_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file011_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file012_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file013_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file014_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file015_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file016_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file017_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file018_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file019_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-005/2021-02-02_t-005.pkl
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-005/2021-02-02_t-005.pkl
#
# collecting stim traces for cell # 1 out of 28
# collecting stim traces for cell # 2 out of 28
# collecting stim traces for cell # 3 out of 28
# collecting stim traces for cell # 4 out of 28
# collecting stim traces for cell # 5 out of 28
# collecting stim traces for cell # 6 out of 28
# collecting stim traces for cell # 7 out of 28
# collecting stim traces for cell # 8 out of 28
# collecting stim traces for cell # 9 out of 28
# collecting stim traces for cell # 10 out of 28
# collecting stim traces for cell # 11 out of 28
# collecting stim traces for cell # 12 out of 28
# collecting stim traces for cell # 13 out of 28
# collecting stim traces for cell # 14 out of 28
# collecting stim traces for cell # 15 out of 28
# collecting stim traces for cell # 16 out of 28
# collecting stim traces for cell # 17 out of 28
# collecting stim traces for cell # 18 out of 28
# collecting stim traces for cell # 19 out of 28
# collecting stim traces for cell # 20 out of 28
# collecting stim traces for cell # 21 out of 28
# collecting stim traces for cell # 22 out of 28
# collecting stim traces for cell # 23 out of 28
# collecting stim traces for cell # 24 out of 28
# collecting stim traces for cell # 25 out of 28
# collecting stim traces for cell # 26 out of 28
# collecting stim traces for cell # 27 out of 28
# collecting stim traces for cell # 28 out of 28
# (28, 57)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 52.0 percent hits over 100 stims
# |- Target # 1: 73.0 percent hits over 100 stims
# |- Target # 2: 85.0 percent hits over 100 stims
# |- Target # 3: 63.0 percent hits over 100 stims
# |- Target # 4: 52.0 percent hits over 100 stims
# |- Target # 5: 45.0 percent hits over 100 stims
# |- Target # 6: 69.0 percent hits over 100 stims
# |- Target # 7: 71.0 percent hits over 100 stims
# |- Target # 8: 67.0 percent hits over 100 stims
# |- Target # 9: 94.0 percent hits over 100 stims
# |- Target # 10: 99.0 percent hits over 100 stims
# |- Target # 11: 79.0 percent hits over 100 stims
# |- Target # 12: 45.0 percent hits over 100 stims
# |- Target # 13: 73.0 percent hits over 100 stims
# |- Target # 14: 60.0 percent hits over 100 stims
# |- Target # 15: 52.0 percent hits over 100 stims
# |- Target # 16: 67.0 percent hits over 100 stims
# |- Target # 17: 93.0 percent hits over 100 stims
# |- Target # 18: 67.0 percent hits over 100 stims
# |- Target # 19: 100.0 percent hits over 100 stims
# |- Target # 20: 92.0 percent hits over 100 stims
# |- Target # 21: 66.0 percent hits over 100 stims
# |- Target # 22: 77.0 percent hits over 100 stims
# |- Target # 23: 62.0 percent hits over 100 stims
# |- Target # 24: 64.0 percent hits over 100 stims
# |- Target # 25: 54.0 percent hits over 100 stims
# |- Target # 26: 86.0 percent hits over 100 stims
# |- Target # 27: 86.0 percent hits over 100 stims
#
# avg photostim. success rate is: 71.18 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-005/2021-02-02_t-005.pkl
#
#
# importing expobj for "2021-02-02, t-006" from: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-006/2021-02-02_t-006.pkl
#
#
# DONE IMPORT of PS18: t-006, pre 4ap 2p all optical, 10 cells x 4 groups; 5mW per cell; 250ms-stim multi_interleaved (prot. #3)
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-006/2021-02-02_t-006.pkl
#
# re-collecting subset frames of current trial
# baseline frames:  [0, 23317]
# current trial frames:  [38791, 54246]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-006/2021-02-02_t-006.pkl
#
# Loading 230 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-006/2021-02-02_t-006.pkl
#
#
# searching for targeted cells...
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-006/2021-02-02_t-006.pkl
#
# Number of targeted cells found suite2p:  0
#
# Target cells found in suite2p:  []  -- 0 cells (out of 28 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-006/2021-02-02_t-006.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-006/2021-02-02_t-006_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file019_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file020_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file021_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file022_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file023_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file024_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file025_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file026_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file027_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-006/2021-02-02_t-006.pkl
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-006/2021-02-02_t-006.pkl
#
# collecting stim traces for cell # 1 out of 28
# collecting stim traces for cell # 2 out of 28
# collecting stim traces for cell # 3 out of 28
# collecting stim traces for cell # 4 out of 28
# collecting stim traces for cell # 5 out of 28
# collecting stim traces for cell # 6 out of 28
# collecting stim traces for cell # 7 out of 28
# collecting stim traces for cell # 8 out of 28
# collecting stim traces for cell # 9 out of 28
# collecting stim traces for cell # 10 out of 28
# collecting stim traces for cell # 11 out of 28
# collecting stim traces for cell # 12 out of 28
# collecting stim traces for cell # 13 out of 28
# collecting stim traces for cell # 14 out of 28
# collecting stim traces for cell # 15 out of 28
# collecting stim traces for cell # 16 out of 28
# collecting stim traces for cell # 17 out of 28
# collecting stim traces for cell # 18 out of 28
# collecting stim traces for cell # 19 out of 28
# collecting stim traces for cell # 20 out of 28
# collecting stim traces for cell # 21 out of 28
# collecting stim traces for cell # 22 out of 28
# collecting stim traces for cell # 23 out of 28
# collecting stim traces for cell # 24 out of 28
# collecting stim traces for cell # 25 out of 28
# collecting stim traces for cell # 26 out of 28
# collecting stim traces for cell # 27 out of 28
# collecting stim traces for cell # 28 out of 28
# (28, 65)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 83.0 percent hits over 100 stims
# |- Target # 1: 87.0 percent hits over 100 stims
# |- Target # 2: 77.0 percent hits over 100 stims
# |- Target # 3: 62.0 percent hits over 100 stims
# |- Target # 4: 60.0 percent hits over 100 stims
# |- Target # 5: 68.0 percent hits over 100 stims
# |- Target # 6: 72.0 percent hits over 100 stims
# |- Target # 7: 56.0 percent hits over 100 stims
# |- Target # 8: 59.0 percent hits over 100 stims
# |- Target # 9: 72.0 percent hits over 100 stims
# |- Target # 10: 72.0 percent hits over 100 stims
# |- Target # 11: 64.0 percent hits over 100 stims
# |- Target # 12: 48.0 percent hits over 100 stims
# |- Target # 13: 61.0 percent hits over 100 stims
# |- Target # 14: 54.0 percent hits over 100 stims
# |- Target # 15: 65.0 percent hits over 100 stims
# |- Target # 16: 77.0 percent hits over 100 stims
# |- Target # 17: 99.0 percent hits over 100 stims
# |- Target # 18: 96.0 percent hits over 100 stims
# |- Target # 19: 100.0 percent hits over 100 stims
# |- Target # 20: 100.0 percent hits over 100 stims
# |- Target # 21: 92.0 percent hits over 100 stims
# |- Target # 22: 86.0 percent hits over 100 stims
# |- Target # 23: 85.0 percent hits over 100 stims
# |- Target # 24: 98.0 percent hits over 100 stims
# |- Target # 25: 91.0 percent hits over 100 stims
# |- Target # 26: 100.0 percent hits over 100 stims
# |- Target # 27: 100.0 percent hits over 100 stims
#
# avg photostim. success rate is: 78.0 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-006/2021-02-02_t-006.pkl

# %% [markdown]
# ### post4ap

# %%
trials = ['t-008']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    prep = 'PS18'
    date = '2021-02-02'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/%s/%s_%s/%s_%s.pkl" % (date, prep, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/%s/suite2p/alloptical-2p-0_8x-alltrials/plane0' % (date, prep)
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-02-02, t-008" from: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-008/2021-02-02_t-008.pkl
#
#
# DONE IMPORT of PS18: t-008, post 4ap 2p all optical, 10 cells x 4 groups; 5mW per cell; 250ms-stim multi_interleaved (prot. #3); 9 sz events; trial starts just after and ends mid sz
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-008/2021-02-02_t-008.pkl
#
# re-collecting subset frames of current trial
# baseline frames:  [0, 23317]
# current trial frames:  [54246, 69720]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-008/2021-02-02_t-008.pkl
#
# Loading 230 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-008/2021-02-02_t-008.pkl
#
#
# searching for targeted cells...
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-008/2021-02-02_t-008.pkl
#
# Number of targeted cells found suite2p:  0
#
# Target cells found in suite2p:  []  -- 0 cells (out of 28 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-008/2021-02-02_t-008.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-008/2021-02-02_t-008_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file027_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file028_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file029_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file030_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file031_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file032_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file033_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/suite2p/alloptical-2p-0_8x-alltrials/plane0/reg_tif/file034_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-008/2021-02-02_t-008.pkl
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-008/2021-02-02_t-008.pkl
#
# collecting stim traces for cell # 1 out of 28
# collecting stim traces for cell # 2 out of 28
# collecting stim traces for cell # 3 out of 28
# collecting stim traces for cell # 4 out of 28
# collecting stim traces for cell # 5 out of 28
# collecting stim traces for cell # 6 out of 28
# collecting stim traces for cell # 7 out of 28
# collecting stim traces for cell # 8 out of 28
# collecting stim traces for cell # 9 out of 28
# collecting stim traces for cell # 10 out of 28
# collecting stim traces for cell # 11 out of 28
# collecting stim traces for cell # 12 out of 28
# collecting stim traces for cell # 13 out of 28
# collecting stim traces for cell # 14 out of 28
# collecting stim traces for cell # 15 out of 28
# collecting stim traces for cell # 16 out of 28
# collecting stim traces for cell # 17 out of 28
# collecting stim traces for cell # 18 out of 28
# collecting stim traces for cell # 19 out of 28
# collecting stim traces for cell # 20 out of 28
# collecting stim traces for cell # 21 out of 28
# collecting stim traces for cell # 22 out of 28
# collecting stim traces for cell # 23 out of 28
# collecting stim traces for cell # 24 out of 28
# collecting stim traces for cell # 25 out of 28
# collecting stim traces for cell # 26 out of 28
# collecting stim traces for cell # 27 out of 28
# collecting stim traces for cell # 28 out of 28
# (28, 65)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 78.05 percent hits over 41 stims
# |- Target # 1: 56.1 percent hits over 41 stims
# |- Target # 2: 65.85 percent hits over 41 stims
# |- Target # 3: 73.17 percent hits over 41 stims
# |- Target # 4: 56.1 percent hits over 41 stims
# |- Target # 5: 70.73 percent hits over 41 stims
# |- Target # 6: 65.85 percent hits over 41 stims
# |- Target # 7: 60.98 percent hits over 41 stims
# |- Target # 8: 46.34 percent hits over 41 stims
# |- Target # 9: 65.85 percent hits over 41 stims
# |- Target # 10: 60.98 percent hits over 41 stims
# |- Target # 11: 51.22 percent hits over 41 stims
# |- Target # 12: 41.46 percent hits over 41 stims
# |- Target # 13: 60.98 percent hits over 41 stims
# |- Target # 14: 48.78 percent hits over 41 stims
# |- Target # 15: 60.98 percent hits over 41 stims
# |- Target # 16: 56.1 percent hits over 41 stims
# |- Target # 17: 80.49 percent hits over 41 stims
# |- Target # 18: 73.17 percent hits over 41 stims
# |- Target # 19: 87.8 percent hits over 41 stims
# |- Target # 20: 78.05 percent hits over 41 stims
# |- Target # 21: 68.29 percent hits over 41 stims
# |- Target # 22: 60.98 percent hits over 41 stims
# /home/pshah/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py:3327: UserWarning: the seizure filtering by *cells* functionality is only available for s2p defined cell targets as of now
#   warnings.warn(
# |- Target # 23: 73.17 percent hits over 41 stims
# |- Target # 24: 78.05 percent hits over 41 stims
# |- Target # 25: 68.29 percent hits over 41 stims
# |- Target # 26: 58.54 percent hits over 41 stims
# |- Target # 27: 60.98 percent hits over 41 stims
#
# avg photostim. success rate is: 64.55 pct.
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 76.27 percent hits over 59 stims
# |- Target # 1: 67.8 percent hits over 59 stims
# |- Target # 2: 67.8 percent hits over 59 stims
# |- Target # 3: 64.41 percent hits over 59 stims
# |- Target # 4: 61.02 percent hits over 59 stims
# |- Target # 5: 57.63 percent hits over 59 stims
# |- Target # 6: 49.15 percent hits over 59 stims
# |- Target # 7: 47.46 percent hits over 59 stims
# |- Target # 8: 52.54 percent hits over 59 stims
# |- Target # 9: 50.85 percent hits over 59 stims
# |- Target # 10: 47.46 percent hits over 59 stims
# |- Target # 11: 37.29 percent hits over 59 stims
# |- Target # 12: 42.37 percent hits over 59 stims
# |- Target # 13: 40.68 percent hits over 59 stims
# |- Target # 14: 57.63 percent hits over 59 stims
# |- Target # 15: 61.02 percent hits over 59 stims
# |- Target # 16: 55.93 percent hits over 59 stims
# |- Target # 17: 67.8 percent hits over 59 stims
# |- Target # 18: 59.32 percent hits over 59 stims
# |- Target # 19: 57.63 percent hits over 59 stims
# |- Target # 20: 45.76 percent hits over 59 stims
# |- Target # 21: 49.15 percent hits over 59 stims
# |- Target # 22: 50.85 percent hits over 59 stims
# |- Target # 23: 61.02 percent hits over 59 stims
# |- Target # 24: 72.88 percent hits over 59 stims
# |- Target # 25: 42.37 percent hits over 59 stims
# |- Target # 26: 47.46 percent hits over 59 stims
# |- Target # 27: 47.46 percent hits over 59 stims
#
# avg photostim. success rate is: 54.96 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-02-02/PS18/2021-02-02_t-008/2021-02-02_t-008.pkl
