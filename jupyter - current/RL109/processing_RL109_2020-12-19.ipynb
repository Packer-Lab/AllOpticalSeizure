# %% [markdown]
# # Processing - RL109 - 2020-12-19

# %%
import sys; sys.path.append('/home/pshah/Documents/code/PackerLab_pycharm/')
import os
import pickle
import alloptical_utils_pj as aoutils
import alloptical_plotting_utils as aoplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import utils.funcs_pj as pj
import tifffile as tf

# %%
to_suite2p = ['t-005', 't-006', 't-007', 't-008', 't-011', 't-012', 't-013', 't-014', 't-016',
              't-017', 't-018', 't-019', 't-020', 't-021']
baseline_trials = ['t-005', 't-006'] # specify which trials to use as spont baseline
# note ^^^ this only works currently when the spont baseline trials all come first, and also back to back

# %% [markdown]
# ### pre4ap

# %%
trials = ['t-007', 't-008', 't-011', 't-012', 't-013', 't-014']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2020-12-19'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/RL109/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0'
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2020-12-19, t-007" from: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-007/2020-12-19_t-007.pkl
#
#
# DONE IMPORT of RL109: t-007, pre 4ap 2p all optical, 10 cells x 5 groups; 5mW per cell preset: 2020-11-25_PS_250ms-stim-50hz (approach #1)
# re-collecting subset frames of current trial
# baseline frames:  [0, 38053]
# current trial frames:  [38053, 54421]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-007/2020-12-19_t-007.pkl
#
# Loading 545 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-007/2020-12-19_t-007.pkl
#
#
# searching for targeted cells...
# (350, 136)
# (255, 242)
# (243, 312)
# (261, 418)
# (237, 221)
# (341, 74)
# (482, 115)
# (410, 245)
# (191, 278)
# (301, 95)
# (262, 135)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-007/2020-12-19_t-007.pkl
#
# Number of targeted cells found suite2p:  11
#
# Target cells found in suite2p:  [28, 69, 84, 162, 165, 271, 304, 415, 416, 590, 769]  -- 11 cells (out of 50 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-007/2020-12-19_t-007.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-007/2020-12-19_t-007_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-007/2020-12-19_t-007.pkl
#
# collecting stim traces for cell # 1 out of 50
# collecting stim traces for cell # 2 out of 50
# collecting stim traces for cell # 3 out of 50
# collecting stim traces for cell # 4 out of 50
# collecting stim traces for cell # 5 out of 50
# collecting stim traces for cell # 6 out of 50
# collecting stim traces for cell # 7 out of 50
# collecting stim traces for cell # 8 out of 50
# collecting stim traces for cell # 9 out of 50
# collecting stim traces for cell # 10 out of 50
# collecting stim traces for cell # 11 out of 50
# collecting stim traces for cell # 12 out of 50
# collecting stim traces for cell # 13 out of 50
# collecting stim traces for cell # 14 out of 50
# collecting stim traces for cell # 15 out of 50
# collecting stim traces for cell # 16 out of 50
# collecting stim traces for cell # 17 out of 50
# collecting stim traces for cell # 18 out of 50
# collecting stim traces for cell # 19 out of 50
# collecting stim traces for cell # 20 out of 50
# collecting stim traces for cell # 21 out of 50
# collecting stim traces for cell # 22 out of 50
# collecting stim traces for cell # 23 out of 50
# collecting stim traces for cell # 24 out of 50
# collecting stim traces for cell # 25 out of 50
# collecting stim traces for cell # 26 out of 50
# collecting stim traces for cell # 27 out of 50
# collecting stim traces for cell # 28 out of 50
# collecting stim traces for cell # 29 out of 50
# collecting stim traces for cell # 30 out of 50
# collecting stim traces for cell # 31 out of 50
# collecting stim traces for cell # 32 out of 50
# collecting stim traces for cell # 33 out of 50
# collecting stim traces for cell # 34 out of 50
# collecting stim traces for cell # 35 out of 50
# collecting stim traces for cell # 36 out of 50
# collecting stim traces for cell # 37 out of 50
# collecting stim traces for cell # 38 out of 50
# collecting stim traces for cell # 39 out of 50
# collecting stim traces for cell # 40 out of 50
# collecting stim traces for cell # 41 out of 50
# collecting stim traces for cell # 42 out of 50
# collecting stim traces for cell # 43 out of 50
# collecting stim traces for cell # 44 out of 50
# collecting stim traces for cell # 45 out of 50
# collecting stim traces for cell # 46 out of 50
# collecting stim traces for cell # 47 out of 50
# collecting stim traces for cell # 48 out of 50
# collecting stim traces for cell # 49 out of 50
# collecting stim traces for cell # 50 out of 50
# (50, 143)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 30.0 percent hits over 100 stims
# |- Target # 1: 28.0 percent hits over 100 stims
# |- Target # 2: 40.0 percent hits over 100 stims
# |- Target # 3: 35.0 percent hits over 100 stims
# |- Target # 4: 35.0 percent hits over 100 stims
# |- Target # 5: 31.0 percent hits over 100 stims
# |- Target # 6: 28.0 percent hits over 100 stims
# |- Target # 7: 71.0 percent hits over 100 stims
# |- Target # 8: 34.0 percent hits over 100 stims
# |- Target # 9: 32.0 percent hits over 100 stims
# |- Target # 10: 90.0 percent hits over 100 stims
# |- Target # 11: 36.0 percent hits over 100 stims
# |- Target # 12: 45.0 percent hits over 100 stims
# |- Target # 13: 37.0 percent hits over 100 stims
# |- Target # 14: 45.0 percent hits over 100 stims
# |- Target # 15: 27.0 percent hits over 100 stims
# |- Target # 16: 53.0 percent hits over 100 stims
# |- Target # 17: 34.0 percent hits over 100 stims
# |- Target # 18: 37.0 percent hits over 100 stims
# |- Target # 19: 23.0 percent hits over 100 stims
# |- Target # 20: 63.0 percent hits over 100 stims
# |- Target # 21: 30.0 percent hits over 100 stims
# |- Target # 22: 31.0 percent hits over 100 stims
# |- Target # 23: 22.0 percent hits over 100 stims
# |- Target # 24: 40.0 percent hits over 100 stims
# |- Target # 25: 17.0 percent hits over 100 stims
# |- Target # 26: 25.0 percent hits over 100 stims
# |- Target # 27: 30.0 percent hits over 100 stims
# |- Target # 28: 37.0 percent hits over 100 stims
# |- Target # 29: 21.0 percent hits over 100 stims
# |- Target # 30: 31.0 percent hits over 100 stims
# |- Target # 31: 72.0 percent hits over 100 stims
# |- Target # 32: 48.0 percent hits over 100 stims
# |- Target # 33: 39.0 percent hits over 100 stims
# |- Target # 34: 29.0 percent hits over 100 stims
# |- Target # 35: 18.0 percent hits over 100 stims
# |- Target # 36: 32.0 percent hits over 100 stims
# |- Target # 37: 33.0 percent hits over 100 stims
# |- Target # 38: 36.0 percent hits over 100 stims
# |- Target # 39: 28.0 percent hits over 100 stims
# |- Target # 40: 28.0 percent hits over 100 stims
# |- Target # 41: 28.0 percent hits over 100 stims
# |- Target # 42: 26.0 percent hits over 100 stims
# |- Target # 43: 29.0 percent hits over 100 stims
# |- Target # 44: 29.0 percent hits over 100 stims
# |- Target # 45: 25.0 percent hits over 100 stims
# |- Target # 46: 26.0 percent hits over 100 stims
# |- Target # 47: 23.0 percent hits over 100 stims
# |- Target # 48: 31.0 percent hits over 100 stims
# |- Target # 49: 41.0 percent hits over 100 stims
#
# avg photostim. success rate is: 35.18 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-007/2020-12-19_t-007.pkl
#
#
# importing expobj for "2020-12-19, t-008" from: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-008/2020-12-19_t-008.pkl
#
#
# DONE IMPORT of RL109: t-008, pre 4ap 2p all optical, 10 cells x 5 groups; 5mW per cell preset: 2020-12-17_PS_10shots-interleaved (approach #2)
# re-collecting subset frames of current trial
# baseline frames:  [0, 38053]
# current trial frames:  [54421, 70789]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-008/2020-12-19_t-008.pkl
#
# Loading 545 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-008/2020-12-19_t-008.pkl
#
#
# searching for targeted cells...
# (350, 136)
# (255, 242)
# (243, 312)
# (261, 418)
# (237, 221)
# (341, 74)
# (482, 115)
# (410, 245)
# (191, 278)
# (301, 95)
# (262, 135)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-008/2020-12-19_t-008.pkl
#
# Number of targeted cells found suite2p:  11
#
# Target cells found in suite2p:  [28, 69, 84, 162, 165, 271, 304, 415, 416, 590, 769]  -- 11 cells (out of 50 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-008/2020-12-19_t-008.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-008/2020-12-19_t-008_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-008/2020-12-19_t-008.pkl
#
# collecting stim traces for cell # 1 out of 50
# collecting stim traces for cell # 2 out of 50
# collecting stim traces for cell # 3 out of 50
# collecting stim traces for cell # 4 out of 50
# collecting stim traces for cell # 5 out of 50
# collecting stim traces for cell # 6 out of 50
# collecting stim traces for cell # 7 out of 50
# collecting stim traces for cell # 8 out of 50
# collecting stim traces for cell # 9 out of 50
# collecting stim traces for cell # 10 out of 50
# collecting stim traces for cell # 11 out of 50
# collecting stim traces for cell # 12 out of 50
# collecting stim traces for cell # 13 out of 50
# collecting stim traces for cell # 14 out of 50
# collecting stim traces for cell # 15 out of 50
# collecting stim traces for cell # 16 out of 50
# collecting stim traces for cell # 17 out of 50
# collecting stim traces for cell # 18 out of 50
# collecting stim traces for cell # 19 out of 50
# collecting stim traces for cell # 20 out of 50
# collecting stim traces for cell # 21 out of 50
# collecting stim traces for cell # 22 out of 50
# collecting stim traces for cell # 23 out of 50
# collecting stim traces for cell # 24 out of 50
# collecting stim traces for cell # 25 out of 50
# collecting stim traces for cell # 26 out of 50
# collecting stim traces for cell # 27 out of 50
# collecting stim traces for cell # 28 out of 50
# collecting stim traces for cell # 29 out of 50
# collecting stim traces for cell # 30 out of 50
# collecting stim traces for cell # 31 out of 50
# collecting stim traces for cell # 32 out of 50
# collecting stim traces for cell # 33 out of 50
# collecting stim traces for cell # 34 out of 50
# collecting stim traces for cell # 35 out of 50
# collecting stim traces for cell # 36 out of 50
# collecting stim traces for cell # 37 out of 50
# collecting stim traces for cell # 38 out of 50
# collecting stim traces for cell # 39 out of 50
# collecting stim traces for cell # 40 out of 50
# collecting stim traces for cell # 41 out of 50
# collecting stim traces for cell # 42 out of 50
# collecting stim traces for cell # 43 out of 50
# collecting stim traces for cell # 44 out of 50
# collecting stim traces for cell # 45 out of 50
# collecting stim traces for cell # 46 out of 50
# collecting stim traces for cell # 47 out of 50
# collecting stim traces for cell # 48 out of 50
# collecting stim traces for cell # 49 out of 50
# collecting stim traces for cell # 50 out of 50
# (50, 143)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 34.0 percent hits over 100 stims
# |- Target # 1: 39.0 percent hits over 100 stims
# |- Target # 2: 30.0 percent hits over 100 stims
# |- Target # 3: 34.0 percent hits over 100 stims
# |- Target # 4: 38.0 percent hits over 100 stims
# |- Target # 5: 24.0 percent hits over 100 stims
# |- Target # 6: 43.0 percent hits over 100 stims
# |- Target # 7: 55.0 percent hits over 100 stims
# |- Target # 8: 39.0 percent hits over 100 stims
# |- Target # 9: 44.0 percent hits over 100 stims
# |- Target # 10: 69.0 percent hits over 100 stims
# |- Target # 11: 67.0 percent hits over 100 stims
# |- Target # 12: 52.0 percent hits over 100 stims
# |- Target # 13: 45.0 percent hits over 100 stims
# |- Target # 14: 52.0 percent hits over 100 stims
# |- Target # 15: 64.0 percent hits over 100 stims
# |- Target # 16: 45.0 percent hits over 100 stims
# |- Target # 17: 24.0 percent hits over 100 stims
# |- Target # 18: 58.0 percent hits over 100 stims
# |- Target # 19: 27.0 percent hits over 100 stims
# |- Target # 20: 36.0 percent hits over 100 stims
# |- Target # 21: 54.0 percent hits over 100 stims
# |- Target # 22: 60.0 percent hits over 100 stims
# |- Target # 23: 56.0 percent hits over 100 stims
# |- Target # 24: 37.0 percent hits over 100 stims
# |- Target # 25: 60.0 percent hits over 100 stims
# |- Target # 26: 36.0 percent hits over 100 stims
# |- Target # 27: 43.0 percent hits over 100 stims
# |- Target # 28: 34.0 percent hits over 100 stims
# |- Target # 29: 82.0 percent hits over 100 stims
# |- Target # 30: 33.0 percent hits over 100 stims
# |- Target # 31: 39.0 percent hits over 100 stims
# |- Target # 32: 52.0 percent hits over 100 stims
# |- Target # 33: 60.0 percent hits over 100 stims
# |- Target # 34: 45.0 percent hits over 100 stims
# |- Target # 35: 30.0 percent hits over 100 stims
# |- Target # 36: 39.0 percent hits over 100 stims
# |- Target # 37: 40.0 percent hits over 100 stims
# |- Target # 38: 25.0 percent hits over 100 stims
# |- Target # 39: 42.0 percent hits over 100 stims
# |- Target # 40: 34.0 percent hits over 100 stims
# |- Target # 41: 53.0 percent hits over 100 stims
# |- Target # 42: 56.0 percent hits over 100 stims
# |- Target # 43: 38.0 percent hits over 100 stims
# |- Target # 44: 37.0 percent hits over 100 stims
# |- Target # 45: 68.0 percent hits over 100 stims
# |- Target # 46: 34.0 percent hits over 100 stims
# |- Target # 47: 33.0 percent hits over 100 stims
# |- Target # 48: 35.0 percent hits over 100 stims
# |- Target # 49: 37.0 percent hits over 100 stims
#
# avg photostim. success rate is: 44.22 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-008/2020-12-19_t-008.pkl
#
#
# importing expobj for "2020-12-19, t-011" from: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-011/2020-12-19_t-011.pkl
#
#
# DONE IMPORT of RL109: t-011, pre 4ap 2p all optical, photostim: 9 cells x 4 groups; 5mW per cell; preset: 2020-11-25_PS_250ms-stim-50hz (approach #1); clumps of cells fired together - classic_naparm style
# re-collecting subset frames of current trial
# baseline frames:  [0, 38053]
# current trial frames:  [70789, 87157]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-011/2020-12-19_t-011.pkl
#
# Loading 545 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-011/2020-12-19_t-011.pkl
#
#
# searching for targeted cells...
# (255, 242)
# (267, 311)
# (189, 278)
# (276, 233)
# (256, 250)
# (192, 287)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-011/2020-12-19_t-011.pkl
#
# Number of targeted cells found suite2p:  6
#
# Target cells found in suite2p:  [69, 130, 416, 425, 618, 712]  -- 6 cells (out of 36 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-011/2020-12-19_t-011.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-011/2020-12-19_t-011_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-011/2020-12-19_t-011.pkl
#
# collecting stim traces for cell # 1 out of 36
# collecting stim traces for cell # 2 out of 36
# collecting stim traces for cell # 3 out of 36
# collecting stim traces for cell # 4 out of 36
# collecting stim traces for cell # 5 out of 36
# collecting stim traces for cell # 6 out of 36
# collecting stim traces for cell # 7 out of 36
# collecting stim traces for cell # 8 out of 36
# collecting stim traces for cell # 9 out of 36
# collecting stim traces for cell # 10 out of 36
# collecting stim traces for cell # 11 out of 36
# collecting stim traces for cell # 12 out of 36
# collecting stim traces for cell # 13 out of 36
# collecting stim traces for cell # 14 out of 36
# collecting stim traces for cell # 15 out of 36
# collecting stim traces for cell # 16 out of 36
# collecting stim traces for cell # 17 out of 36
# collecting stim traces for cell # 18 out of 36
# collecting stim traces for cell # 19 out of 36
# collecting stim traces for cell # 20 out of 36
# collecting stim traces for cell # 21 out of 36
# collecting stim traces for cell # 22 out of 36
# collecting stim traces for cell # 23 out of 36
# collecting stim traces for cell # 24 out of 36
# collecting stim traces for cell # 25 out of 36
# collecting stim traces for cell # 26 out of 36
# collecting stim traces for cell # 27 out of 36
# collecting stim traces for cell # 28 out of 36
# collecting stim traces for cell # 29 out of 36
# collecting stim traces for cell # 30 out of 36
# collecting stim traces for cell # 31 out of 36
# collecting stim traces for cell # 32 out of 36
# collecting stim traces for cell # 33 out of 36
# collecting stim traces for cell # 34 out of 36
# collecting stim traces for cell # 35 out of 36
# collecting stim traces for cell # 36 out of 36
# (36, 136)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 95.0 percent hits over 100 stims
# |- Target # 1: 99.0 percent hits over 100 stims
# |- Target # 2: 83.0 percent hits over 100 stims
# |- Target # 3: 98.0 percent hits over 100 stims
# |- Target # 4: 97.0 percent hits over 100 stims
# |- Target # 5: 95.0 percent hits over 100 stims
# |- Target # 6: 80.0 percent hits over 100 stims
# |- Target # 7: 100.0 percent hits over 100 stims
# |- Target # 8: 93.0 percent hits over 100 stims
# |- Target # 9: 97.0 percent hits over 100 stims
# |- Target # 10: 99.0 percent hits over 100 stims
# |- Target # 11: 98.0 percent hits over 100 stims
# |- Target # 12: 93.0 percent hits over 100 stims
# |- Target # 13: 100.0 percent hits over 100 stims
# |- Target # 14: 100.0 percent hits over 100 stims
# |- Target # 15: 84.0 percent hits over 100 stims
# |- Target # 16: 53.0 percent hits over 100 stims
# |- Target # 17: 100.0 percent hits over 100 stims
# |- Target # 18: 43.0 percent hits over 100 stims
# |- Target # 19: 99.0 percent hits over 100 stims
# |- Target # 20: 100.0 percent hits over 100 stims
# |- Target # 21: 100.0 percent hits over 100 stims
# |- Target # 22: 100.0 percent hits over 100 stims
# |- Target # 23: 100.0 percent hits over 100 stims
# |- Target # 24: 96.0 percent hits over 100 stims
# |- Target # 25: 100.0 percent hits over 100 stims
# |- Target # 26: 100.0 percent hits over 100 stims
# |- Target # 27: 74.0 percent hits over 100 stims
# |- Target # 28: 95.0 percent hits over 100 stims
# |- Target # 29: 76.0 percent hits over 100 stims
# |- Target # 30: 84.0 percent hits over 100 stims
# |- Target # 31: 99.0 percent hits over 100 stims
# |- Target # 32: 94.0 percent hits over 100 stims
# |- Target # 33: 74.0 percent hits over 100 stims
# |- Target # 34: 86.0 percent hits over 100 stims
# |- Target # 35: 63.0 percent hits over 100 stims
#
# avg photostim. success rate is: 90.19 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-011/2020-12-19_t-011.pkl
#
#
# importing expobj for "2020-12-19, t-012" from: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-012/2020-12-19_t-012.pkl
#
#
# DONE IMPORT of RL109: t-012, pre 4ap 2p all optical, photostim: 53 cells x 1 groups; 5mW per cell; preset: 2020-11-25_PS_250ms-stim-50hz (approach #1); same targets as t011 but fired as a large group
# re-collecting subset frames of current trial
# baseline frames:  [0, 38053]
# current trial frames:  [87157, 103525]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-012/2020-12-19_t-012.pkl
#
# Loading 545 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-012/2020-12-19_t-012.pkl
#
#
# searching for targeted cells...
# (197, 394)
# (255, 242)
# (267, 311)
# (267, 379)
# (238, 246)
# (189, 278)
# (276, 233)
# (303, 363)
# (256, 250)
# (192, 287)
# (266, 394)
# (180, 299)
# (187, 407)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-012/2020-12-19_t-012.pkl
#
# Number of targeted cells found suite2p:  13
#
# Target cells found in suite2p:  [54, 69, 130, 156, 379, 416, 425, 606, 618, 712, 714, 993, 1188]  -- 13 cells (out of 53 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-012/2020-12-19_t-012.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-012/2020-12-19_t-012_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-012/2020-12-19_t-012.pkl
#
# collecting stim traces for cell # 1 out of 53
# collecting stim traces for cell # 2 out of 53
# collecting stim traces for cell # 3 out of 53
# collecting stim traces for cell # 4 out of 53
# collecting stim traces for cell # 5 out of 53
# collecting stim traces for cell # 6 out of 53
# collecting stim traces for cell # 7 out of 53
# collecting stim traces for cell # 8 out of 53
# collecting stim traces for cell # 9 out of 53
# collecting stim traces for cell # 10 out of 53
# collecting stim traces for cell # 11 out of 53
# collecting stim traces for cell # 12 out of 53
# collecting stim traces for cell # 13 out of 53
# collecting stim traces for cell # 14 out of 53
# collecting stim traces for cell # 15 out of 53
# collecting stim traces for cell # 16 out of 53
# collecting stim traces for cell # 17 out of 53
# collecting stim traces for cell # 18 out of 53
# collecting stim traces for cell # 19 out of 53
# collecting stim traces for cell # 20 out of 53
# collecting stim traces for cell # 21 out of 53
# collecting stim traces for cell # 22 out of 53
# collecting stim traces for cell # 23 out of 53
# collecting stim traces for cell # 24 out of 53
# collecting stim traces for cell # 25 out of 53
# collecting stim traces for cell # 26 out of 53
# collecting stim traces for cell # 27 out of 53
# collecting stim traces for cell # 28 out of 53
# collecting stim traces for cell # 29 out of 53
# collecting stim traces for cell # 30 out of 53
# collecting stim traces for cell # 31 out of 53
# collecting stim traces for cell # 32 out of 53
# collecting stim traces for cell # 33 out of 53
# collecting stim traces for cell # 34 out of 53
# collecting stim traces for cell # 35 out of 53
# collecting stim traces for cell # 36 out of 53
# collecting stim traces for cell # 37 out of 53
# collecting stim traces for cell # 38 out of 53
# collecting stim traces for cell # 39 out of 53
# collecting stim traces for cell # 40 out of 53
# collecting stim traces for cell # 41 out of 53
# collecting stim traces for cell # 42 out of 53
# collecting stim traces for cell # 43 out of 53
# collecting stim traces for cell # 44 out of 53
# collecting stim traces for cell # 45 out of 53
# collecting stim traces for cell # 46 out of 53
# collecting stim traces for cell # 47 out of 53
# collecting stim traces for cell # 48 out of 53
# collecting stim traces for cell # 49 out of 53
# collecting stim traces for cell # 50 out of 53
# collecting stim traces for cell # 51 out of 53
# collecting stim traces for cell # 52 out of 53
# collecting stim traces for cell # 53 out of 53
# (53, 113)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 60.0 percent hits over 100 stims
# |- Target # 1: 95.0 percent hits over 100 stims
# |- Target # 2: 81.0 percent hits over 100 stims
# |- Target # 3: 95.0 percent hits over 100 stims
# |- Target # 4: 100.0 percent hits over 100 stims
# |- Target # 5: 72.0 percent hits over 100 stims
# |- Target # 6: 51.0 percent hits over 100 stims
# |- Target # 7: 100.0 percent hits over 100 stims
# |- Target # 8: 93.0 percent hits over 100 stims
# |- Target # 9: 74.0 percent hits over 100 stims
# |- Target # 10: 99.0 percent hits over 100 stims
# |- Target # 11: 99.0 percent hits over 100 stims
# |- Target # 12: 99.0 percent hits over 100 stims
# |- Target # 13: 99.0 percent hits over 100 stims
# |- Target # 14: 100.0 percent hits over 100 stims
# |- Target # 15: 100.0 percent hits over 100 stims
# |- Target # 16: 99.0 percent hits over 100 stims
# |- Target # 17: 61.0 percent hits over 100 stims
# |- Target # 18: 99.0 percent hits over 100 stims
# |- Target # 19: 92.0 percent hits over 100 stims
# |- Target # 20: 99.0 percent hits over 100 stims
# |- Target # 21: 100.0 percent hits over 100 stims
# |- Target # 22: 100.0 percent hits over 100 stims
# |- Target # 23: 80.0 percent hits over 100 stims
# |- Target # 24: 82.0 percent hits over 100 stims
# |- Target # 25: 89.0 percent hits over 100 stims
# |- Target # 26: 99.0 percent hits over 100 stims
# |- Target # 27: 100.0 percent hits over 100 stims
# |- Target # 28: 96.0 percent hits over 100 stims
# |- Target # 29: 100.0 percent hits over 100 stims
# |- Target # 30: 68.0 percent hits over 100 stims
# |- Target # 31: 88.0 percent hits over 100 stims
# |- Target # 32: 65.0 percent hits over 100 stims
# |- Target # 33: 96.0 percent hits over 100 stims
# |- Target # 34: 90.0 percent hits over 100 stims
# |- Target # 35: 92.0 percent hits over 100 stims
# |- Target # 36: 44.0 percent hits over 100 stims
# |- Target # 37: 32.0 percent hits over 100 stims
# |- Target # 38: 55.0 percent hits over 100 stims
# |- Target # 39: 83.0 percent hits over 100 stims
# |- Target # 40: 95.0 percent hits over 100 stims
# |- Target # 41: 90.0 percent hits over 100 stims
# |- Target # 42: 99.0 percent hits over 100 stims
# |- Target # 43: 45.0 percent hits over 100 stims
# |- Target # 44: 75.0 percent hits over 100 stims
# |- Target # 45: 87.0 percent hits over 100 stims
# |- Target # 46: 87.0 percent hits over 100 stims
# |- Target # 47: 87.0 percent hits over 100 stims
# |- Target # 48: 67.0 percent hits over 100 stims
# |- Target # 49: 71.0 percent hits over 100 stims
# |- Target # 50: 41.0 percent hits over 100 stims
# |- Target # 51: 48.0 percent hits over 100 stims
# |- Target # 52: 34.0 percent hits over 100 stims
#
# avg photostim. success rate is: 82.11 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-012/2020-12-19_t-012.pkl
#
#
# importing expobj for "2020-12-19, t-013" from: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl
#
#
# DONE IMPORT of RL109: t-013, pre 4ap 2p all optical, photostim: 9 cells x 4 groups; 5mW per cell; preset: 2020-11-25_PS_250ms-stim-50hz (approach #1); same targets and protocol as t011 but random vs ekmeans group assignment
# re-collecting subset frames of current trial
# baseline frames:  [0, 38053]
# current trial frames:  [103525, 119893]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl
#
# Loading 545 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl
#
#
# searching for targeted cells...
# (255, 242)
# (267, 311)
# (189, 278)
# (276, 233)
# (256, 250)
# (192, 287)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl
#
# Number of targeted cells found suite2p:  6
#
# Target cells found in suite2p:  [69, 130, 416, 425, 618, 712]  -- 6 cells (out of 36 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl
#
# collecting stim traces for cell # 1 out of 36
# collecting stim traces for cell # 2 out of 36
# collecting stim traces for cell # 3 out of 36
# collecting stim traces for cell # 4 out of 36
# collecting stim traces for cell # 5 out of 36
# collecting stim traces for cell # 6 out of 36
# collecting stim traces for cell # 7 out of 36
# collecting stim traces for cell # 8 out of 36
# collecting stim traces for cell # 9 out of 36
# collecting stim traces for cell # 10 out of 36
# collecting stim traces for cell # 11 out of 36
# collecting stim traces for cell # 12 out of 36
# collecting stim traces for cell # 13 out of 36
# collecting stim traces for cell # 14 out of 36
# collecting stim traces for cell # 15 out of 36
# collecting stim traces for cell # 16 out of 36
# collecting stim traces for cell # 17 out of 36
# collecting stim traces for cell # 18 out of 36
# collecting stim traces for cell # 19 out of 36
# collecting stim traces for cell # 20 out of 36
# collecting stim traces for cell # 21 out of 36
# collecting stim traces for cell # 22 out of 36
# collecting stim traces for cell # 23 out of 36
# collecting stim traces for cell # 24 out of 36
# collecting stim traces for cell # 25 out of 36
# collecting stim traces for cell # 26 out of 36
# collecting stim traces for cell # 27 out of 36
# collecting stim traces for cell # 28 out of 36
# collecting stim traces for cell # 29 out of 36
# collecting stim traces for cell # 30 out of 36
# collecting stim traces for cell # 31 out of 36
# collecting stim traces for cell # 32 out of 36
# collecting stim traces for cell # 33 out of 36
# collecting stim traces for cell # 34 out of 36
# collecting stim traces for cell # 35 out of 36
# collecting stim traces for cell # 36 out of 36
# (36, 136)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 76.0 percent hits over 100 stims
# |- Target # 1: 96.0 percent hits over 100 stims
# |- Target # 2: 83.0 percent hits over 100 stims
# |- Target # 3: 92.0 percent hits over 100 stims
# |- Target # 4: 89.0 percent hits over 100 stims
# |- Target # 5: 90.0 percent hits over 100 stims
# |- Target # 6: 73.0 percent hits over 100 stims
# |- Target # 7: 98.0 percent hits over 100 stims
# |- Target # 8: 67.0 percent hits over 100 stims
# |- Target # 9: 96.0 percent hits over 100 stims
# |- Target # 10: 97.0 percent hits over 100 stims
# |- Target # 11: 97.0 percent hits over 100 stims
# |- Target # 12: 83.0 percent hits over 100 stims
# |- Target # 13: 92.0 percent hits over 100 stims
# |- Target # 14: 94.0 percent hits over 100 stims
# |- Target # 15: 84.0 percent hits over 100 stims
# |- Target # 16: 63.0 percent hits over 100 stims
# |- Target # 17: 97.0 percent hits over 100 stims
# |- Target # 18: 41.0 percent hits over 100 stims
# |- Target # 19: 77.0 percent hits over 100 stims
# |- Target # 20: 95.0 percent hits over 100 stims
# |- Target # 21: 100.0 percent hits over 100 stims
# |- Target # 22: 82.0 percent hits over 100 stims
# |- Target # 23: 100.0 percent hits over 100 stims
# |- Target # 24: 77.0 percent hits over 100 stims
# |- Target # 25: 74.0 percent hits over 100 stims
# |- Target # 26: 87.0 percent hits over 100 stims
# |- Target # 27: 58.0 percent hits over 100 stims
# |- Target # 28: 64.0 percent hits over 100 stims
# |- Target # 29: 38.0 percent hits over 100 stims
# |- Target # 30: 46.0 percent hits over 100 stims
# |- Target # 31: 68.0 percent hits over 100 stims
# |- Target # 32: 70.0 percent hits over 100 stims
# |- Target # 33: 46.0 percent hits over 100 stims
# |- Target # 34: 58.0 percent hits over 100 stims
# |- Target # 35: 48.0 percent hits over 100 stims
#
# avg photostim. success rate is: 77.67 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-013/2020-12-19_t-013.pkl
#
#
# importing expobj for "2020-12-19, t-014" from: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-014/2020-12-19_t-014.pkl
#
#
# DONE IMPORT of RL109: t-014, pre 4ap 2p all optical, 40 cells x 1 groups; 5mW per cell; preset: 2020-11-25_PS_250ms-stim-50hz (approach #1); a different overall set of clumped cells, but targeted as one large group of 40 cells.
# re-collecting subset frames of current trial
# baseline frames:  [0, 38053]
# current trial frames:  [119893, 136261]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-014/2020-12-19_t-014.pkl
#
# Loading 545 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-014/2020-12-19_t-014.pkl
#
#
# searching for targeted cells...
# (349, 132)
# (267, 312)
# (238, 221)
# (186, 409)
# (344, 158)
# (410, 246)
# (205, 391)
# (267, 394)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-014/2020-12-19_t-014.pkl
#
# Number of targeted cells found suite2p:  8
#
# Target cells found in suite2p:  [61, 130, 165, 258, 407, 415, 621, 714]  -- 8 cells (out of 40 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-014/2020-12-19_t-014.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-014/2020-12-19_t-014_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-014/2020-12-19_t-014.pkl
#
# collecting stim traces for cell # 1 out of 40
# collecting stim traces for cell # 2 out of 40
# collecting stim traces for cell # 3 out of 40
# collecting stim traces for cell # 4 out of 40
# collecting stim traces for cell # 5 out of 40
# collecting stim traces for cell # 6 out of 40
# collecting stim traces for cell # 7 out of 40
# collecting stim traces for cell # 8 out of 40
# collecting stim traces for cell # 9 out of 40
# collecting stim traces for cell # 10 out of 40
# collecting stim traces for cell # 11 out of 40
# collecting stim traces for cell # 12 out of 40
# collecting stim traces for cell # 13 out of 40
# collecting stim traces for cell # 14 out of 40
# collecting stim traces for cell # 15 out of 40
# collecting stim traces for cell # 16 out of 40
# collecting stim traces for cell # 17 out of 40
# collecting stim traces for cell # 18 out of 40
# collecting stim traces for cell # 19 out of 40
# collecting stim traces for cell # 20 out of 40
# collecting stim traces for cell # 21 out of 40
# collecting stim traces for cell # 22 out of 40
# collecting stim traces for cell # 23 out of 40
# collecting stim traces for cell # 24 out of 40
# collecting stim traces for cell # 25 out of 40
# collecting stim traces for cell # 26 out of 40
# collecting stim traces for cell # 27 out of 40
# collecting stim traces for cell # 28 out of 40
# collecting stim traces for cell # 29 out of 40
# collecting stim traces for cell # 30 out of 40
# collecting stim traces for cell # 31 out of 40
# collecting stim traces for cell # 32 out of 40
# collecting stim traces for cell # 33 out of 40
# collecting stim traces for cell # 34 out of 40
# collecting stim traces for cell # 35 out of 40
# collecting stim traces for cell # 36 out of 40
# collecting stim traces for cell # 37 out of 40
# collecting stim traces for cell # 38 out of 40
# collecting stim traces for cell # 39 out of 40
# collecting stim traces for cell # 40 out of 40
# (40, 113)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 66.0 percent hits over 100 stims
# |- Target # 1: 67.0 percent hits over 100 stims
# |- Target # 2: 67.0 percent hits over 100 stims
# |- Target # 3: 81.0 percent hits over 100 stims
# |- Target # 4: 94.0 percent hits over 100 stims
# |- Target # 5: 64.0 percent hits over 100 stims
# |- Target # 6: 64.0 percent hits over 100 stims
# |- Target # 7: 76.0 percent hits over 100 stims
# |- Target # 8: 29.0 percent hits over 100 stims
# |- Target # 9: 47.0 percent hits over 100 stims
# |- Target # 10: 64.0 percent hits over 100 stims
# |- Target # 11: 91.0 percent hits over 100 stims
# |- Target # 12: 83.0 percent hits over 100 stims
# |- Target # 13: 99.0 percent hits over 100 stims
# |- Target # 14: 74.0 percent hits over 100 stims
# |- Target # 15: 75.0 percent hits over 100 stims
# |- Target # 16: 78.0 percent hits over 100 stims
# |- Target # 17: 88.0 percent hits over 100 stims
# |- Target # 18: 88.0 percent hits over 100 stims
# |- Target # 19: 39.0 percent hits over 100 stims
# |- Target # 20: 100.0 percent hits over 100 stims
# |- Target # 21: 99.0 percent hits over 100 stims
# |- Target # 22: 94.0 percent hits over 100 stims
# |- Target # 23: 86.0 percent hits over 100 stims
# |- Target # 24: 69.0 percent hits over 100 stims
# |- Target # 25: 98.0 percent hits over 100 stims
# |- Target # 26: 94.0 percent hits over 100 stims
# |- Target # 27: 97.0 percent hits over 100 stims
# |- Target # 28: 99.0 percent hits over 100 stims
# |- Target # 29: 37.0 percent hits over 100 stims
# |- Target # 30: 81.0 percent hits over 100 stims
# |- Target # 31: 76.0 percent hits over 100 stims
# |- Target # 32: 48.0 percent hits over 100 stims
# |- Target # 33: 64.0 percent hits over 100 stims
# |- Target # 34: 92.0 percent hits over 100 stims
# |- Target # 35: 58.0 percent hits over 100 stims
# |- Target # 36: 52.0 percent hits over 100 stims
# |- Target # 37: 66.0 percent hits over 100 stims
# |- Target # 38: 40.0 percent hits over 100 stims
# |- Target # 39: 43.0 percent hits over 100 stims
#
# avg photostim. success rate is: 73.18 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-014/2020-12-19_t-014.pkl

# %% [markdown]
# ## post4ap

# %%
trials = ['t-016', 't-017', 't-018', 't-019', 't-020', 't-021']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2020-12-19'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/RL109/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/2020-12-19/suite2p/alloptical-2p-1x-alltrials/plane0'
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2020-12-19, t-016" from: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-016/2020-12-19_t-016.pkl
#
#
# DONE IMPORT of RL109: t-016, post 4ap 2p all optical, 5 sz total, trial starts mid sz
# re-collecting subset frames of current trial
# baseline frames:  [0, 38053]
# current trial frames:  [136261, 151697]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-016/2020-12-19_t-016.pkl
#
# Loading 545 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-016/2020-12-19_t-016.pkl
#
#
# searching for targeted cells...
# (349, 132)
# (267, 312)
# (238, 221)
# (186, 409)
# (344, 158)
# (410, 246)
# (205, 391)
# (267, 394)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-016/2020-12-19_t-016.pkl
#
# Number of targeted cells found suite2p:  8
#
# Target cells found in suite2p:  [61, 130, 165, 258, 407, 415, 621, 714]  -- 8 cells (out of 40 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-016/2020-12-19_t-016.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-016/2020-12-19_t-016_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-016/2020-12-19_t-016.pkl
#
# collecting stim traces for cell # 1 out of 40
# collecting stim traces for cell # 2 out of 40
# collecting stim traces for cell # 3 out of 40
# collecting stim traces for cell # 4 out of 40
# collecting stim traces for cell # 5 out of 40
# collecting stim traces for cell # 6 out of 40
# collecting stim traces for cell # 7 out of 40
# collecting stim traces for cell # 8 out of 40
# collecting stim traces for cell # 9 out of 40
# collecting stim traces for cell # 10 out of 40
# collecting stim traces for cell # 11 out of 40
# collecting stim traces for cell # 12 out of 40
# collecting stim traces for cell # 13 out of 40
# collecting stim traces for cell # 14 out of 40
# collecting stim traces for cell # 15 out of 40
# collecting stim traces for cell # 16 out of 40
# collecting stim traces for cell # 17 out of 40
# collecting stim traces for cell # 18 out of 40
# collecting stim traces for cell # 19 out of 40
# collecting stim traces for cell # 20 out of 40
# collecting stim traces for cell # 21 out of 40
# collecting stim traces for cell # 22 out of 40
# collecting stim traces for cell # 23 out of 40
# collecting stim traces for cell # 24 out of 40
# collecting stim traces for cell # 25 out of 40
# collecting stim traces for cell # 26 out of 40
# collecting stim traces for cell # 27 out of 40
# collecting stim traces for cell # 28 out of 40
# collecting stim traces for cell # 29 out of 40
# collecting stim traces for cell # 30 out of 40
# collecting stim traces for cell # 31 out of 40
# collecting stim traces for cell # 32 out of 40
# collecting stim traces for cell # 33 out of 40
# collecting stim traces for cell # 34 out of 40
# collecting stim traces for cell # 35 out of 40
# collecting stim traces for cell # 36 out of 40
# collecting stim traces for cell # 37 out of 40
# collecting stim traces for cell # 38 out of 40
# collecting stim traces for cell # 39 out of 40
# collecting stim traces for cell # 40 out of 40
# (40, 113)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 74.29 percent hits over 35 stims
# |- Target # 1: 88.57 percent hits over 35 stims
# |- Target # 2: 60.0 percent hits over 35 stims
# |- Target # 3: 100.0 percent hits over 35 stims
# |- Target # 4: 94.29 percent hits over 35 stims
# |- Target # 5: 74.29 percent hits over 35 stims
# |- Target # 6: 88.57 percent hits over 35 stims
# |- Target # 7: 97.14 percent hits over 35 stims
# |- Target # 8: 74.29 percent hits over 35 stims
# |- Target # 9: 82.86 percent hits over 35 stims
# |- Target # 10: 77.14 percent hits over 35 stims
# |- Target # 11: 100.0 percent hits over 35 stims
# /home/pshah/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py:3316: UserWarning: the seizure filtering by *cells* functionality is only available for s2p defined cell targets as of now
#   warnings.warn(
# |- Target # 12: 94.29 percent hits over 35 stims
# |- Target # 13: 94.29 percent hits over 35 stims
# |- Target # 14: 74.29 percent hits over 35 stims
# |- Target # 15: 82.86 percent hits over 35 stims
# |- Target # 16: 57.14 percent hits over 35 stims
# |- Target # 17: 88.57 percent hits over 35 stims
# |- Target # 18: 71.43 percent hits over 35 stims
# |- Target # 19: 62.86 percent hits over 35 stims
# |- Target # 20: 97.14 percent hits over 35 stims
# |- Target # 21: 100.0 percent hits over 35 stims
# |- Target # 22: 100.0 percent hits over 35 stims
# |- Target # 23: 100.0 percent hits over 35 stims
# |- Target # 24: 100.0 percent hits over 35 stims
# |- Target # 25: 100.0 percent hits over 35 stims
# |- Target # 26: 97.14 percent hits over 35 stims
# |- Target # 27: 100.0 percent hits over 35 stims
# |- Target # 28: 100.0 percent hits over 35 stims
# |- Target # 29: 60.0 percent hits over 35 stims
# |- Target # 30: 68.57 percent hits over 35 stims
# |- Target # 31: 85.71 percent hits over 35 stims
# |- Target # 32: 65.71 percent hits over 35 stims
# |- Target # 33: 77.14 percent hits over 35 stims
# |- Target # 34: 77.14 percent hits over 35 stims
# |- Target # 35: 62.86 percent hits over 35 stims
# |- Target # 36: 80.0 percent hits over 35 stims
# |- Target # 37: 91.43 percent hits over 35 stims
# |- Target # 38: 71.43 percent hits over 35 stims
# |- Target # 39: 25.71 percent hits over 35 stims
#
# avg photostim. success rate is: 82.43 pct.
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 73.85 percent hits over 65 stims
# |- Target # 1: 80.0 percent hits over 65 stims
# |- Target # 2: 80.0 percent hits over 65 stims
# |- Target # 3: 92.31 percent hits over 65 stims
# |- Target # 4: 98.46 percent hits over 65 stims
# |- Target # 5: 73.85 percent hits over 65 stims
# |- Target # 6: 80.0 percent hits over 65 stims
# |- Target # 7: 96.92 percent hits over 65 stims
# |- Target # 8: 58.46 percent hits over 65 stims
# |- Target # 9: 81.54 percent hits over 65 stims
# |- Target # 10: 64.62 percent hits over 65 stims
# |- Target # 11: 83.08 percent hits over 65 stims
# |- Target # 12: 78.46 percent hits over 65 stims
# |- Target # 13: 78.46 percent hits over 65 stims
# |- Target # 14: 70.77 percent hits over 65 stims
# |- Target # 15: 70.77 percent hits over 65 stims
# |- Target # 16: 61.54 percent hits over 65 stims
# |- Target # 17: 75.38 percent hits over 65 stims
# |- Target # 18: 58.46 percent hits over 65 stims
# |- Target # 19: 40.0 percent hits over 65 stims
# |- Target # 20: 96.92 percent hits over 65 stims
# |- Target # 21: 92.31 percent hits over 65 stims
# |- Target # 22: 89.23 percent hits over 65 stims
# |- Target # 23: 95.38 percent hits over 65 stims
# |- Target # 24: 90.77 percent hits over 65 stims
# |- Target # 25: 80.0 percent hits over 65 stims
# |- Target # 26: 56.92 percent hits over 65 stims
# |- Target # 27: 87.69 percent hits over 65 stims
# |- Target # 28: 72.31 percent hits over 65 stims
# |- Target # 29: 46.15 percent hits over 65 stims
# |- Target # 30: 44.62 percent hits over 65 stims
# |- Target # 31: 38.46 percent hits over 65 stims
# |- Target # 32: 44.62 percent hits over 65 stims
# |- Target # 33: 38.46 percent hits over 65 stims
# |- Target # 34: 47.69 percent hits over 65 stims
# |- Target # 35: 41.54 percent hits over 65 stims
# |- Target # 36: 44.62 percent hits over 65 stims
# |- Target # 37: 40.0 percent hits over 65 stims
# |- Target # 38: 40.0 percent hits over 65 stims
# |- Target # 39: 40.0 percent hits over 65 stims
#
# avg photostim. success rate is: 68.12 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-016/2020-12-19_t-016.pkl
#
#
# importing expobj for "2020-12-19, t-017" from: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-017/2020-12-19_t-017.pkl
#
#
# DONE IMPORT of RL109: t-017, post 4ap 2p all optical, 3 sz, trial start mid sz 1
# re-collecting subset frames of current trial
# baseline frames:  [0, 38053]
# current trial frames:  [151697, 169217]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-017/2020-12-19_t-017.pkl
#
# Loading 545 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-017/2020-12-19_t-017.pkl
#
#
# searching for targeted cells...
# (349, 132)
# (267, 312)
# (238, 221)
# (186, 409)
# (344, 158)
# (410, 246)
# (205, 391)
# (267, 394)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-017/2020-12-19_t-017.pkl
#
# Number of targeted cells found suite2p:  8
#
# Target cells found in suite2p:  [61, 130, 165, 258, 407, 415, 621, 714]  -- 8 cells (out of 40 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-017/2020-12-19_t-017.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-017/2020-12-19_t-017_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-017/2020-12-19_t-017.pkl
#
# collecting stim traces for cell # 1 out of 40
# collecting stim traces for cell # 2 out of 40
# collecting stim traces for cell # 3 out of 40
# collecting stim traces for cell # 4 out of 40
# collecting stim traces for cell # 5 out of 40
# collecting stim traces for cell # 6 out of 40
# collecting stim traces for cell # 7 out of 40
# collecting stim traces for cell # 8 out of 40
# collecting stim traces for cell # 9 out of 40
# collecting stim traces for cell # 10 out of 40
# collecting stim traces for cell # 11 out of 40
# collecting stim traces for cell # 12 out of 40
# collecting stim traces for cell # 13 out of 40
# collecting stim traces for cell # 14 out of 40
# collecting stim traces for cell # 15 out of 40
# collecting stim traces for cell # 16 out of 40
# collecting stim traces for cell # 17 out of 40
# collecting stim traces for cell # 18 out of 40
# collecting stim traces for cell # 19 out of 40
# collecting stim traces for cell # 20 out of 40
# collecting stim traces for cell # 21 out of 40
# collecting stim traces for cell # 22 out of 40
# collecting stim traces for cell # 23 out of 40
# collecting stim traces for cell # 24 out of 40
# collecting stim traces for cell # 25 out of 40
# collecting stim traces for cell # 26 out of 40
# collecting stim traces for cell # 27 out of 40
# collecting stim traces for cell # 28 out of 40
# collecting stim traces for cell # 29 out of 40
# collecting stim traces for cell # 30 out of 40
# collecting stim traces for cell # 31 out of 40
# collecting stim traces for cell # 32 out of 40
# collecting stim traces for cell # 33 out of 40
# collecting stim traces for cell # 34 out of 40
# collecting stim traces for cell # 35 out of 40
# collecting stim traces for cell # 36 out of 40
# collecting stim traces for cell # 37 out of 40
# collecting stim traces for cell # 38 out of 40
# collecting stim traces for cell # 39 out of 40
# collecting stim traces for cell # 40 out of 40
# (40, 113)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 40.26 percent hits over 77 stims
# |- Target # 1: 50.65 percent hits over 77 stims
# /home/pshah/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py:3316: UserWarning: the seizure filtering by *cells* functionality is only available for s2p defined cell targets as of now
#   warnings.warn(
# |- Target # 2: 42.86 percent hits over 77 stims
# |- Target # 3: 55.84 percent hits over 77 stims
# |- Target # 4: 66.23 percent hits over 77 stims
# |- Target # 5: 46.75 percent hits over 77 stims
# |- Target # 6: 57.14 percent hits over 77 stims
# |- Target # 7: 75.32 percent hits over 77 stims
# |- Target # 8: 61.04 percent hits over 77 stims
# |- Target # 9: 54.55 percent hits over 77 stims
# |- Target # 10: 40.26 percent hits over 77 stims
# |- Target # 11: 64.94 percent hits over 77 stims
# |- Target # 12: 63.64 percent hits over 77 stims
# |- Target # 13: 76.62 percent hits over 77 stims
# |- Target # 14: 64.94 percent hits over 77 stims
# |- Target # 15: 64.94 percent hits over 77 stims
# |- Target # 16: 59.74 percent hits over 77 stims
# |- Target # 17: 67.53 percent hits over 77 stims
# |- Target # 18: 59.74 percent hits over 77 stims
# |- Target # 19: 64.94 percent hits over 77 stims
# |- Target # 20: 71.43 percent hits over 77 stims
# |- Target # 21: 77.92 percent hits over 77 stims
# |- Target # 22: 79.22 percent hits over 77 stims
# |- Target # 23: 81.82 percent hits over 77 stims
# |- Target # 24: 81.82 percent hits over 77 stims
# |- Target # 25: 74.03 percent hits over 77 stims
# |- Target # 26: 64.94 percent hits over 77 stims
# |- Target # 27: 76.62 percent hits over 77 stims
# |- Target # 28: 76.62 percent hits over 77 stims
# |- Target # 29: 37.66 percent hits over 77 stims
# |- Target # 30: 35.06 percent hits over 77 stims
# |- Target # 31: 18.18 percent hits over 77 stims
# |- Target # 32: 36.36 percent hits over 77 stims
# |- Target # 33: 32.47 percent hits over 77 stims
# |- Target # 34: 54.55 percent hits over 77 stims
# |- Target # 35: 38.96 percent hits over 77 stims
# |- Target # 36: 38.96 percent hits over 77 stims
# |- Target # 37: 55.84 percent hits over 77 stims
# |- Target # 38: 36.36 percent hits over 77 stims
# |- Target # 39: 31.17 percent hits over 77 stims
#
# avg photostim. success rate is: 56.95 pct.
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 52.17 percent hits over 23 stims
# |- Target # 1: 69.57 percent hits over 23 stims
# |- Target # 2: 56.52 percent hits over 23 stims
# |- Target # 3: 78.26 percent hits over 23 stims
# |- Target # 4: 73.91 percent hits over 23 stims
# |- Target # 5: 52.17 percent hits over 23 stims
# |- Target # 6: 78.26 percent hits over 23 stims
# |- Target # 7: 95.65 percent hits over 23 stims
# |- Target # 8: 47.83 percent hits over 23 stims
# |- Target # 9: 65.22 percent hits over 23 stims
# |- Target # 10: 60.87 percent hits over 23 stims
# |- Target # 11: 82.61 percent hits over 23 stims
# |- Target # 12: 82.61 percent hits over 23 stims
# |- Target # 13: 65.22 percent hits over 23 stims
# |- Target # 14: 69.57 percent hits over 23 stims
# |- Target # 15: 78.26 percent hits over 23 stims
# |- Target # 16: 43.48 percent hits over 23 stims
# |- Target # 17: 65.22 percent hits over 23 stims
# |- Target # 18: 56.52 percent hits over 23 stims
# |- Target # 19: 52.17 percent hits over 23 stims
# |- Target # 20: 82.61 percent hits over 23 stims
# |- Target # 21: 86.96 percent hits over 23 stims
# |- Target # 22: 86.96 percent hits over 23 stims
# |- Target # 23: 95.65 percent hits over 23 stims
# |- Target # 24: 86.96 percent hits over 23 stims
# |- Target # 25: 69.57 percent hits over 23 stims
# |- Target # 26: 47.83 percent hits over 23 stims
# |- Target # 27: 65.22 percent hits over 23 stims
# |- Target # 28: 73.91 percent hits over 23 stims
# |- Target # 29: 21.74 percent hits over 23 stims
# |- Target # 30: 30.43 percent hits over 23 stims
# |- Target # 31: 30.43 percent hits over 23 stims
# |- Target # 32: 30.43 percent hits over 23 stims
# |- Target # 33: 17.39 percent hits over 23 stims
# |- Target # 34: 30.43 percent hits over 23 stims
# |- Target # 35: 30.43 percent hits over 23 stims
# |- Target # 36: 39.13 percent hits over 23 stims
# |- Target # 37: 39.13 percent hits over 23 stims
# |- Target # 38: 26.09 percent hits over 23 stims
# |- Target # 39: 30.43 percent hits over 23 stims
#
# avg photostim. success rate is: 58.7 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-017/2020-12-19_t-017.pkl
#
#
# importing expobj for "2020-12-19, t-018" from: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-018/2020-12-19_t-018.pkl
#
#
# DONE IMPORT of RL109: t-018, post 4ap 2p all optical, 2 sz within photostim, 2nd one possible with CSD + 1 sz at the end with CSD
# re-collecting subset frames of current trial
# baseline frames:  [0, 38053]
# current trial frames:  [169217, 196001]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-018/2020-12-19_t-018.pkl
#
# Loading 545 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-018/2020-12-19_t-018.pkl
#
#
# searching for targeted cells...
# (255, 242)
# (267, 311)
# (189, 278)
# (276, 233)
# (256, 250)
# (192, 287)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-018/2020-12-19_t-018.pkl
#
# Number of targeted cells found suite2p:  6
#
# Target cells found in suite2p:  [69, 130, 416, 425, 618, 712]  -- 6 cells (out of 36 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-018/2020-12-19_t-018.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-018/2020-12-19_t-018_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-018/2020-12-19_t-018.pkl
#
# collecting stim traces for cell # 1 out of 36
# collecting stim traces for cell # 2 out of 36
# collecting stim traces for cell # 3 out of 36
# collecting stim traces for cell # 4 out of 36
# collecting stim traces for cell # 5 out of 36
# collecting stim traces for cell # 6 out of 36
# collecting stim traces for cell # 7 out of 36
# collecting stim traces for cell # 8 out of 36
# collecting stim traces for cell # 9 out of 36
# collecting stim traces for cell # 10 out of 36
# collecting stim traces for cell # 11 out of 36
# collecting stim traces for cell # 12 out of 36
# collecting stim traces for cell # 13 out of 36
# collecting stim traces for cell # 14 out of 36
# collecting stim traces for cell # 15 out of 36
# collecting stim traces for cell # 16 out of 36
# collecting stim traces for cell # 17 out of 36
# collecting stim traces for cell # 18 out of 36
# collecting stim traces for cell # 19 out of 36
# collecting stim traces for cell # 20 out of 36
# collecting stim traces for cell # 21 out of 36
# collecting stim traces for cell # 22 out of 36
# collecting stim traces for cell # 23 out of 36
# collecting stim traces for cell # 24 out of 36
# collecting stim traces for cell # 25 out of 36
# collecting stim traces for cell # 26 out of 36
# collecting stim traces for cell # 27 out of 36
# collecting stim traces for cell # 28 out of 36
# collecting stim traces for cell # 29 out of 36
# collecting stim traces for cell # 30 out of 36
# collecting stim traces for cell # 31 out of 36
# collecting stim traces for cell # 32 out of 36
# collecting stim traces for cell # 33 out of 36
# collecting stim traces for cell # 34 out of 36
# collecting stim traces for cell # 35 out of 36
# collecting stim traces for cell # 36 out of 36
# (36, 136)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 62.34 percent hits over 77 stims
# |- Target # 1: 76.62 percent hits over 77 stims
# |- Target # 2: 63.64 percent hits over 77 stims
# |- Target # 3: 90.91 percent hits over 77 stims
# /home/pshah/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py:3316: UserWarning: the seizure filtering by *cells* functionality is only available for s2p defined cell targets as of now
#   warnings.warn(
# |- Target # 4: 64.94 percent hits over 77 stims
# |- Target # 5: 84.42 percent hits over 77 stims
# |- Target # 6: 64.94 percent hits over 77 stims
# |- Target # 7: 96.1 percent hits over 77 stims
# |- Target # 8: 81.82 percent hits over 77 stims
# |- Target # 9: 77.92 percent hits over 77 stims
# |- Target # 10: 80.52 percent hits over 77 stims
# |- Target # 11: 75.32 percent hits over 77 stims
# |- Target # 12: 92.21 percent hits over 77 stims
# |- Target # 13: 96.1 percent hits over 77 stims
# |- Target # 14: 85.71 percent hits over 77 stims
# |- Target # 15: 79.22 percent hits over 77 stims
# |- Target # 16: 48.05 percent hits over 77 stims
# |- Target # 17: 81.82 percent hits over 77 stims
# |- Target # 18: 42.86 percent hits over 77 stims
# |- Target # 19: 48.05 percent hits over 77 stims
# |- Target # 20: 68.83 percent hits over 77 stims
# |- Target # 21: 90.91 percent hits over 77 stims
# |- Target # 22: 63.64 percent hits over 77 stims
# |- Target # 23: 79.22 percent hits over 77 stims
# |- Target # 24: 32.47 percent hits over 77 stims
# |- Target # 25: 66.23 percent hits over 77 stims
# |- Target # 26: 59.74 percent hits over 77 stims
# |- Target # 27: 42.86 percent hits over 77 stims
# |- Target # 28: 23.38 percent hits over 77 stims
# |- Target # 29: 20.78 percent hits over 77 stims
# |- Target # 30: 20.78 percent hits over 77 stims
# |- Target # 31: 58.44 percent hits over 77 stims
# |- Target # 32: 38.96 percent hits over 77 stims
# |- Target # 33: 32.47 percent hits over 77 stims
# |- Target # 34: 38.96 percent hits over 77 stims
# |- Target # 35: 32.47 percent hits over 77 stims
#
# avg photostim. success rate is: 62.88 pct.
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 34.78 percent hits over 23 stims
# |- Target # 1: 43.48 percent hits over 23 stims
# |- Target # 2: 34.78 percent hits over 23 stims
# |- Target # 3: 39.13 percent hits over 23 stims
# |- Target # 4: 26.09 percent hits over 23 stims
# |- Target # 5: 47.83 percent hits over 23 stims
# |- Target # 6: 65.22 percent hits over 23 stims
# |- Target # 7: 65.22 percent hits over 23 stims
# |- Target # 8: 52.17 percent hits over 23 stims
# |- Target # 9: 30.43 percent hits over 23 stims
# |- Target # 10: 47.83 percent hits over 23 stims
# |- Target # 11: 30.43 percent hits over 23 stims
# |- Target # 12: 52.17 percent hits over 23 stims
# |- Target # 13: 47.83 percent hits over 23 stims
# |- Target # 14: 34.78 percent hits over 23 stims
# |- Target # 15: 52.17 percent hits over 23 stims
# |- Target # 16: 34.78 percent hits over 23 stims
# |- Target # 17: 43.48 percent hits over 23 stims
# |- Target # 18: 47.83 percent hits over 23 stims
# |- Target # 19: 39.13 percent hits over 23 stims
# |- Target # 20: 43.48 percent hits over 23 stims
# |- Target # 21: 47.83 percent hits over 23 stims
# |- Target # 22: 43.48 percent hits over 23 stims
# |- Target # 23: 43.48 percent hits over 23 stims
# |- Target # 24: 56.52 percent hits over 23 stims
# |- Target # 25: 47.83 percent hits over 23 stims
# |- Target # 26: 39.13 percent hits over 23 stims
# |- Target # 27: 52.17 percent hits over 23 stims
# |- Target # 28: 43.48 percent hits over 23 stims
# |- Target # 29: 56.52 percent hits over 23 stims
# |- Target # 30: 56.52 percent hits over 23 stims
# |- Target # 31: 47.83 percent hits over 23 stims
# |- Target # 32: 43.48 percent hits over 23 stims
# |- Target # 33: 60.87 percent hits over 23 stims
# |- Target # 34: 56.52 percent hits over 23 stims
# |- Target # 35: 43.48 percent hits over 23 stims
#
# avg photostim. success rate is: 45.89 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-018/2020-12-19_t-018.pkl
#
#
# importing expobj for "2020-12-19, t-019" from: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-019/2020-12-19_t-019.pkl
#
#
# DONE IMPORT of RL109: t-019, post 4ap 2p all optical, no sz
# re-collecting subset frames of current trial
# baseline frames:  [0, 38053]
# current trial frames:  [196001, 212369]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-019/2020-12-19_t-019.pkl
#
# Loading 545 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-019/2020-12-19_t-019.pkl
#
#
# searching for targeted cells...
# (349, 132)
# (267, 312)
# (238, 221)
# (330, 77)
# (186, 409)
# (483, 115)
# (460, 130)
# (238, 246)
# (344, 158)
# (410, 246)
# (300, 95)
# (178, 294)
# (205, 391)
# (188, 285)
# (267, 394)
# (392, 136)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-019/2020-12-19_t-019.pkl
#
# Number of targeted cells found suite2p:  16
#
# Target cells found in suite2p:  [61, 130, 165, 190, 258, 304, 352, 379, 407, 415, 590, 599, 621, 712, 714, 795]  -- 16 cells (out of 58 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-019/2020-12-19_t-019.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-019/2020-12-19_t-019_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-019/2020-12-19_t-019.pkl
#
# collecting stim traces for cell # 1 out of 58
# collecting stim traces for cell # 2 out of 58
# collecting stim traces for cell # 3 out of 58
# collecting stim traces for cell # 4 out of 58
# collecting stim traces for cell # 5 out of 58
# collecting stim traces for cell # 6 out of 58
# collecting stim traces for cell # 7 out of 58
# collecting stim traces for cell # 8 out of 58
# collecting stim traces for cell # 9 out of 58
# collecting stim traces for cell # 10 out of 58
# collecting stim traces for cell # 11 out of 58
# collecting stim traces for cell # 12 out of 58
# collecting stim traces for cell # 13 out of 58
# collecting stim traces for cell # 14 out of 58
# collecting stim traces for cell # 15 out of 58
# collecting stim traces for cell # 16 out of 58
# collecting stim traces for cell # 17 out of 58
# collecting stim traces for cell # 18 out of 58
# collecting stim traces for cell # 19 out of 58
# collecting stim traces for cell # 20 out of 58
# collecting stim traces for cell # 21 out of 58
# collecting stim traces for cell # 22 out of 58
# collecting stim traces for cell # 23 out of 58
# collecting stim traces for cell # 24 out of 58
# collecting stim traces for cell # 25 out of 58
# collecting stim traces for cell # 26 out of 58
# collecting stim traces for cell # 27 out of 58
# collecting stim traces for cell # 28 out of 58
# collecting stim traces for cell # 29 out of 58
# collecting stim traces for cell # 30 out of 58
# collecting stim traces for cell # 31 out of 58
# collecting stim traces for cell # 32 out of 58
# collecting stim traces for cell # 33 out of 58
# collecting stim traces for cell # 34 out of 58
# collecting stim traces for cell # 35 out of 58
# collecting stim traces for cell # 36 out of 58
# collecting stim traces for cell # 37 out of 58
# collecting stim traces for cell # 38 out of 58
# collecting stim traces for cell # 39 out of 58
# collecting stim traces for cell # 40 out of 58
# collecting stim traces for cell # 41 out of 58
# collecting stim traces for cell # 42 out of 58
# collecting stim traces for cell # 43 out of 58
# collecting stim traces for cell # 44 out of 58
# collecting stim traces for cell # 45 out of 58
# collecting stim traces for cell # 46 out of 58
# collecting stim traces for cell # 47 out of 58
# collecting stim traces for cell # 48 out of 58
# collecting stim traces for cell # 49 out of 58
# collecting stim traces for cell # 50 out of 58
# collecting stim traces for cell # 51 out of 58
# collecting stim traces for cell # 52 out of 58
# collecting stim traces for cell # 53 out of 58
# collecting stim traces for cell # 54 out of 58
# collecting stim traces for cell # 55 out of 58
# collecting stim traces for cell # 56 out of 58
# collecting stim traces for cell # 57 out of 58
# collecting stim traces for cell # 58 out of 58
# (58, 121)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 39.0 percent hits over 100 stims
# |- Target # 1: 30.0 percent hits over 100 stims
# |- Target # 2: 41.0 percent hits over 100 stims
# |- Target # 3: 49.0 percent hits over 100 stims
# |- Target # 4: 94.0 percent hits over 100 stims
# |- Target # 5: 74.0 percent hits over 100 stims
# |- Target # 6: 73.0 percent hits over 100 stims
# |- Target # 7: 74.0 percent hits over 100 stims
# |- Target # 8: 62.0 percent hits over 100 stims
# |- Target # 9: 56.0 percent hits over 100 stims
# |- Target # 10: 84.0 percent hits over 100 stims
# |- Target # 11: 78.0 percent hits over 100 stims
# |- Target # 12: 72.0 percent hits over 100 stims
# |- Target # 13: 70.0 percent hits over 100 stims
# |- Target # 14: 73.0 percent hits over 100 stims
# |- Target # 15: 78.0 percent hits over 100 stims
# |- Target # 16: 75.0 percent hits over 100 stims
# |- Target # 17: 71.0 percent hits over 100 stims
# |- Target # 18: 67.0 percent hits over 100 stims
# |- Target # 19: 35.0 percent hits over 100 stims
# |- Target # 20: 55.0 percent hits over 100 stims
# |- Target # 21: 52.0 percent hits over 100 stims
# |- Target # 22: 49.0 percent hits over 100 stims
# |- Target # 23: 54.0 percent hits over 100 stims
# |- Target # 24: 86.0 percent hits over 100 stims
# |- Target # 25: 78.0 percent hits over 100 stims
# |- Target # 26: 86.0 percent hits over 100 stims
# |- Target # 27: 77.0 percent hits over 100 stims
# |- Target # 28: 86.0 percent hits over 100 stims
# |- Target # 29: 74.0 percent hits over 100 stims
# |- Target # 30: 86.0 percent hits over 100 stims
# |- Target # 31: 77.0 percent hits over 100 stims
# |- Target # 32: 74.0 percent hits over 100 stims
# |- Target # 33: 62.0 percent hits over 100 stims
# |- Target # 34: 94.0 percent hits over 100 stims
# |- Target # 35: 98.0 percent hits over 100 stims
# |- Target # 36: 96.0 percent hits over 100 stims
# |- Target # 37: 98.0 percent hits over 100 stims
# |- Target # 38: 98.0 percent hits over 100 stims
# |- Target # 39: 80.0 percent hits over 100 stims
# |- Target # 40: 60.0 percent hits over 100 stims
# |- Target # 41: 71.0 percent hits over 100 stims
# |- Target # 42: 100.0 percent hits over 100 stims
# |- Target # 43: 99.0 percent hits over 100 stims
# |- Target # 44: 98.0 percent hits over 100 stims
# |- Target # 45: 100.0 percent hits over 100 stims
# |- Target # 46: 26.0 percent hits over 100 stims
# |- Target # 47: 42.0 percent hits over 100 stims
# |- Target # 48: 42.0 percent hits over 100 stims
# |- Target # 49: 40.0 percent hits over 100 stims
# |- Target # 50: 42.0 percent hits over 100 stims
# |- Target # 51: 42.0 percent hits over 100 stims
# |- Target # 52: 60.0 percent hits over 100 stims
# |- Target # 53: 35.0 percent hits over 100 stims
# |- Target # 54: 29.0 percent hits over 100 stims
# |- Target # 55: 64.0 percent hits over 100 stims
# |- Target # 56: 32.0 percent hits over 100 stims
# |- Target # 57: 25.0 percent hits over 100 stims
#
# avg photostim. success rate is: 66.59 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-019/2020-12-19_t-019.pkl
#
#
# importing expobj for "2020-12-19, t-020" from: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
#
#
# DONE IMPORT of RL109: t-020, post 4ap 2p all optical, 4 sz, trial ends mid sz
# re-collecting subset frames of current trial
# baseline frames:  [0, 38053]
# current trial frames:  [212369, 232384]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
#
# Loading 545 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
#
#
# searching for targeted cells...
# (350, 136)
# (255, 242)
# (243, 312)
# (261, 418)
# (237, 221)
# (341, 74)
# (482, 115)
# (410, 245)
# (191, 278)
# (301, 95)
# (262, 135)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
#
# Number of targeted cells found suite2p:  11
#
# Target cells found in suite2p:  [28, 69, 84, 162, 165, 271, 304, 415, 416, 590, 769]  -- 11 cells (out of 50 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
#
# collecting stim traces for cell # 1 out of 50
# collecting stim traces for cell # 2 out of 50
# collecting stim traces for cell # 3 out of 50
# collecting stim traces for cell # 4 out of 50
# collecting stim traces for cell # 5 out of 50
# collecting stim traces for cell # 6 out of 50
# collecting stim traces for cell # 7 out of 50
# collecting stim traces for cell # 8 out of 50
# collecting stim traces for cell # 9 out of 50
# collecting stim traces for cell # 10 out of 50
# collecting stim traces for cell # 11 out of 50
# collecting stim traces for cell # 12 out of 50
# collecting stim traces for cell # 13 out of 50
# collecting stim traces for cell # 14 out of 50
# collecting stim traces for cell # 15 out of 50
# collecting stim traces for cell # 16 out of 50
# collecting stim traces for cell # 17 out of 50
# collecting stim traces for cell # 18 out of 50
# collecting stim traces for cell # 19 out of 50
# collecting stim traces for cell # 20 out of 50
# collecting stim traces for cell # 21 out of 50
# collecting stim traces for cell # 22 out of 50
# collecting stim traces for cell # 23 out of 50
# collecting stim traces for cell # 24 out of 50
# collecting stim traces for cell # 25 out of 50
# collecting stim traces for cell # 26 out of 50
# collecting stim traces for cell # 27 out of 50
# collecting stim traces for cell # 28 out of 50
# collecting stim traces for cell # 29 out of 50
# collecting stim traces for cell # 30 out of 50
# collecting stim traces for cell # 31 out of 50
# collecting stim traces for cell # 32 out of 50
# collecting stim traces for cell # 33 out of 50
# collecting stim traces for cell # 34 out of 50
# collecting stim traces for cell # 35 out of 50
# collecting stim traces for cell # 36 out of 50
# collecting stim traces for cell # 37 out of 50
# collecting stim traces for cell # 38 out of 50
# collecting stim traces for cell # 39 out of 50
# collecting stim traces for cell # 40 out of 50
# collecting stim traces for cell # 41 out of 50
# collecting stim traces for cell # 42 out of 50
# collecting stim traces for cell # 43 out of 50
# collecting stim traces for cell # 44 out of 50
# collecting stim traces for cell # 45 out of 50
# collecting stim traces for cell # 46 out of 50
# collecting stim traces for cell # 47 out of 50
# collecting stim traces for cell # 48 out of 50
# collecting stim traces for cell # 49 out of 50
# collecting stim traces for cell # 50 out of 50
# (50, 143)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 47.83 percent hits over 23 stims
# |- Target # 1: 47.83 percent hits over 23 stims
# |- Target # 2: 60.87 percent hits over 23 stims
# |- Target # 3: 60.87 percent hits over 23 stims
# |- Target # 4: 30.43 percent hits over 23 stims
# |- Target # 5: 26.09 percent hits over 23 stims
# |- Target # 6: 56.52 percent hits over 23 stims
# |- Target # 7: 78.26 percent hits over 23 stims
# |- Target # 8: 60.87 percent hits over 23 stims
# |- Target # 9: 43.48 percent hits over 23 stims
# |- Target # 10: 91.3 percent hits over 23 stims
# |- Target # 11: 60.87 percent hits over 23 stims
# |- Target # 12: 47.83 percent hits over 23 stims
# |- Target # 13: 65.22 percent hits over 23 stims
# |- Target # 14: 60.87 percent hits over 23 stims
# |- Target # 15: 69.57 percent hits over 23 stims
# |- Target # 16: 65.22 percent hits over 23 stims
# |- Target # 17: 47.83 percent hits over 23 stims
# |- Target # 18: 56.52 percent hits over 23 stims
# |- Target # 19: 21.74 percent hits over 23 stims
# |- Target # 20: 39.13 percent hits over 23 stims
# |- Target # 21: 26.09 percent hits over 23 stims
# |- Target # 22: 39.13 percent hits over 23 stims
# |- Target # 23: 17.39 percent hits over 23 stims
# |- Target # 24: 21.74 percent hits over 23 stims
# |- Target # 25: 39.13 percent hits over 23 stims
# |- Target # 26: 21.74 percent hits over 23 stims
# |- Target # 27: 39.13 percent hits over 23 stims
# |- Target # 28: 30.43 percent hits over 23 stims
# |- Target # 29: 56.52 percent hits over 23 stims
# |- Target # 30: 26.09 percent hits over 23 stims
# |- Target # 31: 52.17 percent hits over 23 stims
# |- Target # 32: 47.83 percent hits over 23 stims
# |- Target # 33: 47.83 percent hits over 23 stims
# |- Target # 34: 65.22 percent hits over 23 stims
# |- Target # 35: 26.09 percent hits over 23 stims
# |- Target # 36: 43.48 percent hits over 23 stims
# |- Target # 37: 17.39 percent hits over 23 stims
# |- Target # 38: 26.09 percent hits over 23 stims
# |- Target # 39: 26.09 percent hits over 23 stims
# |- Target # 40: 26.09 percent hits over 23 stims
# |- Target # 41: 26.09 percent hits over 23 stims
# |- Target # 42: 34.78 percent hits over 23 stims
# |- Target # 43: 34.78 percent hits over 23 stims
# |- Target # 44: 34.78 percent hits over 23 stims
# |- Target # 45: 26.09 percent hits over 23 stims
# |- Target # 46: 13.04 percent hits over 23 stims
# |- Target # 47: 17.39 percent hits over 23 stims
# |- Target # 48: 21.74 percent hits over 23 stims
# |- Target # 49: 17.39 percent hits over 23 stims
#
# avg photostim. success rate is: 41.22 pct.
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 45.45 percent hits over 77 stims
# |- Target # 1: 40.26 percent hits over 77 stims
# |- Target # 2: 40.26 percent hits over 77 stims
# |- Target # 3: 41.56 percent hits over 77 stims
# |- Target # 4: 35.06 percent hits over 77 stims
# |- Target # 5: 45.45 percent hits over 77 stims
# |- Target # 6: 46.75 percent hits over 77 stims
# |- Target # 7: 42.86 percent hits over 77 stims
# |- Target # 8: 40.26 percent hits over 77 stims
# |- Target # 9: 44.16 percent hits over 77 stims
# /home/pshah/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py:3316: UserWarning: the seizure filtering by *cells* functionality is only available for s2p defined cell targets as of now
#   warnings.warn(
# |- Target # 10: 46.75 percent hits over 77 stims
# |- Target # 11: 40.26 percent hits over 77 stims
# |- Target # 12: 38.96 percent hits over 77 stims
# |- Target # 13: 48.05 percent hits over 77 stims
# |- Target # 14: 32.47 percent hits over 77 stims
# |- Target # 15: 36.36 percent hits over 77 stims
# |- Target # 16: 33.77 percent hits over 77 stims
# |- Target # 17: 40.26 percent hits over 77 stims
# |- Target # 18: 29.87 percent hits over 77 stims
# |- Target # 19: 32.47 percent hits over 77 stims
# |- Target # 20: 25.97 percent hits over 77 stims
# |- Target # 21: 27.27 percent hits over 77 stims
# |- Target # 22: 37.66 percent hits over 77 stims
# |- Target # 23: 28.57 percent hits over 77 stims
# |- Target # 24: 28.57 percent hits over 77 stims
# |- Target # 25: 32.47 percent hits over 77 stims
# |- Target # 26: 27.27 percent hits over 77 stims
# |- Target # 27: 20.78 percent hits over 77 stims
# |- Target # 28: 31.17 percent hits over 77 stims
# |- Target # 29: 38.96 percent hits over 77 stims
# |- Target # 30: 28.57 percent hits over 77 stims
# |- Target # 31: 33.77 percent hits over 77 stims
# |- Target # 32: 37.66 percent hits over 77 stims
# |- Target # 33: 36.36 percent hits over 77 stims
# |- Target # 34: 29.87 percent hits over 77 stims
# |- Target # 35: 23.38 percent hits over 77 stims
# |- Target # 36: 32.47 percent hits over 77 stims
# |- Target # 37: 20.78 percent hits over 77 stims
# |- Target # 38: 25.97 percent hits over 77 stims
# |- Target # 39: 22.08 percent hits over 77 stims
# |- Target # 40: 25.97 percent hits over 77 stims
# |- Target # 41: 28.57 percent hits over 77 stims
# |- Target # 42: 24.68 percent hits over 77 stims
# |- Target # 43: 32.47 percent hits over 77 stims
# |- Target # 44: 29.87 percent hits over 77 stims
# |- Target # 45: 22.08 percent hits over 77 stims
# |- Target # 46: 29.87 percent hits over 77 stims
# |- Target # 47: 23.38 percent hits over 77 stims
# |- Target # 48: 23.38 percent hits over 77 stims
# |- Target # 49: 31.17 percent hits over 77 stims
#
# avg photostim. success rate is: 33.25 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-020/2020-12-19_t-020.pkl
#
#
# importing expobj for "2020-12-19, t-021" from: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-021/2020-12-19_t-021.pkl
#
#
# DONE IMPORT of RL109: t-021, post 4ap 2p all optical, 2 sz events, starts mid seizure that does terminate, 2nd one seems to be gone into SE
# re-collecting subset frames of current trial
# baseline frames:  [0, 38053]
# current trial frames:  [232384, 256018]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-021/2020-12-19_t-021.pkl
#
# Loading 545 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-021/2020-12-19_t-021.pkl
#
#
# searching for targeted cells...
# (350, 136)
# (255, 242)
# (243, 312)
# (261, 418)
# (237, 221)
# (341, 74)
# (482, 115)
# (410, 245)
# (191, 278)
# (301, 95)
# (262, 135)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-021/2020-12-19_t-021.pkl
#
# Number of targeted cells found suite2p:  11
#
# Target cells found in suite2p:  [28, 69, 84, 162, 165, 271, 304, 415, 416, 590, 769]  -- 11 cells (out of 50 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-021/2020-12-19_t-021.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-021/2020-12-19_t-021_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-021/2020-12-19_t-021.pkl
#
# collecting stim traces for cell # 1 out of 50
# collecting stim traces for cell # 2 out of 50
# collecting stim traces for cell # 3 out of 50
# collecting stim traces for cell # 4 out of 50
# collecting stim traces for cell # 5 out of 50
# collecting stim traces for cell # 6 out of 50
# collecting stim traces for cell # 7 out of 50
# collecting stim traces for cell # 8 out of 50
# collecting stim traces for cell # 9 out of 50
# collecting stim traces for cell # 10 out of 50
# collecting stim traces for cell # 11 out of 50
# collecting stim traces for cell # 12 out of 50
# collecting stim traces for cell # 13 out of 50
# collecting stim traces for cell # 14 out of 50
# collecting stim traces for cell # 15 out of 50
# collecting stim traces for cell # 16 out of 50
# collecting stim traces for cell # 17 out of 50
# collecting stim traces for cell # 18 out of 50
# collecting stim traces for cell # 19 out of 50
# collecting stim traces for cell # 20 out of 50
# collecting stim traces for cell # 21 out of 50
# collecting stim traces for cell # 22 out of 50
# collecting stim traces for cell # 23 out of 50
# collecting stim traces for cell # 24 out of 50
# collecting stim traces for cell # 25 out of 50
# collecting stim traces for cell # 26 out of 50
# collecting stim traces for cell # 27 out of 50
# collecting stim traces for cell # 28 out of 50
# collecting stim traces for cell # 29 out of 50
# collecting stim traces for cell # 30 out of 50
# collecting stim traces for cell # 31 out of 50
# collecting stim traces for cell # 32 out of 50
# collecting stim traces for cell # 33 out of 50
# collecting stim traces for cell # 34 out of 50
# collecting stim traces for cell # 35 out of 50
# collecting stim traces for cell # 36 out of 50
# collecting stim traces for cell # 37 out of 50
# collecting stim traces for cell # 38 out of 50
# collecting stim traces for cell # 39 out of 50
# collecting stim traces for cell # 40 out of 50
# collecting stim traces for cell # 41 out of 50
# collecting stim traces for cell # 42 out of 50
# collecting stim traces for cell # 43 out of 50
# collecting stim traces for cell # 44 out of 50
# collecting stim traces for cell # 45 out of 50
# collecting stim traces for cell # 46 out of 50
# collecting stim traces for cell # 47 out of 50
# collecting stim traces for cell # 48 out of 50
# collecting stim traces for cell # 49 out of 50
# collecting stim traces for cell # 50 out of 50
# (50, 143)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 40.0 percent hits over 10 stims
# |- Target # 1: 40.0 percent hits over 10 stims
# |- Target # 2: 10.0 percent hits over 10 stims
# |- Target # 3: 10.0 percent hits over 10 stims
# |- Target # 4: 30.0 percent hits over 10 stims
# |- Target # 5: 20.0 percent hits over 10 stims
# |- Target # 6: 30.0 percent hits over 10 stims
# |- Target # 7: 20.0 percent hits over 10 stims
# |- Target # 8: 30.0 percent hits over 10 stims
# |- Target # 9: 20.0 percent hits over 10 stims
# |- Target # 10: 20.0 percent hits over 10 stims
# |- Target # 11: 30.0 percent hits over 10 stims
# |- Target # 12: 30.0 percent hits over 10 stims
# |- Target # 13: 0.0 percent hits over 10 stims
# |- Target # 14: 20.0 percent hits over 10 stims
# |- Target # 15: 20.0 percent hits over 10 stims
# |- Target # 16: 30.0 percent hits over 10 stims
# |- Target # 17: 40.0 percent hits over 10 stims
# |- Target # 18: 20.0 percent hits over 10 stims
# |- Target # 19: 10.0 percent hits over 10 stims
# |- Target # 20: 10.0 percent hits over 10 stims
# |- Target # 21: 40.0 percent hits over 10 stims
# |- Target # 22: 20.0 percent hits over 10 stims
# |- Target # 23: 20.0 percent hits over 10 stims
# |- Target # 24: 20.0 percent hits over 10 stims
# |- Target # 25: 20.0 percent hits over 10 stims
# |- Target # 26: 20.0 percent hits over 10 stims
# |- Target # 27: 10.0 percent hits over 10 stims
# |- Target # 28: 20.0 percent hits over 10 stims
# |- Target # 29: 40.0 percent hits over 10 stims
# |- Target # 30: 30.0 percent hits over 10 stims
# |- Target # 31: 10.0 percent hits over 10 stims
# |- Target # 32: 10.0 percent hits over 10 stims
# |- Target # 33: 20.0 percent hits over 10 stims
# |- Target # 34: 0.0 percent hits over 10 stims
# |- Target # 35: 10.0 percent hits over 10 stims
# |- Target # 36: 30.0 percent hits over 10 stims
# |- Target # 37: 30.0 percent hits over 10 stims
# |- Target # 38: 20.0 percent hits over 10 stims
# |- Target # 39: 0.0 percent hits over 10 stims
# |- Target # 40: 0.0 percent hits over 10 stims
# |- Target # 41: 20.0 percent hits over 10 stims
# |- Target # 42: 10.0 percent hits over 10 stims
# |- Target # 43: 0.0 percent hits over 10 stims
# |- Target # 44: 0.0 percent hits over 10 stims
# |- Target # 45: 20.0 percent hits over 10 stims
# |- Target # 46: 20.0 percent hits over 10 stims
# |- Target # 47: 10.0 percent hits over 10 stims
# |- Target # 48: 0.0 percent hits over 10 stims
# |- Target # 49: 20.0 percent hits over 10 stims
#
# avg photostim. success rate is: 19.0 pct.
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 32.22 percent hits over 90 stims
# |- Target # 1: 33.33 percent hits over 90 stims
# |- Target # 2: 34.44 percent hits over 90 stims
# |- Target # 3: 33.33 percent hits over 90 stims
# |- Target # 4: 38.89 percent hits over 90 stims
# |- Target # 5: 33.33 percent hits over 90 stims
# |- Target # 6: 33.33 percent hits over 90 stims
# |- Target # 7: 27.78 percent hits over 90 stims
# |- Target # 8: 33.33 percent hits over 90 stims
# |- Target # 9: 33.33 percent hits over 90 stims
# |- Target # 10: 26.67 percent hits over 90 stims
# |- Target # 11: 36.67 percent hits over 90 stims
# |- Target # 12: 43.33 percent hits over 90 stims
# |- Target # 13: 32.22 percent hits over 90 stims
# |- Target # 14: 28.89 percent hits over 90 stims
# |- Target # 15: 25.56 percent hits over 90 stims
# |- Target # 16: 34.44 percent hits over 90 stims
# /home/pshah/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py:3316: UserWarning: the seizure filtering by *cells* functionality is only available for s2p defined cell targets as of now
#   warnings.warn(
# |- Target # 17: 26.67 percent hits over 90 stims
# |- Target # 18: 22.22 percent hits over 90 stims
# |- Target # 19: 28.89 percent hits over 90 stims
# |- Target # 20: 21.11 percent hits over 90 stims
# |- Target # 21: 35.56 percent hits over 90 stims
# |- Target # 22: 26.67 percent hits over 90 stims
# |- Target # 23: 26.67 percent hits over 90 stims
# |- Target # 24: 26.67 percent hits over 90 stims
# |- Target # 25: 20.0 percent hits over 90 stims
# |- Target # 26: 26.67 percent hits over 90 stims
# |- Target # 27: 24.44 percent hits over 90 stims
# |- Target # 28: 23.33 percent hits over 90 stims
# |- Target # 29: 32.22 percent hits over 90 stims
# |- Target # 30: 31.11 percent hits over 90 stims
# |- Target # 31: 30.0 percent hits over 90 stims
# |- Target # 32: 23.33 percent hits over 90 stims
# |- Target # 33: 27.78 percent hits over 90 stims
# |- Target # 34: 30.0 percent hits over 90 stims
# |- Target # 35: 28.89 percent hits over 90 stims
# |- Target # 36: 26.67 percent hits over 90 stims
# |- Target # 37: 30.0 percent hits over 90 stims
# |- Target # 38: 25.56 percent hits over 90 stims
# |- Target # 39: 22.22 percent hits over 90 stims
# |- Target # 40: 23.33 percent hits over 90 stims
# |- Target # 41: 24.44 percent hits over 90 stims
# |- Target # 42: 24.44 percent hits over 90 stims
# |- Target # 43: 22.22 percent hits over 90 stims
# |- Target # 44: 31.11 percent hits over 90 stims
# |- Target # 45: 17.78 percent hits over 90 stims
# |- Target # 46: 30.0 percent hits over 90 stims
# |- Target # 47: 20.0 percent hits over 90 stims
# |- Target # 48: 25.56 percent hits over 90 stims
# |- Target # 49: 26.67 percent hits over 90 stims
#
# avg photostim. success rate is: 28.47 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-19/RL109/2020-12-19_t-021/2020-12-19_t-021.pkl
