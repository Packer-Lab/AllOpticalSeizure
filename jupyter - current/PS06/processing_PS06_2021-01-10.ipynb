# %%
import sys; sys.path.append('/home/pshah/Documents/code/PackerLab_pycharm/')
import os
import pickle
import alloptical_utils_pj as aoutils
import alloptical_plotting_utils as aoplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import utils.funcs_pj as pj
import tifffile as tf

# %%
to_suite2p = ['t-002', 't-003', 't-005', 't-007', 't-008', 't-009', 't-010', 't-011', 't-012', 
              't-013', 't-014', 't-015', 't-016'] # specify all trials that were used in the suite2p runtotal_frames_stitched = 0
baseline_trials = ['t-002', 't-003', 't-005', 't-007'] # specify which trials to use as spont baseline
# note ^^^ this only works currently when the spont baseline trials all come first, and also back to back

# %% [markdown]
# ### pre4ap

# %%
trials = ['t-008', 't-009', 't-010', 't-011']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2021-01-10'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/PS06/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/2021-01-10/suite2p/alloptical-2p-08x-alltrials-reg_tiff/plane0'
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-01-10, t-008" from: /home/pshah/mnt/qnap/Analysis/2021-01-10/PS06/2021-01-10_t-008/2021-01-10_t-008.pkl
#
#
# DONE IMPORT of PS06: t-008, pre 4ap 2p all optical, 10 cells x 5 groups; 5mW per cell; 100ms-stim-40hz-multi_interleaved (prot. #3)
# re-collecting subset frames of current trial
# baseline frames:  [0, 42181]
# current trial frames:  [42181, 49888]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-10/PS06/2021-01-10_t-008/2021-01-10_t-008.pkl
#
# Loading 2849 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-10/PS06/2021-01-10_t-008/2021-01-10_t-008.pkl
#
#
# searching for targeted cells...
# (620, 702)
# (534, 832)
# (294, 244)
# (678, 460)
# (226, 132)
# (374, 420)
# (372, 218)
# (294, 244)
# (272, 548)
# (288, 232)
# (502, 828)
# (632, 762)
# (604, 600)
# (304, 178)
# (374, 512)
# (378, 492)
# (692, 548)
# (288, 232)
# (636, 808)
# (394, 196)
# (356, 508)
# ...

# %% [markdown]
# ### post4ap

# %%
trials = ['t-012', 't-013', 't-014', 't-015', 't-016']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2021-01-10'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/PS06/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/2021-01-10/suite2p/alloptical-2p-08x-alltrials-reg_tiff/plane0'
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-01-10, t-008" from: /home/pshah/mnt/qnap/Analysis/2021-01-10/PS06/2021-01-10_t-008/2021-01-10_t-008.pkl
#
#
# DONE IMPORT of PS06: t-008, pre 4ap 2p all optical, 10 cells x 5 groups; 5mW per cell; 100ms-stim-40hz-multi_interleaved (prot. #3)
# re-collecting subset frames of current trial
# baseline frames:  [0, 42181]
# current trial frames:  [42181, 49888]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-10/PS06/2021-01-10_t-008/2021-01-10_t-008.pkl
#
# Loading 2849 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-10/PS06/2021-01-10_t-008/2021-01-10_t-008.pkl
#
#
# searching for targeted cells...
# (620, 702)
# (534, 832)
# (294, 244)
# (678, 460)
# (226, 132)
# (374, 420)
# (372, 218)
# (294, 244)
# (272, 548)
# (288, 232)
# (502, 828)
# (632, 762)
# (604, 600)
# (304, 178)
# (374, 512)
# (378, 492)
# (692, 548)
# (288, 232)
# (636, 808)
# (394, 196)
# (356, 508)
# ...

# %%
print("\n COMPLETED RUNNING ALL OPTICAL PROCESSING PHOTOSTIM.")
# Out:
#  COMPLETED RUNNING ALL OPTICAL PROCESSING PHOTOSTIM.
