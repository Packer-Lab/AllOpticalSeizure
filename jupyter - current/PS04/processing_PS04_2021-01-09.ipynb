# %% [markdown]
# # Processing - PS04 - 2021-01-09

# %%
import sys; sys.path.append('/home/pshah/Documents/code/PackerLab_pycharm/')
import os
import pickle
import alloptical_utils_pj as aoutils
import alloptical_plotting_utils as aoplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import utils.funcs_pj as pj
import tifffile as tf

# %%
to_suite2p = ['t-004', 't-006', 't-012', 't-013', 't-014', 't-015', 't-017', 't-018'
                  ] # specify all trials that were used in the suite2p runtotal_frames_stitched = 0
baseline_trials = ['t-004', 't-006'] # specify which trials to use as spont baseline
# note ^^^ this only works currently when the spont baseline trials all come first, and also back to back

# %% [markdown]
# ### pre4ap

# %%
trials = ['t-012', 't-013', 't-014', 't-015', 't-017']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2021-01-09'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/suite2p/alloptical-2p-1_25x-alltrials/plane0' % date
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-01-09, t-012" from: /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-012/2021-01-09_t-012.pkl
#
#
# DONE IMPORT of PS04: t-012, pre 4ap 2p all optical, 14 cells x 2 groups; 7mW per cell preset: 250ms multi_interleaved 30 trials
#
# -----Loading up target coordinates...
# Number of targets: 28
# Number of targets (in SLM group 1):  14
# Number of targets (in SLM group 1):  14
# Got targets...
# re-collecting subset frames of current trial
# baseline frames:  [0, 27094]
# current trial frames:  [27094, 31609]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-012/2021-01-09_t-012.pkl
#
# Loading 1259 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-012/2021-01-09_t-012.pkl
#
#
# searching for targeted cells...
# (888, 642)
# (196, 494)
# (238, 412)
# (372, 368)
# (928, 722)
# (526, 220)
# (430, 726)
# (854, 662)
# (862, 462)
# (848, 626)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-012/2021-01-09_t-012.pkl
#
# Number of targeted cells found suite2p:  10
#
# Target cells found in suite2p:  [78, 84, 150, 188, 237, 260, 298, 878, 1004, 1017]  -- 10 cells (out of 28 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-012/2021-01-09_t-012.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-012/2021-01-09_t-012_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file013_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file014_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file015_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-012/2021-01-09_t-012.pkl
#
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-012/2021-01-09_t-012.pkl
#
# collecting stim traces for cell # 1 out of 28
# collecting stim traces for cell # 2 out of 28
# collecting stim traces for cell # 3 out of 28
# collecting stim traces for cell # 4 out of 28
# collecting stim traces for cell # 5 out of 28
# collecting stim traces for cell # 6 out of 28
# collecting stim traces for cell # 7 out of 28
# collecting stim traces for cell # 8 out of 28
# collecting stim traces for cell # 9 out of 28
# collecting stim traces for cell # 10 out of 28
# collecting stim traces for cell # 11 out of 28
# collecting stim traces for cell # 12 out of 28
# collecting stim traces for cell # 13 out of 28
# collecting stim traces for cell # 14 out of 28
# collecting stim traces for cell # 15 out of 28
# collecting stim traces for cell # 16 out of 28
# collecting stim traces for cell # 17 out of 28
# collecting stim traces for cell # 18 out of 28
# collecting stim traces for cell # 19 out of 28
# collecting stim traces for cell # 20 out of 28
# collecting stim traces for cell # 21 out of 28
# collecting stim traces for cell # 22 out of 28
# collecting stim traces for cell # 23 out of 28
# collecting stim traces for cell # 24 out of 28
# collecting stim traces for cell # 25 out of 28
# collecting stim traces for cell # 26 out of 28
# collecting stim traces for cell # 27 out of 28
# collecting stim traces for cell # 28 out of 28
# (28, 60)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 60.0 percent hits over 30 stims
# |- Target # 1: 86.67 percent hits over 30 stims
# |- Target # 2: 73.33 percent hits over 30 stims
# |- Target # 3: 60.0 percent hits over 30 stims
# |- Target # 4: 73.33 percent hits over 30 stims
# |- Target # 5: 56.67 percent hits over 30 stims
# |- Target # 6: 66.67 percent hits over 30 stims
# |- Target # 7: 63.33 percent hits over 30 stims
# |- Target # 8: 66.67 percent hits over 30 stims
# |- Target # 9: 83.33 percent hits over 30 stims
# |- Target # 10: 56.67 percent hits over 30 stims
# |- Target # 11: 56.67 percent hits over 30 stims
# |- Target # 12: 40.0 percent hits over 30 stims
# |- Target # 13: 56.67 percent hits over 30 stims
# |- Target # 14: 56.67 percent hits over 30 stims
# |- Target # 15: 26.67 percent hits over 30 stims
# |- Target # 16: 26.67 percent hits over 30 stims
# |- Target # 17: 20.0 percent hits over 30 stims
# |- Target # 18: 30.0 percent hits over 30 stims
# |- Target # 19: 50.0 percent hits over 30 stims
# |- Target # 20: 23.33 percent hits over 30 stims
# |- Target # 21: 43.33 percent hits over 30 stims
# |- Target # 22: 66.67 percent hits over 30 stims
# |- Target # 23: 33.33 percent hits over 30 stims
# |- Target # 24: 30.0 percent hits over 30 stims
# |- Target # 25: 40.0 percent hits over 30 stims
# |- Target # 26: 43.33 percent hits over 30 stims
# |- Target # 27: 36.67 percent hits over 30 stims
#
# avg photostim. success rate is: 50.95 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-012/2021-01-09_t-012.pkl
#
#
# importing expobj for "2021-01-09, t-013" from: /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-013/2021-01-09_t-013.pkl
#
#
# DONE IMPORT of PS04: t-013, pre 4ap 2p all optical, 14 cells x 2 groups; 7mW per cell preset: 100ms multi_interleaved 30 trials
#
# -----Loading up target coordinates...
# Number of targets: 28
# Number of targets (in SLM group 1):  14
# Number of targets (in SLM group 1):  14
# Got targets...
# re-collecting subset frames of current trial
# baseline frames:  [0, 27094]
# current trial frames:  [31609, 36577]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-013/2021-01-09_t-013.pkl
#
# Loading 1259 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-013/2021-01-09_t-013.pkl
#
#
# searching for targeted cells...
# (888, 642)
# (196, 494)
# (238, 412)
# (372, 368)
# (928, 722)
# (526, 220)
# (430, 726)
# (854, 662)
# (862, 462)
# (848, 626)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-013/2021-01-09_t-013.pkl
#
# Number of targeted cells found suite2p:  10
#
# Target cells found in suite2p:  [78, 84, 150, 188, 237, 260, 298, 878, 1004, 1017]  -- 10 cells (out of 28 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-013/2021-01-09_t-013.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-013/2021-01-09_t-013_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file015_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file016_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file017_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file018_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-013/2021-01-09_t-013.pkl
#
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-013/2021-01-09_t-013.pkl
#
# collecting stim traces for cell # 1 out of 28
# collecting stim traces for cell # 2 out of 28
# collecting stim traces for cell # 3 out of 28
# collecting stim traces for cell # 4 out of 28
# collecting stim traces for cell # 5 out of 28
# collecting stim traces for cell # 6 out of 28
# collecting stim traces for cell # 7 out of 28
# collecting stim traces for cell # 8 out of 28
# collecting stim traces for cell # 9 out of 28
# collecting stim traces for cell # 10 out of 28
# collecting stim traces for cell # 11 out of 28
# collecting stim traces for cell # 12 out of 28
# collecting stim traces for cell # 13 out of 28
# collecting stim traces for cell # 14 out of 28
# collecting stim traces for cell # 15 out of 28
# collecting stim traces for cell # 16 out of 28
# collecting stim traces for cell # 17 out of 28
# collecting stim traces for cell # 18 out of 28
# collecting stim traces for cell # 19 out of 28
# collecting stim traces for cell # 20 out of 28
# collecting stim traces for cell # 21 out of 28
# collecting stim traces for cell # 22 out of 28
# collecting stim traces for cell # 23 out of 28
# collecting stim traces for cell # 24 out of 28
# collecting stim traces for cell # 25 out of 28
# collecting stim traces for cell # 26 out of 28
# collecting stim traces for cell # 27 out of 28
# collecting stim traces for cell # 28 out of 28
# (28, 56)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 36.67 percent hits over 30 stims
# |- Target # 1: 20.0 percent hits over 30 stims
# |- Target # 2: 36.67 percent hits over 30 stims
# |- Target # 3: 30.0 percent hits over 30 stims
# |- Target # 4: 30.0 percent hits over 30 stims
# |- Target # 5: 36.67 percent hits over 30 stims
# |- Target # 6: 43.33 percent hits over 30 stims
# |- Target # 7: 43.33 percent hits over 30 stims
# |- Target # 8: 56.67 percent hits over 30 stims
# |- Target # 9: 43.33 percent hits over 30 stims
# |- Target # 10: 46.67 percent hits over 30 stims
# |- Target # 11: 60.0 percent hits over 30 stims
# |- Target # 12: 40.0 percent hits over 30 stims
# |- Target # 13: 46.67 percent hits over 30 stims
# |- Target # 14: 46.67 percent hits over 30 stims
# |- Target # 15: 56.67 percent hits over 30 stims
# |- Target # 16: 43.33 percent hits over 30 stims
# |- Target # 17: 56.67 percent hits over 30 stims
# |- Target # 18: 33.33 percent hits over 30 stims
# |- Target # 19: 20.0 percent hits over 30 stims
# |- Target # 20: 50.0 percent hits over 30 stims
# |- Target # 21: 23.33 percent hits over 30 stims
# |- Target # 22: 16.67 percent hits over 30 stims
# |- Target # 23: 36.67 percent hits over 30 stims
# |- Target # 24: 40.0 percent hits over 30 stims
# |- Target # 25: 33.33 percent hits over 30 stims
# |- Target # 26: 36.67 percent hits over 30 stims
# |- Target # 27: 33.33 percent hits over 30 stims
#
# avg photostim. success rate is: 39.17 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-013/2021-01-09_t-013.pkl
#
#
# importing expobj for "2021-01-09, t-014" from: /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-014/2021-01-09_t-014.pkl
#
#
# DONE IMPORT of PS04: t-014, pre 4ap 2p all optical, 14 cells x 2 groups; 7mW per cell preset: 250ms multi_interleaved 30 trials
#
# -----Loading up target coordinates...
# Number of targets: 28
# Number of targets (in SLM group 1):  14
# Number of targets (in SLM group 1):  14
# Got targets...
# re-collecting subset frames of current trial
# baseline frames:  [0, 27094]
# current trial frames:  [36577, 41545]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-014/2021-01-09_t-014.pkl
#
# Loading 1259 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-014/2021-01-09_t-014.pkl
#
#
# searching for targeted cells...
# (888, 642)
# (196, 494)
# (238, 412)
# (372, 368)
# (928, 722)
# (526, 220)
# (430, 726)
# (854, 662)
# (862, 462)
# (848, 626)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-014/2021-01-09_t-014.pkl
#
# Number of targeted cells found suite2p:  10
#
# Target cells found in suite2p:  [78, 84, 150, 188, 237, 260, 298, 878, 1004, 1017]  -- 10 cells (out of 28 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-014/2021-01-09_t-014.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-014/2021-01-09_t-014_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file018_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file019_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file020_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-014/2021-01-09_t-014.pkl
#
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-014/2021-01-09_t-014.pkl
#
# collecting stim traces for cell # 1 out of 28
# collecting stim traces for cell # 2 out of 28
# collecting stim traces for cell # 3 out of 28
# collecting stim traces for cell # 4 out of 28
# collecting stim traces for cell # 5 out of 28
# collecting stim traces for cell # 6 out of 28
# collecting stim traces for cell # 7 out of 28
# collecting stim traces for cell # 8 out of 28
# collecting stim traces for cell # 9 out of 28
# collecting stim traces for cell # 10 out of 28
# collecting stim traces for cell # 11 out of 28
# collecting stim traces for cell # 12 out of 28
# collecting stim traces for cell # 13 out of 28
# collecting stim traces for cell # 14 out of 28
# collecting stim traces for cell # 15 out of 28
# collecting stim traces for cell # 16 out of 28
# collecting stim traces for cell # 17 out of 28
# collecting stim traces for cell # 18 out of 28
# collecting stim traces for cell # 19 out of 28
# collecting stim traces for cell # 20 out of 28
# collecting stim traces for cell # 21 out of 28
# collecting stim traces for cell # 22 out of 28
# collecting stim traces for cell # 23 out of 28
# collecting stim traces for cell # 24 out of 28
# collecting stim traces for cell # 25 out of 28
# collecting stim traces for cell # 26 out of 28
# collecting stim traces for cell # 27 out of 28
# collecting stim traces for cell # 28 out of 28
# (28, 60)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 46.67 percent hits over 30 stims
# |- Target # 1: 26.67 percent hits over 30 stims
# |- Target # 2: 43.33 percent hits over 30 stims
# |- Target # 3: 40.0 percent hits over 30 stims
# |- Target # 4: 43.33 percent hits over 30 stims
# |- Target # 5: 43.33 percent hits over 30 stims
# |- Target # 6: 46.67 percent hits over 30 stims
# |- Target # 7: 50.0 percent hits over 30 stims
# |- Target # 8: 60.0 percent hits over 30 stims
# |- Target # 9: 63.33 percent hits over 30 stims
# |- Target # 10: 50.0 percent hits over 30 stims
# |- Target # 11: 50.0 percent hits over 30 stims
# |- Target # 12: 56.67 percent hits over 30 stims
# |- Target # 13: 56.67 percent hits over 30 stims
# |- Target # 14: 63.33 percent hits over 30 stims
# |- Target # 15: 53.33 percent hits over 30 stims
# |- Target # 16: 36.67 percent hits over 30 stims
# |- Target # 17: 50.0 percent hits over 30 stims
# |- Target # 18: 46.67 percent hits over 30 stims
# |- Target # 19: 43.33 percent hits over 30 stims
# |- Target # 20: 56.67 percent hits over 30 stims
# |- Target # 21: 40.0 percent hits over 30 stims
# |- Target # 22: 36.67 percent hits over 30 stims
# |- Target # 23: 46.67 percent hits over 30 stims
# |- Target # 24: 36.67 percent hits over 30 stims
# |- Target # 25: 40.0 percent hits over 30 stims
# |- Target # 26: 56.67 percent hits over 30 stims
# |- Target # 27: 40.0 percent hits over 30 stims
#
# avg photostim. success rate is: 47.26 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-014/2021-01-09_t-014.pkl
#
#
# importing expobj for "2021-01-09, t-015" from: /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-015/2021-01-09_t-015.pkl
#
#
# DONE IMPORT of PS04: t-015, pre 4ap 2p all optical, 14 cells x 2 groups; 7mW per cell preset: 100ms multi_interleaved 30 trials
#
# -----Loading up target coordinates...
# Number of targets: 28
# Number of targets (in SLM group 1):  14
# Number of targets (in SLM group 1):  14
# Got targets...
# re-collecting subset frames of current trial
# baseline frames:  [0, 27094]
# current trial frames:  [41545, 46513]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-015/2021-01-09_t-015.pkl
#
# Loading 1259 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-015/2021-01-09_t-015.pkl
#
#
# searching for targeted cells...
# (888, 642)
# (196, 494)
# (238, 412)
# (372, 368)
# (928, 722)
# (526, 220)
# (430, 726)
# (854, 662)
# (862, 462)
# (848, 626)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-015/2021-01-09_t-015.pkl
#
# Number of targeted cells found suite2p:  10
#
# Target cells found in suite2p:  [78, 84, 150, 188, 237, 260, 298, 878, 1004, 1017]  -- 10 cells (out of 28 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-015/2021-01-09_t-015.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-015/2021-01-09_t-015_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file020_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file021_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file022_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file023_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-015/2021-01-09_t-015.pkl
#
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-015/2021-01-09_t-015.pkl
#
# collecting stim traces for cell # 1 out of 28
# collecting stim traces for cell # 2 out of 28
# collecting stim traces for cell # 3 out of 28
# collecting stim traces for cell # 4 out of 28
# collecting stim traces for cell # 5 out of 28
# collecting stim traces for cell # 6 out of 28
# collecting stim traces for cell # 7 out of 28
# collecting stim traces for cell # 8 out of 28
# collecting stim traces for cell # 9 out of 28
# collecting stim traces for cell # 10 out of 28
# collecting stim traces for cell # 11 out of 28
# collecting stim traces for cell # 12 out of 28
# collecting stim traces for cell # 13 out of 28
# collecting stim traces for cell # 14 out of 28
# collecting stim traces for cell # 15 out of 28
# collecting stim traces for cell # 16 out of 28
# collecting stim traces for cell # 17 out of 28
# collecting stim traces for cell # 18 out of 28
# collecting stim traces for cell # 19 out of 28
# collecting stim traces for cell # 20 out of 28
# collecting stim traces for cell # 21 out of 28
# collecting stim traces for cell # 22 out of 28
# collecting stim traces for cell # 23 out of 28
# collecting stim traces for cell # 24 out of 28
# collecting stim traces for cell # 25 out of 28
# collecting stim traces for cell # 26 out of 28
# collecting stim traces for cell # 27 out of 28
# collecting stim traces for cell # 28 out of 28
# (28, 56)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 23.33 percent hits over 30 stims
# |- Target # 1: 36.67 percent hits over 30 stims
# |- Target # 2: 20.0 percent hits over 30 stims
# |- Target # 3: 13.33 percent hits over 30 stims
# |- Target # 4: 23.33 percent hits over 30 stims
# |- Target # 5: 30.0 percent hits over 30 stims
# |- Target # 6: 23.33 percent hits over 30 stims
# |- Target # 7: 26.67 percent hits over 30 stims
# |- Target # 8: 33.33 percent hits over 30 stims
# |- Target # 9: 20.0 percent hits over 30 stims
# |- Target # 10: 30.0 percent hits over 30 stims
# |- Target # 11: 23.33 percent hits over 30 stims
# |- Target # 12: 40.0 percent hits over 30 stims
# |- Target # 13: 40.0 percent hits over 30 stims
# |- Target # 14: 36.67 percent hits over 30 stims
# |- Target # 15: 46.67 percent hits over 30 stims
# |- Target # 16: 36.67 percent hits over 30 stims
# |- Target # 17: 40.0 percent hits over 30 stims
# |- Target # 18: 13.33 percent hits over 30 stims
# |- Target # 19: 13.33 percent hits over 30 stims
# |- Target # 20: 23.33 percent hits over 30 stims
# |- Target # 21: 16.67 percent hits over 30 stims
# |- Target # 22: 10.0 percent hits over 30 stims
# |- Target # 23: 26.67 percent hits over 30 stims
# |- Target # 24: 43.33 percent hits over 30 stims
# |- Target # 25: 10.0 percent hits over 30 stims
# |- Target # 26: 36.67 percent hits over 30 stims
# |- Target # 27: 16.67 percent hits over 30 stims
#
# avg photostim. success rate is: 26.9 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-015/2021-01-09_t-015.pkl
#
#
# importing expobj for "2021-01-09, t-017" from: /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-017/2021-01-09_t-017.pkl
#
#
# DONE IMPORT of PS04: t-017, pre 4ap 2p all optical, 14 cells x 2 groups; 7mW per cell preset: 250ms multi_interleaved 30 trials
#
# -----Loading up target coordinates...
# Number of targets: 28
# Number of targets (in SLM group 1):  14
# Number of targets (in SLM group 1):  14
# Got targets...
# re-collecting subset frames of current trial
# baseline frames:  [0, 27094]
# current trial frames:  [46513, 51481]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-017/2021-01-09_t-017.pkl
#
# Loading 1259 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-017/2021-01-09_t-017.pkl
#
#
# searching for targeted cells...
# (888, 642)
# (196, 494)
# (238, 412)
# (372, 368)
# (928, 722)
# (526, 220)
# (430, 726)
# (854, 662)
# (862, 462)
# (848, 626)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-017/2021-01-09_t-017.pkl
#
# Number of targeted cells found suite2p:  10
#
# Target cells found in suite2p:  [78, 84, 150, 188, 237, 260, 298, 878, 1004, 1017]  -- 10 cells (out of 28 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-017/2021-01-09_t-017.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-017/2021-01-09_t-017_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file023_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file024_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file025_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-017/2021-01-09_t-017.pkl
#
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-017/2021-01-09_t-017.pkl
#
# collecting stim traces for cell # 1 out of 28
# collecting stim traces for cell # 2 out of 28
# collecting stim traces for cell # 3 out of 28
# collecting stim traces for cell # 4 out of 28
# collecting stim traces for cell # 5 out of 28
# collecting stim traces for cell # 6 out of 28
# collecting stim traces for cell # 7 out of 28
# collecting stim traces for cell # 8 out of 28
# collecting stim traces for cell # 9 out of 28
# collecting stim traces for cell # 10 out of 28
# collecting stim traces for cell # 11 out of 28
# collecting stim traces for cell # 12 out of 28
# collecting stim traces for cell # 13 out of 28
# collecting stim traces for cell # 14 out of 28
# collecting stim traces for cell # 15 out of 28
# collecting stim traces for cell # 16 out of 28
# collecting stim traces for cell # 17 out of 28
# collecting stim traces for cell # 18 out of 28
# collecting stim traces for cell # 19 out of 28
# collecting stim traces for cell # 20 out of 28
# collecting stim traces for cell # 21 out of 28
# collecting stim traces for cell # 22 out of 28
# collecting stim traces for cell # 23 out of 28
# collecting stim traces for cell # 24 out of 28
# collecting stim traces for cell # 25 out of 28
# collecting stim traces for cell # 26 out of 28
# collecting stim traces for cell # 27 out of 28
# collecting stim traces for cell # 28 out of 28
# (28, 60)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 60.0 percent hits over 30 stims
# |- Target # 1: 53.33 percent hits over 30 stims
# |- Target # 2: 60.0 percent hits over 30 stims
# |- Target # 3: 46.67 percent hits over 30 stims
# |- Target # 4: 96.67 percent hits over 30 stims
# |- Target # 5: 90.0 percent hits over 30 stims
# |- Target # 6: 76.67 percent hits over 30 stims
# |- Target # 7: 90.0 percent hits over 30 stims
# |- Target # 8: 60.0 percent hits over 30 stims
# |- Target # 9: 46.67 percent hits over 30 stims
# |- Target # 10: 73.33 percent hits over 30 stims
# |- Target # 11: 56.67 percent hits over 30 stims
# |- Target # 12: 50.0 percent hits over 30 stims
# |- Target # 13: 66.67 percent hits over 30 stims
# |- Target # 14: 46.67 percent hits over 30 stims
# |- Target # 15: 53.33 percent hits over 30 stims
# |- Target # 16: 43.33 percent hits over 30 stims
# |- Target # 17: 43.33 percent hits over 30 stims
# |- Target # 18: 86.67 percent hits over 30 stims
# |- Target # 19: 96.67 percent hits over 30 stims
# |- Target # 20: 46.67 percent hits over 30 stims
# |- Target # 21: 80.0 percent hits over 30 stims
# |- Target # 22: 100.0 percent hits over 30 stims
# |- Target # 23: 66.67 percent hits over 30 stims
# |- Target # 24: 63.33 percent hits over 30 stims
# |- Target # 25: 60.0 percent hits over 30 stims
# |- Target # 26: 50.0 percent hits over 30 stims
# |- Target # 27: 56.67 percent hits over 30 stims
#
# avg photostim. success rate is: 65.0 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-017/2021-01-09_t-017.pkl

# %% [markdown]
# ### post4ap

# %%
trials = ['t-018']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2021-01-09'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/suite2p/alloptical-2p-1_25x-alltrials/plane0' % date
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-01-09, t-018" from: /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-018/2021-01-09_t-018.pkl
#
#
# DONE IMPORT of PS04: t-018, post 4ap 2p all optical, 6 events, starts mid sz and 1 sz after end of photostim; FOV had moved - check carefully; 14 cells x 2 groups; 7mW per cell preset: 250ms multi_interleaved 30 trials
#
# -----Loading up target coordinates...
# Number of targets: 28
# Number of targets (in SLM group 1):  14
# Number of targets (in SLM group 1):  14
# Got targets...
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-018/2021-01-09_t-018.pkl
#
# re-collecting subset frames of current trial
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file027_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2021-01-09/suite2p/alloptical-2p-1_25x-alltrials/plane0/reg_tif/file028_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-018/2021-01-09_t-018.pkl
#
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-018/2021-01-09_t-018.pkl
#
# collecting stim traces for cell # 1 out of 28
# collecting stim traces for cell # 2 out of 28
# collecting stim traces for cell # 3 out of 28
# collecting stim traces for cell # 4 out of 28
# collecting stim traces for cell # 5 out of 28
# collecting stim traces for cell # 6 out of 28
# collecting stim traces for cell # 7 out of 28
# collecting stim traces for cell # 8 out of 28
# collecting stim traces for cell # 9 out of 28
# collecting stim traces for cell # 10 out of 28
# collecting stim traces for cell # 11 out of 28
# collecting stim traces for cell # 12 out of 28
# collecting stim traces for cell # 13 out of 28
# collecting stim traces for cell # 14 out of 28
# collecting stim traces for cell # 15 out of 28
# collecting stim traces for cell # 16 out of 28
# collecting stim traces for cell # 17 out of 28
# collecting stim traces for cell # 18 out of 28
# collecting stim traces for cell # 19 out of 28
# collecting stim traces for cell # 20 out of 28
# collecting stim traces for cell # 21 out of 28
# collecting stim traces for cell # 22 out of 28
# collecting stim traces for cell # 23 out of 28
# collecting stim traces for cell # 24 out of 28
# collecting stim traces for cell # 25 out of 28
# collecting stim traces for cell # 26 out of 28
# collecting stim traces for cell # 27 out of 28
# collecting stim traces for cell # 28 out of 28
# (28, 60)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 71.43 percent hits over 7 stims
# |- Target # 1: 57.14 percent hits over 7 stims
# |- Target # 2: 42.86 percent hits over 7 stims
# |- Target # 3: 57.14 percent hits over 7 stims
# |- Target # 4: 57.14 percent hits over 7 stims
# |- Target # 5: 57.14 percent hits over 7 stims
# |- Target # 6: 71.43 percent hits over 7 stims
# |- Target # 7: 71.43 percent hits over 7 stims
# |- Target # 8: 71.43 percent hits over 7 stims
# |- Target # 9: 85.71 percent hits over 7 stims
# |- Target # 10: 42.86 percent hits over 7 stims
# |- Target # 11: 57.14 percent hits over 7 stims
# |- Target # 12: 14.29 percent hits over 7 stims
# |- Target # 13: 42.86 percent hits over 7 stims
# |- Target # 14: 57.14 percent hits over 7 stims
# |- Target # 15: 14.29 percent hits over 7 stims
# |- Target # 16: 14.29 percent hits over 7 stims
# |- Target # 17: 14.29 percent hits over 7 stims
# |- Target # 18: 28.57 percent hits over 7 stims
# |- Target # 19: 42.86 percent hits over 7 stims
# |- Target # 20: 14.29 percent hits over 7 stims
# |- Target # 21: 14.29 percent hits over 7 stims
# |- Target # 22: 28.57 percent hits over 7 stims
# |- Target # 23: 28.57 percent hits over 7 stims
# |- Target # 24: 14.29 percent hits over 7 stims
# |- Target # 25: 28.57 percent hits over 7 stims
# |- Target # 26: 42.86 percent hits over 7 stims
# |- Target # 27: 57.14 percent hits over 7 stims
#
# avg photostim. success rate is: 42.86 pct.
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 56.52 percent hits over 23 stims
# |- Target # 1: 52.17 percent hits over 23 stims
# |- Target # 2: 56.52 percent hits over 23 stims
# |- Target # 3: 39.13 percent hits over 23 stims
# |- Target # 4: 65.22 percent hits over 23 stims
# |- Target # 5: 60.87 percent hits over 23 stims
# |- Target # 6: 65.22 percent hits over 23 stims
# |- Target # 7: 65.22 percent hits over 23 stims
# |- Target # 8: 65.22 percent hits over 23 stims
# |- Target # 9: 86.96 percent hits over 23 stims
# |- Target # 10: 56.52 percent hits over 23 stims
# |- Target # 11: 56.52 percent hits over 23 stims
# |- Target # 12: 30.43 percent hits over 23 stims
# |- Target # 13: 47.83 percent hits over 23 stims
# |- Target # 14: 52.17 percent hits over 23 stims
# |- Target # 15: 39.13 percent hits over 23 stims
# |- Target # 16: 34.78 percent hits over 23 stims
# |- Target # 17: 47.83 percent hits over 23 stims
# |- Target # 18: 43.48 percent hits over 23 stims
# |- Target # 19: 43.48 percent hits over 23 stims
# |- Target # 20: 52.17 percent hits over 23 stims
# |- Target # 21: 47.83 percent hits over 23 stims
# |- Target # 22: 52.17 percent hits over 23 stims
# |- Target # 23: 47.83 percent hits over 23 stims
# |- Target # 24: 47.83 percent hits over 23 stims
# |- Target # 25: 43.48 percent hits over 23 stims
# |- Target # 26: 39.13 percent hits over 23 stims
# |- Target # 27: 39.13 percent hits over 23 stims
#
# avg photostim. success rate is: 51.24 pct.
# /home/pshah/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py:3342: UserWarning: the seizure filtering by *cells* functionality is only available for s2p defined cell targets as of now
#   warnings.warn(
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-09/2021-01-09_t-018/2021-01-09_t-018.pkl
