# %% [markdown]
# # Analysis Code - PS18 - 2021-02-02
#
# run on: 2021-06-09

# %%
# %% IMPORT MODULES AND TRIAL expobj OBJECT
import sys
sys.path.append('/home/pshah/Documents/code/PackerLab_pycharm/')
sys.path.append('/home/pshah/Documents/code/')
import alloptical_utils_pj as aoutils
import alloptical_plotting_utils as aoplot
import utils.funcs_pj as pj

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from skimage import draw

# %% [markdown]
# ## pre4ap

# %% [markdown]
# ### Analysis for raw SLM targets traces

# %%
trials = ['t-005', 't-006']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    prep = 'PS18'
    date = '2021-02-02'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/%s/%s_%s/%s_%s.pkl" % (date, prep, date, trial, date, trial)
   
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path, verbose=False)  

    expobj._findTargets()
    expobj.raw_traces_from_targets(force_redo=True, save=True)
    expobj.save()
    aoutils.slm_targets_responses(expobj, experiment, trial, y_spacing_factor=1, smooth_overlap_traces=5, figsize=[20, 15],
                                  linewidth_overlap_traces=0.6, y_lims_periphotostim_trace=[-0.5, 4.0], 
                                  v_lims_periphotostim_heatmap=[-2,5], save_results=True)
# Out:
# /home/pshah/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py:3691: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   fig.tight_layout()
# /home/pshah/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py:3691: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   fig.tight_layout()

# %% [markdown]
# ## post4ap

# %% [markdown]
# ### Analysis for raw SLM targets traces

# %%
trials = ['t-008']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    prep = 'PS18'
    date = '2021-02-02'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/%s/%s_%s/%s_%s.pkl" % (date, prep, date, trial, date, trial)

    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path, verbose=False)  
    
    expobj._findTargets()
    expobj.raw_traces_from_targets(force_redo=True, save=True)
    expobj.save()
    aoutils.slm_targets_responses(expobj, experiment, trial, y_spacing_factor=1, smooth_overlap_traces=5, figsize=[20, 15],
                                  linewidth_overlap_traces=0.6, y_lims_periphotostim_trace=[-0.5, 4.0],
                                  v_lims_periphotostim_heatmap=[-2,5], save_results=True)
