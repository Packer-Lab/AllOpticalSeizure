# %% [markdown]
# # Processing - PS05 - 2021-01-08

# %%
import sys; sys.path.append('/home/pshah/Documents/code/PackerLab_pycharm/')
import os
import pickle
import alloptical_utils_pj as aoutils
import alloptical_plotting_utils as aoplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import utils.funcs_pj as pj
import tifffile as tf

# %%
to_suite2p = ['t-003', 't-005', 't-010', 't-011', 't-012'] # specify all trials that were used in the suite2p runtotal_frames_stitched = 0
baseline_trials = ['t-003', 't-005'] # specify which trials to use as spont baseline
# note ^^^ this only works currently when the spont baseline trials all come first, and also back to back

# %% [markdown]
# ### pre4ap

# %%
trials = ['t-010', 't-011']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2021-01-08'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/PS05/%s/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/suite2p/alloptical-2p-1_25x-alltrials/plane0' % date
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-01-08, t-010" from: /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-010/2021-01-08_t-010.pkl
#
#
# DONE IMPORT of PS05: t-010, pre 4ap 2p all optical, moved FOV back to original location. 32 cells x 1 groups; 7mW per cell, 250ms stim (prot. #1b)
# re-collecting subset frames of current trial
# baseline frames:  [0, 31611]
# current trial frames:  [31611, 47491]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-010/2021-01-08_t-010.pkl
#
# Loading 771 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-010/2021-01-08_t-010.pkl
#
#
# searching for targeted cells...
# (384, 428)
# (440, 146)
# (566, 268)
# (566, 268)
# (506, 524)
# (294, 380)
# (402, 394)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-010/2021-01-08_t-010.pkl
#
# Number of targeted cells found suite2p:  7
#
# Target cells found in suite2p:  [13, 100, 400, 412, 458, 975, 1220]  -- 7 cells (out of 32 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-010/2021-01-08_t-010.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-010/2021-01-08_t-010_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-010/2021-01-08_t-010.pkl
#
# collecting stim traces for cell # 1 out of 32
# collecting stim traces for cell # 2 out of 32
# collecting stim traces for cell # 3 out of 32
# collecting stim traces for cell # 4 out of 32
# collecting stim traces for cell # 5 out of 32
# collecting stim traces for cell # 6 out of 32
# collecting stim traces for cell # 7 out of 32
# collecting stim traces for cell # 8 out of 32
# collecting stim traces for cell # 9 out of 32
# collecting stim traces for cell # 10 out of 32
# collecting stim traces for cell # 11 out of 32
# collecting stim traces for cell # 12 out of 32
# collecting stim traces for cell # 13 out of 32
# collecting stim traces for cell # 14 out of 32
# collecting stim traces for cell # 15 out of 32
# collecting stim traces for cell # 16 out of 32
# collecting stim traces for cell # 17 out of 32
# collecting stim traces for cell # 18 out of 32
# collecting stim traces for cell # 19 out of 32
# collecting stim traces for cell # 20 out of 32
# collecting stim traces for cell # 21 out of 32
# collecting stim traces for cell # 22 out of 32
# collecting stim traces for cell # 23 out of 32
# collecting stim traces for cell # 24 out of 32
# collecting stim traces for cell # 25 out of 32
# collecting stim traces for cell # 26 out of 32
# collecting stim traces for cell # 27 out of 32
# collecting stim traces for cell # 28 out of 32
# collecting stim traces for cell # 29 out of 32
# collecting stim traces for cell # 30 out of 32
# collecting stim traces for cell # 31 out of 32
# collecting stim traces for cell # 32 out of 32
# (32, 56)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 100.0 percent hits over 100 stims
# |- Target # 1: 100.0 percent hits over 100 stims
# |- Target # 2: 100.0 percent hits over 100 stims
# |- Target # 3: 100.0 percent hits over 100 stims
# |- Target # 4: 100.0 percent hits over 100 stims
# |- Target # 5: 100.0 percent hits over 100 stims
# |- Target # 6: 100.0 percent hits over 100 stims
# |- Target # 7: 100.0 percent hits over 100 stims
# |- Target # 8: 100.0 percent hits over 100 stims
# |- Target # 9: 100.0 percent hits over 100 stims
# |- Target # 10: 100.0 percent hits over 100 stims
# |- Target # 11: 100.0 percent hits over 100 stims
# |- Target # 12: 99.0 percent hits over 100 stims
# |- Target # 13: 100.0 percent hits over 100 stims
# |- Target # 14: 100.0 percent hits over 100 stims
# |- Target # 15: 100.0 percent hits over 100 stims
# |- Target # 16: 100.0 percent hits over 100 stims
# |- Target # 17: 100.0 percent hits over 100 stims
# |- Target # 18: 100.0 percent hits over 100 stims
# |- Target # 19: 100.0 percent hits over 100 stims
# |- Target # 20: 100.0 percent hits over 100 stims
# |- Target # 21: 100.0 percent hits over 100 stims
# |- Target # 22: 100.0 percent hits over 100 stims
# |- Target # 23: 100.0 percent hits over 100 stims
# |- Target # 24: 100.0 percent hits over 100 stims
# |- Target # 25: 100.0 percent hits over 100 stims
# |- Target # 26: 100.0 percent hits over 100 stims
# |- Target # 27: 100.0 percent hits over 100 stims
# |- Target # 28: 100.0 percent hits over 100 stims
# |- Target # 29: 100.0 percent hits over 100 stims
# |- Target # 30: 100.0 percent hits over 100 stims
# |- Target # 31: 97.0 percent hits over 100 stims
#
# avg photostim. success rate is: 99.88 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-010/2021-01-08_t-010.pkl
#
#
# importing expobj for "2021-01-08, t-011" from: /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-011/2021-01-08_t-011.pkl
#
#
# DONE IMPORT of PS05: t-011, pre 4ap 2p all optical, 32 cells x 1 groups; 5mW per cell, 100ms stim (prot. #1)
# re-collecting subset frames of current trial
# baseline frames:  [0, 31611]
# current trial frames:  [47491, 64049]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-011/2021-01-08_t-011.pkl
#
# Loading 771 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-011/2021-01-08_t-011.pkl
#
#
# searching for targeted cells...
# (384, 428)
# (440, 146)
# (566, 268)
# (566, 268)
# (506, 524)
# (294, 380)
# (402, 394)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-011/2021-01-08_t-011.pkl
#
# Number of targeted cells found suite2p:  7
#
# Target cells found in suite2p:  [13, 100, 400, 412, 458, 975, 1220]  -- 7 cells (out of 32 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-011/2021-01-08_t-011.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-011/2021-01-08_t-011_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-011/2021-01-08_t-011.pkl
#
# collecting stim traces for cell # 1 out of 32
# collecting stim traces for cell # 2 out of 32
# collecting stim traces for cell # 3 out of 32
# collecting stim traces for cell # 4 out of 32
# collecting stim traces for cell # 5 out of 32
# collecting stim traces for cell # 6 out of 32
# collecting stim traces for cell # 7 out of 32
# collecting stim traces for cell # 8 out of 32
# collecting stim traces for cell # 9 out of 32
# collecting stim traces for cell # 10 out of 32
# collecting stim traces for cell # 11 out of 32
# collecting stim traces for cell # 12 out of 32
# collecting stim traces for cell # 13 out of 32
# collecting stim traces for cell # 14 out of 32
# collecting stim traces for cell # 15 out of 32
# collecting stim traces for cell # 16 out of 32
# collecting stim traces for cell # 17 out of 32
# collecting stim traces for cell # 18 out of 32
# collecting stim traces for cell # 19 out of 32
# collecting stim traces for cell # 20 out of 32
# collecting stim traces for cell # 21 out of 32
# collecting stim traces for cell # 22 out of 32
# collecting stim traces for cell # 23 out of 32
# collecting stim traces for cell # 24 out of 32
# collecting stim traces for cell # 25 out of 32
# collecting stim traces for cell # 26 out of 32
# collecting stim traces for cell # 27 out of 32
# collecting stim traces for cell # 28 out of 32
# collecting stim traces for cell # 29 out of 32
# collecting stim traces for cell # 30 out of 32
# collecting stim traces for cell # 31 out of 32
# collecting stim traces for cell # 32 out of 32
# (32, 54)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 95.0 percent hits over 100 stims
# |- Target # 1: 94.0 percent hits over 100 stims
# |- Target # 2: 98.0 percent hits over 100 stims
# |- Target # 3: 95.0 percent hits over 100 stims
# |- Target # 4: 95.0 percent hits over 100 stims
# |- Target # 5: 80.0 percent hits over 100 stims
# |- Target # 6: 99.0 percent hits over 100 stims
# |- Target # 7: 87.0 percent hits over 100 stims
# |- Target # 8: 98.0 percent hits over 100 stims
# |- Target # 9: 86.0 percent hits over 100 stims
# |- Target # 10: 73.0 percent hits over 100 stims
# |- Target # 11: 95.0 percent hits over 100 stims
# |- Target # 12: 69.0 percent hits over 100 stims
# |- Target # 13: 81.0 percent hits over 100 stims
# |- Target # 14: 82.0 percent hits over 100 stims
# |- Target # 15: 74.0 percent hits over 100 stims
# |- Target # 16: 100.0 percent hits over 100 stims
# |- Target # 17: 93.0 percent hits over 100 stims
# |- Target # 18: 81.0 percent hits over 100 stims
# |- Target # 19: 100.0 percent hits over 100 stims
# |- Target # 20: 76.0 percent hits over 100 stims
# |- Target # 21: 100.0 percent hits over 100 stims
# |- Target # 22: 100.0 percent hits over 100 stims
# |- Target # 23: 93.0 percent hits over 100 stims
# |- Target # 24: 93.0 percent hits over 100 stims
# |- Target # 25: 83.0 percent hits over 100 stims
# |- Target # 26: 93.0 percent hits over 100 stims
# |- Target # 27: 97.0 percent hits over 100 stims
# |- Target # 28: 94.0 percent hits over 100 stims
# |- Target # 29: 93.0 percent hits over 100 stims
# |- Target # 30: 65.0 percent hits over 100 stims
# |- Target # 31: 55.0 percent hits over 100 stims
#
# avg photostim. success rate is: 88.03 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-08/2021-01-08_t-011/2021-01-08_t-011.pkl

# %% [markdown]
# ### post4ap

# %%
trials = ['t-012']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2021-01-08'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/PS05/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/%s/suite2p/alloptical-2p-1_25x-alltrials/plane0' % date
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2021-01-08, t-012" from: /home/pshah/mnt/qnap/Analysis/2021-01-08/PS05/2021-01-08_t-012/2021-01-08_t-012.pkl
#
#
# DONE IMPORT of PS05: t-012, post 4ap 2p all optical, 6 sz total, trial starts and ends both mid-sz, 1 sz after end of trial; lots of movement artifacts. 32 cells x 1 groups; 7mW per cell, 250ms stim (prot. #1b).
# re-collecting subset frames of current trial
# baseline frames:  [0, 31611]
# current trial frames:  [64049, 80607]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-08/PS05/2021-01-08_t-012/2021-01-08_t-012.pkl
#
# Loading 771 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-08/PS05/2021-01-08_t-012/2021-01-08_t-012.pkl
#
#
# searching for targeted cells...
# (384, 428)
# (440, 146)
# (566, 268)
# (566, 268)
# (506, 524)
# (294, 380)
# (402, 394)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-08/PS05/2021-01-08_t-012/2021-01-08_t-012.pkl
#
# Number of targeted cells found suite2p:  7
#
# Target cells found in suite2p:  [13, 100, 400, 412, 458, 975, 1220]  -- 7 cells (out of 32 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2021-01-08/PS05/2021-01-08_t-012/2021-01-08_t-012.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2021-01-08/PS05/2021-01-08_t-012/2021-01-08_t-012_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-08/PS05/2021-01-08_t-012/2021-01-08_t-012.pkl
#
# collecting stim traces for cell # 1 out of 32
# collecting stim traces for cell # 2 out of 32
# collecting stim traces for cell # 3 out of 32
# collecting stim traces for cell # 4 out of 32
# collecting stim traces for cell # 5 out of 32
# collecting stim traces for cell # 6 out of 32
# collecting stim traces for cell # 7 out of 32
# collecting stim traces for cell # 8 out of 32
# collecting stim traces for cell # 9 out of 32
# collecting stim traces for cell # 10 out of 32
# collecting stim traces for cell # 11 out of 32
# collecting stim traces for cell # 12 out of 32
# collecting stim traces for cell # 13 out of 32
# collecting stim traces for cell # 14 out of 32
# collecting stim traces for cell # 15 out of 32
# collecting stim traces for cell # 16 out of 32
# collecting stim traces for cell # 17 out of 32
# collecting stim traces for cell # 18 out of 32
# collecting stim traces for cell # 19 out of 32
# collecting stim traces for cell # 20 out of 32
# collecting stim traces for cell # 21 out of 32
# collecting stim traces for cell # 22 out of 32
# collecting stim traces for cell # 23 out of 32
# collecting stim traces for cell # 24 out of 32
# collecting stim traces for cell # 25 out of 32
# collecting stim traces for cell # 26 out of 32
# collecting stim traces for cell # 27 out of 32
# collecting stim traces for cell # 28 out of 32
# collecting stim traces for cell # 29 out of 32
# collecting stim traces for cell # 30 out of 32
# collecting stim traces for cell # 31 out of 32
# collecting stim traces for cell # 32 out of 32
# (32, 56)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 100.0 percent hits over 50 stims
# |- Target # 1: 100.0 percent hits over 50 stims
# |- Target # 2: 100.0 percent hits over 50 stims
# |- Target # 3: 98.0 percent hits over 50 stims
# |- Target # 4: 100.0 percent hits over 50 stims
# |- Target # 5: 100.0 percent hits over 50 stims
# |- Target # 6: 98.0 percent hits over 50 stims
# |- Target # 7: 100.0 percent hits over 50 stims
# |- Target # 8: 100.0 percent hits over 50 stims
# |- Target # 9: 98.0 percent hits over 50 stims
# |- Target # 10: 98.0 percent hits over 50 stims
# |- Target # 11: 98.0 percent hits over 50 stims
# |- Target # 12: 98.0 percent hits over 50 stims
# |- Target # 13: 98.0 percent hits over 50 stims
# /home/pshah/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py:3326: UserWarning: the seizure filtering by *cells* functionality is only available for s2p defined cell targets as of now
#   warnings.warn(
# |- Target # 14: 100.0 percent hits over 50 stims
# |- Target # 15: 98.0 percent hits over 50 stims
# |- Target # 16: 100.0 percent hits over 50 stims
# |- Target # 17: 100.0 percent hits over 50 stims
# |- Target # 18: 98.0 percent hits over 50 stims
# |- Target # 19: 100.0 percent hits over 50 stims
# |- Target # 20: 98.0 percent hits over 50 stims
# |- Target # 21: 100.0 percent hits over 50 stims
# |- Target # 22: 100.0 percent hits over 50 stims
# |- Target # 23: 100.0 percent hits over 50 stims
# |- Target # 24: 100.0 percent hits over 50 stims
# |- Target # 25: 98.0 percent hits over 50 stims
# |- Target # 26: 98.0 percent hits over 50 stims
# |- Target # 27: 98.0 percent hits over 50 stims
# |- Target # 28: 100.0 percent hits over 50 stims
# |- Target # 29: 98.0 percent hits over 50 stims
# |- Target # 30: 98.0 percent hits over 50 stims
# |- Target # 31: 92.0 percent hits over 50 stims
#
# avg photostim. success rate is: 98.81 pct.
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 94.0 percent hits over 50 stims
# |- Target # 1: 92.0 percent hits over 50 stims
# |- Target # 2: 94.0 percent hits over 50 stims
# |- Target # 3: 92.0 percent hits over 50 stims
# |- Target # 4: 94.0 percent hits over 50 stims
# |- Target # 5: 90.0 percent hits over 50 stims
# |- Target # 6: 90.0 percent hits over 50 stims
# |- Target # 7: 88.0 percent hits over 50 stims
# |- Target # 8: 84.0 percent hits over 50 stims
# |- Target # 9: 92.0 percent hits over 50 stims
# |- Target # 10: 82.0 percent hits over 50 stims
# |- Target # 11: 86.0 percent hits over 50 stims
# |- Target # 12: 86.0 percent hits over 50 stims
# |- Target # 13: 86.0 percent hits over 50 stims
# |- Target # 14: 86.0 percent hits over 50 stims
# |- Target # 15: 80.0 percent hits over 50 stims
# |- Target # 16: 92.0 percent hits over 50 stims
# |- Target # 17: 88.0 percent hits over 50 stims
# |- Target # 18: 90.0 percent hits over 50 stims
# |- Target # 19: 98.0 percent hits over 50 stims
# |- Target # 20: 90.0 percent hits over 50 stims
# |- Target # 21: 88.0 percent hits over 50 stims
# |- Target # 22: 90.0 percent hits over 50 stims
# |- Target # 23: 92.0 percent hits over 50 stims
# |- Target # 24: 92.0 percent hits over 50 stims
# |- Target # 25: 90.0 percent hits over 50 stims
# |- Target # 26: 86.0 percent hits over 50 stims
# |- Target # 27: 78.0 percent hits over 50 stims
# |- Target # 28: 86.0 percent hits over 50 stims
# |- Target # 29: 80.0 percent hits over 50 stims
# |- Target # 30: 70.0 percent hits over 50 stims
# |- Target # 31: 42.0 percent hits over 50 stims
#
# avg photostim. success rate is: 86.5 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2021-01-08/PS05/2021-01-08_t-012/2021-01-08_t-012.pkl
