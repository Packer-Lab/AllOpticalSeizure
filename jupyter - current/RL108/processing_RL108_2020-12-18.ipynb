# %% [markdown]
# # Processing - RL108 - 2020-12-18

# %%
import sys; sys.path.append('/home/pshah/Documents/code/PackerLab_pycharm/')
import os
import pickle
import alloptical_utils_pj as aoutils
import alloptical_plotting_utils as aoplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import utils.funcs_pj as pj
import tifffile as tf

# %%
to_suite2p = ['t-005', 't-006', 't-008', 't-009', 't-010', 't-011', 't-012', 't-013'] # specify all trials that were used in the suite2p runtotal_frames_stitched = 0
baseline_trials = ['t-005', 't-006', 't-008'] # specify which trials to use as spont baseline
# note ^^^ this only works currently when the spont baseline trials all come first, and also back to back

# %% [markdown]
# ### pre4ap

# %%
trials = ['t-009', 't-010']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2020-12-18'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/RL108/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/2020-12-18/suite2p/alloptical-2p-1x-alltrials/plane0'
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2020-12-18, t-009" from: /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-009/2020-12-18_t-009.pkl
#
#
# DONE IMPORT of RL108: t-009, pre 4ap 2p all optical, 11 cells x 3 groups; 5mW per cell preset: 2020-11-25_PS_250ms-stim-50hz (approach #1)
# re-collecting subset frames of current trial
# baseline frames:  [0, 48237]
# current trial frames:  [48237, 66025]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-009/2020-12-18_t-009.pkl
#
# Loading 526 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-009/2020-12-18_t-009.pkl
#
#
# searching for targeted cells...
# (350, 331)
# (336, 322)
# (177, 324)
# (130, 285)
# (329, 94)
# (262, 292)
# (312, 286)
# (130, 358)
# (272, 351)
# (319, 202)
# (355, 178)
# (165, 139)
# (354, 316)
# (306, 85)
# (166, 87)
# (338, 384)
# (271, 267)
# (299, 273)
# (134, 259)
# (165, 191)
# (312, 47)
# (100, 117)
# (432, 240)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-009/2020-12-18_t-009.pkl
#
# Number of targeted cells found suite2p:  23
#
# Target cells found in suite2p:  [1, 2, 5, 7, 17, 27, 31, 47, 51, 54, 60, 137, 140, 143, 170, 176, 187, 274, 328, 461, 641, 1948, 2272]  -- 23 cells (out of 34 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-009/2020-12-18_t-009.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-009/2020-12-18_t-009_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-009/2020-12-18_t-009.pkl
#
# collecting stim traces for cell # 1 out of 34
# collecting stim traces for cell # 2 out of 34
# collecting stim traces for cell # 3 out of 34
# collecting stim traces for cell # 4 out of 34
# collecting stim traces for cell # 5 out of 34
# collecting stim traces for cell # 6 out of 34
# collecting stim traces for cell # 7 out of 34
# collecting stim traces for cell # 8 out of 34
# collecting stim traces for cell # 9 out of 34
# collecting stim traces for cell # 10 out of 34
# collecting stim traces for cell # 11 out of 34
# collecting stim traces for cell # 12 out of 34
# collecting stim traces for cell # 13 out of 34
# collecting stim traces for cell # 14 out of 34
# collecting stim traces for cell # 15 out of 34
# collecting stim traces for cell # 16 out of 34
# collecting stim traces for cell # 17 out of 34
# collecting stim traces for cell # 18 out of 34
# collecting stim traces for cell # 19 out of 34
# collecting stim traces for cell # 20 out of 34
# collecting stim traces for cell # 21 out of 34
# collecting stim traces for cell # 22 out of 34
# collecting stim traces for cell # 23 out of 34
# collecting stim traces for cell # 24 out of 34
# collecting stim traces for cell # 25 out of 34
# collecting stim traces for cell # 26 out of 34
# collecting stim traces for cell # 27 out of 34
# collecting stim traces for cell # 28 out of 34
# collecting stim traces for cell # 29 out of 34
# collecting stim traces for cell # 30 out of 34
# collecting stim traces for cell # 31 out of 34
# collecting stim traces for cell # 32 out of 34
# collecting stim traces for cell # 33 out of 34
# collecting stim traces for cell # 34 out of 34
# (34, 128)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 67.0 percent hits over 100 stims
# |- Target # 1: 69.0 percent hits over 100 stims
# |- Target # 2: 88.0 percent hits over 100 stims
# |- Target # 3: 30.0 percent hits over 100 stims
# |- Target # 4: 82.0 percent hits over 100 stims
# |- Target # 5: 55.0 percent hits over 100 stims
# |- Target # 6: 70.0 percent hits over 100 stims
# |- Target # 7: 39.0 percent hits over 100 stims
# |- Target # 8: 62.0 percent hits over 100 stims
# |- Target # 9: 29.0 percent hits over 100 stims
# |- Target # 10: 61.0 percent hits over 100 stims
# |- Target # 11: 75.0 percent hits over 100 stims
# |- Target # 12: 60.0 percent hits over 100 stims
# |- Target # 13: 45.0 percent hits over 100 stims
# |- Target # 14: 53.0 percent hits over 100 stims
# |- Target # 15: 54.0 percent hits over 100 stims
# |- Target # 16: 84.0 percent hits over 100 stims
# |- Target # 17: 86.0 percent hits over 100 stims
# |- Target # 18: 58.0 percent hits over 100 stims
# |- Target # 19: 78.0 percent hits over 100 stims
# |- Target # 20: 99.0 percent hits over 100 stims
# |- Target # 21: 66.0 percent hits over 100 stims
# |- Target # 22: 61.0 percent hits over 100 stims
# |- Target # 23: 100.0 percent hits over 100 stims
# |- Target # 24: 74.0 percent hits over 100 stims
# |- Target # 25: 65.0 percent hits over 100 stims
# |- Target # 26: 96.0 percent hits over 100 stims
# |- Target # 27: 99.0 percent hits over 100 stims
# |- Target # 28: 98.0 percent hits over 100 stims
# |- Target # 29: 73.0 percent hits over 100 stims
# |- Target # 30: 100.0 percent hits over 100 stims
# |- Target # 31: 74.0 percent hits over 100 stims
# |- Target # 32: 72.0 percent hits over 100 stims
# |- Target # 33: 75.0 percent hits over 100 stims
#
# avg photostim. success rate is: 70.5 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-009/2020-12-18_t-009.pkl
#
#
# importing expobj for "2020-12-18, t-010" from: /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-010/2020-12-18_t-010.pkl
#
#
# DONE IMPORT of RL108: t-010, pre 4ap 2p all optical, 11 cells x 3 groups; 5mW per cell preset: 2020-12-17_PS_10shots-interleaved (approach #2)
# re-collecting subset frames of current trial
# baseline frames:  [0, 48237]
# current trial frames:  [66025, 83813]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-010/2020-12-18_t-010.pkl
#
# Loading 526 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-010/2020-12-18_t-010.pkl
#
#
# searching for targeted cells...
# (350, 331)
# (336, 322)
# (177, 324)
# (130, 285)
# (329, 94)
# (262, 292)
# (312, 286)
# (130, 358)
# (272, 351)
# (319, 202)
# (355, 178)
# (165, 139)
# (354, 316)
# (306, 85)
# (166, 87)
# (338, 384)
# (271, 267)
# (299, 273)
# (134, 259)
# (165, 191)
# (312, 47)
# (100, 117)
# (432, 240)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-010/2020-12-18_t-010.pkl
#
# Number of targeted cells found suite2p:  23
#
# Target cells found in suite2p:  [1, 2, 5, 7, 17, 27, 31, 47, 51, 54, 60, 137, 140, 143, 170, 176, 187, 274, 328, 461, 641, 1948, 2272]  -- 23 cells (out of 34 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-010/2020-12-18_t-010.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-010/2020-12-18_t-010_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-010/2020-12-18_t-010.pkl
#
# collecting stim traces for cell # 1 out of 34
# collecting stim traces for cell # 2 out of 34
# collecting stim traces for cell # 3 out of 34
# collecting stim traces for cell # 4 out of 34
# collecting stim traces for cell # 5 out of 34
# collecting stim traces for cell # 6 out of 34
# collecting stim traces for cell # 7 out of 34
# collecting stim traces for cell # 8 out of 34
# collecting stim traces for cell # 9 out of 34
# collecting stim traces for cell # 10 out of 34
# collecting stim traces for cell # 11 out of 34
# collecting stim traces for cell # 12 out of 34
# collecting stim traces for cell # 13 out of 34
# collecting stim traces for cell # 14 out of 34
# collecting stim traces for cell # 15 out of 34
# collecting stim traces for cell # 16 out of 34
# collecting stim traces for cell # 17 out of 34
# collecting stim traces for cell # 18 out of 34
# collecting stim traces for cell # 19 out of 34
# collecting stim traces for cell # 20 out of 34
# collecting stim traces for cell # 21 out of 34
# collecting stim traces for cell # 22 out of 34
# collecting stim traces for cell # 23 out of 34
# collecting stim traces for cell # 24 out of 34
# collecting stim traces for cell # 25 out of 34
# collecting stim traces for cell # 26 out of 34
# collecting stim traces for cell # 27 out of 34
# collecting stim traces for cell # 28 out of 34
# collecting stim traces for cell # 29 out of 34
# collecting stim traces for cell # 30 out of 34
# collecting stim traces for cell # 31 out of 34
# collecting stim traces for cell # 32 out of 34
# collecting stim traces for cell # 33 out of 34
# collecting stim traces for cell # 34 out of 34
# (34, 128)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 28.0 percent hits over 100 stims
# |- Target # 1: 44.0 percent hits over 100 stims
# |- Target # 2: 39.0 percent hits over 100 stims
# |- Target # 3: 26.0 percent hits over 100 stims
# |- Target # 4: 35.0 percent hits over 100 stims
# |- Target # 5: 33.0 percent hits over 100 stims
# |- Target # 6: 42.0 percent hits over 100 stims
# |- Target # 7: 19.0 percent hits over 100 stims
# |- Target # 8: 33.0 percent hits over 100 stims
# |- Target # 9: 22.0 percent hits over 100 stims
# |- Target # 10: 44.0 percent hits over 100 stims
# |- Target # 11: 42.0 percent hits over 100 stims
# |- Target # 12: 31.0 percent hits over 100 stims
# |- Target # 13: 33.0 percent hits over 100 stims
# |- Target # 14: 33.0 percent hits over 100 stims
# |- Target # 15: 32.0 percent hits over 100 stims
# |- Target # 16: 34.0 percent hits over 100 stims
# |- Target # 17: 50.0 percent hits over 100 stims
# |- Target # 18: 26.0 percent hits over 100 stims
# |- Target # 19: 35.0 percent hits over 100 stims
# |- Target # 20: 44.0 percent hits over 100 stims
# |- Target # 21: 71.0 percent hits over 100 stims
# |- Target # 22: 49.0 percent hits over 100 stims
# |- Target # 23: 45.0 percent hits over 100 stims
# |- Target # 24: 50.0 percent hits over 100 stims
# |- Target # 25: 43.0 percent hits over 100 stims
# |- Target # 26: 35.0 percent hits over 100 stims
# |- Target # 27: 54.0 percent hits over 100 stims
# |- Target # 28: 43.0 percent hits over 100 stims
# |- Target # 29: 44.0 percent hits over 100 stims
# |- Target # 30: 57.0 percent hits over 100 stims
# |- Target # 31: 52.0 percent hits over 100 stims
# |- Target # 32: 56.0 percent hits over 100 stims
# |- Target # 33: 26.0 percent hits over 100 stims
#
# avg photostim. success rate is: 39.71 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-010/2020-12-18_t-010.pkl

# %% [markdown]
# ## post4ap

# %%
trials = ['t-011', 't-012', 't-013']

for trial in trials:
    ###### IMPORT pkl file containing expobj
    date = '2020-12-18'
    pkl_path = "/home/pshah/mnt/qnap/Analysis/%s/RL108/%s_%s/%s_%s.pkl" % (date, date, trial, date, trial)
    
    expobj, experiment = aoutils.import_expobj(trial=trial, date=date, pkl_path=pkl_path)
    expobj.s2p_path = '/home/pshah/mnt/qnap/Analysis/2020-12-18/suite2p/alloptical-2p-1x-alltrials/plane0'
    aoutils.run_alloptical_processing_photostim(expobj, to_suite2p=to_suite2p, baseline_trials=baseline_trials, force_redo=True)
# Out:
# importing expobj for "2020-12-18, t-011" from: /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-011/2020-12-18_t-011.pkl
#
#
# DONE IMPORT of RL108: t-011, post 4ap 2p all optical, should be 5 seizures based on the paq LFP file; 11 cells x 3 groups; 5mW per cell preset: 2020-12-17_PS_10shots-interleaved (approach #2)
# re-collecting subset frames of current trial
# baseline frames:  [0, 48237]
# current trial frames:  [83813, 101601]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-011/2020-12-18_t-011.pkl
#
# Loading 526 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-011/2020-12-18_t-011.pkl
#
#
# searching for targeted cells...
# (350, 331)
# (336, 322)
# (177, 324)
# (130, 285)
# (329, 94)
# (262, 292)
# (312, 286)
# (130, 358)
# (272, 351)
# (319, 202)
# (355, 178)
# (165, 139)
# (354, 316)
# (306, 85)
# (166, 87)
# (338, 384)
# (271, 267)
# (299, 273)
# (134, 259)
# (165, 191)
# (312, 47)
# (100, 117)
# (432, 240)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-011/2020-12-18_t-011.pkl
#
# Number of targeted cells found suite2p:  23
#
# Target cells found in suite2p:  [1, 2, 5, 7, 17, 27, 31, 47, 51, 54, 60, 137, 140, 143, 170, 176, 187, 274, 328, 461, 641, 1948, 2272]  -- 23 cells (out of 34 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-011/2020-12-18_t-011.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-011/2020-12-18_t-011_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-011/2020-12-18_t-011.pkl
#
# collecting stim traces for cell # 1 out of 34
# collecting stim traces for cell # 2 out of 34
# collecting stim traces for cell # 3 out of 34
# collecting stim traces for cell # 4 out of 34
# collecting stim traces for cell # 5 out of 34
# collecting stim traces for cell # 6 out of 34
# collecting stim traces for cell # 7 out of 34
# collecting stim traces for cell # 8 out of 34
# collecting stim traces for cell # 9 out of 34
# collecting stim traces for cell # 10 out of 34
# collecting stim traces for cell # 11 out of 34
# collecting stim traces for cell # 12 out of 34
# collecting stim traces for cell # 13 out of 34
# collecting stim traces for cell # 14 out of 34
# collecting stim traces for cell # 15 out of 34
# collecting stim traces for cell # 16 out of 34
# collecting stim traces for cell # 17 out of 34
# collecting stim traces for cell # 18 out of 34
# collecting stim traces for cell # 19 out of 34
# collecting stim traces for cell # 20 out of 34
# collecting stim traces for cell # 21 out of 34
# collecting stim traces for cell # 22 out of 34
# collecting stim traces for cell # 23 out of 34
# collecting stim traces for cell # 24 out of 34
# collecting stim traces for cell # 25 out of 34
# collecting stim traces for cell # 26 out of 34
# collecting stim traces for cell # 27 out of 34
# collecting stim traces for cell # 28 out of 34
# collecting stim traces for cell # 29 out of 34
# collecting stim traces for cell # 30 out of 34
# collecting stim traces for cell # 31 out of 34
# collecting stim traces for cell # 32 out of 34
# collecting stim traces for cell # 33 out of 34
# collecting stim traces for cell # 34 out of 34
# (34, 125)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 32.56 percent hits over 86 stims
# |- Target # 1: 50.0 percent hits over 86 stims
# |- Target # 2: 58.14 percent hits over 86 stims
# |- Target # 3: 25.58 percent hits over 86 stims
# |- Target # 4: 55.81 percent hits over 86 stims
# |- Target # 5: 37.21 percent hits over 86 stims
# |- Target # 6: 56.98 percent hits over 86 stims
# |- Target # 7: 30.23 percent hits over 86 stims
# |- Target # 8: 33.72 percent hits over 86 stims
# |- Target # 9: 32.56 percent hits over 86 stims
# |- Target # 10: 47.67 percent hits over 86 stims
# |- Target # 11: 40.7 percent hits over 86 stims
# |- Target # 12: 45.35 percent hits over 86 stims
# |- Target # 13: 30.23 percent hits over 86 stims
# |- Target # 14: 40.7 percent hits over 86 stims
# |- Target # 15: 32.56 percent hits over 86 stims
# |- Target # 16: 41.86 percent hits over 86 stims
# |- Target # 17: 51.16 percent hits over 86 stims
# |- Target # 18: 50.0 percent hits over 86 stims
# |- Target # 19: 50.0 percent hits over 86 stims
# |- Target # 20: 44.19 percent hits over 86 stims
# |- Target # 21: 62.79 percent hits over 86 stims
# |- Target # 22: 44.19 percent hits over 86 stims
# |- Target # 23: 63.95 percent hits over 86 stims
# |- Target # 24: 56.98 percent hits over 86 stims
# |- Target # 25: 47.67 percent hits over 86 stims
# |- Target # 26: 47.67 percent hits over 86 stims
# |- Target # 27: 60.47 percent hits over 86 stims
# |- Target # 28: 60.47 percent hits over 86 stims
# |- Target # 29: 44.19 percent hits over 86 stims
# |- Target # 30: 48.84 percent hits over 86 stims
# |- Target # 31: 45.35 percent hits over 86 stims
# |- Target # 32: 48.84 percent hits over 86 stims
# |- Target # 33: 38.37 percent hits over 86 stims
#
# avg photostim. success rate is: 45.79 pct.
# /home/pshah/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py:3316: UserWarning: the seizure filtering by *cells* functionality is only available for s2p defined cell targets as of now
#   warnings.warn(
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 28.57 percent hits over 14 stims
# |- Target # 1: 35.71 percent hits over 14 stims
# |- Target # 2: 21.43 percent hits over 14 stims
# |- Target # 3: 21.43 percent hits over 14 stims
# |- Target # 4: 42.86 percent hits over 14 stims
# |- Target # 5: 35.71 percent hits over 14 stims
# |- Target # 6: 50.0 percent hits over 14 stims
# |- Target # 7: 35.71 percent hits over 14 stims
# |- Target # 8: 14.29 percent hits over 14 stims
# |- Target # 9: 21.43 percent hits over 14 stims
# |- Target # 10: 50.0 percent hits over 14 stims
# |- Target # 11: 50.0 percent hits over 14 stims
# |- Target # 12: 42.86 percent hits over 14 stims
# |- Target # 13: 42.86 percent hits over 14 stims
# |- Target # 14: 42.86 percent hits over 14 stims
# |- Target # 15: 50.0 percent hits over 14 stims
# |- Target # 16: 28.57 percent hits over 14 stims
# |- Target # 17: 21.43 percent hits over 14 stims
# |- Target # 18: 42.86 percent hits over 14 stims
# |- Target # 19: 28.57 percent hits over 14 stims
# |- Target # 20: 50.0 percent hits over 14 stims
# |- Target # 21: 28.57 percent hits over 14 stims
# |- Target # 22: 28.57 percent hits over 14 stims
# |- Target # 23: 50.0 percent hits over 14 stims
# |- Target # 24: 35.71 percent hits over 14 stims
# |- Target # 25: 42.86 percent hits over 14 stims
# |- Target # 26: 28.57 percent hits over 14 stims
# |- Target # 27: 42.86 percent hits over 14 stims
# |- Target # 28: 14.29 percent hits over 14 stims
# |- Target # 29: 42.86 percent hits over 14 stims
# |- Target # 30: 28.57 percent hits over 14 stims
# |- Target # 31: 42.86 percent hits over 14 stims
# |- Target # 32: 50.0 percent hits over 14 stims
# |- Target # 33: 28.57 percent hits over 14 stims
#
# avg photostim. success rate is: 35.92 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-011/2020-12-18_t-011.pkl
#
#
# importing expobj for "2020-12-18, t-012" from: /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-012/2020-12-18_t-012.pkl
#
#
# DONE IMPORT of RL108: t-012, post 4ap 2p all optical, no sz events; 11 cells x 3 groups; 5mW per cell preset: 2020-11-25_PS_250ms-stim-50hz (approach #1)
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-012/2020-12-18_t-012.pkl
#
# re-collecting subset frames of current trial
# baseline frames:  [0, 48237]
# current trial frames:  [101601, 117385]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-012/2020-12-18_t-012.pkl
#
# Loading 526 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-012/2020-12-18_t-012.pkl
#
#
# searching for targeted cells...
# (350, 331)
# (336, 322)
# (177, 324)
# (130, 285)
# (329, 94)
# (262, 292)
# (312, 286)
# (130, 358)
# (272, 351)
# (319, 202)
# (355, 178)
# (165, 139)
# (354, 316)
# (306, 85)
# (166, 87)
# (338, 384)
# (271, 267)
# (299, 273)
# (134, 259)
# (165, 191)
# (312, 47)
# (100, 117)
# (432, 240)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-012/2020-12-18_t-012.pkl
#
# Number of targeted cells found suite2p:  23
#
# Target cells found in suite2p:  [1, 2, 5, 7, 17, 27, 31, 47, 51, 54, 60, 137, 140, 143, 170, 176, 187, 274, 328, 461, 641, 1948, 2272]  -- 23 cells (out of 34 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-012/2020-12-18_t-012.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-012/2020-12-18_t-012_s2p_masks.tif
#
#
# collecting raw Flu traces from SLM target coord. areas from registered TIFFs
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-18/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file050_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-18/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file051_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-18/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file052_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-18/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file053_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-18/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file054_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-18/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file055_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-18/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file056_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-18/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file057_chan0.tif
# |- reading tiff: /home/pshah/mnt/qnap/Analysis/2020-12-18/suite2p/alloptical-2p-1x-alltrials/plane0/reg_tif/file058_chan0.tif
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-012/2020-12-18_t-012.pkl
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-012/2020-12-18_t-012.pkl
#
# collecting stim traces for cell # 1 out of 34
# collecting stim traces for cell # 2 out of 34
# collecting stim traces for cell # 3 out of 34
# collecting stim traces for cell # 4 out of 34
# collecting stim traces for cell # 5 out of 34
# collecting stim traces for cell # 6 out of 34
# collecting stim traces for cell # 7 out of 34
# collecting stim traces for cell # 8 out of 34
# collecting stim traces for cell # 9 out of 34
# collecting stim traces for cell # 10 out of 34
# collecting stim traces for cell # 11 out of 34
# collecting stim traces for cell # 12 out of 34
# collecting stim traces for cell # 13 out of 34
# collecting stim traces for cell # 14 out of 34
# collecting stim traces for cell # 15 out of 34
# collecting stim traces for cell # 16 out of 34
# collecting stim traces for cell # 17 out of 34
# collecting stim traces for cell # 18 out of 34
# collecting stim traces for cell # 19 out of 34
# collecting stim traces for cell # 20 out of 34
# collecting stim traces for cell # 21 out of 34
# collecting stim traces for cell # 22 out of 34
# collecting stim traces for cell # 23 out of 34
# collecting stim traces for cell # 24 out of 34
# collecting stim traces for cell # 25 out of 34
# collecting stim traces for cell # 26 out of 34
# collecting stim traces for cell # 27 out of 34
# collecting stim traces for cell # 28 out of 34
# collecting stim traces for cell # 29 out of 34
# collecting stim traces for cell # 30 out of 34
# collecting stim traces for cell # 31 out of 34
# collecting stim traces for cell # 32 out of 34
# collecting stim traces for cell # 33 out of 34
# collecting stim traces for cell # 34 out of 34
# (34, 128)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 55.0 percent hits over 100 stims
# |- Target # 1: 57.0 percent hits over 100 stims
# |- Target # 2: 96.0 percent hits over 100 stims
# |- Target # 3: 29.0 percent hits over 100 stims
# |- Target # 4: 88.0 percent hits over 100 stims
# |- Target # 5: 67.0 percent hits over 100 stims
# |- Target # 6: 75.0 percent hits over 100 stims
# |- Target # 7: 37.0 percent hits over 100 stims
# |- Target # 8: 50.0 percent hits over 100 stims
# |- Target # 9: 42.0 percent hits over 100 stims
# |- Target # 10: 79.0 percent hits over 100 stims
# |- Target # 11: 79.0 percent hits over 100 stims
# |- Target # 12: 62.0 percent hits over 100 stims
# |- Target # 13: 48.0 percent hits over 100 stims
# |- Target # 14: 42.0 percent hits over 100 stims
# |- Target # 15: 76.0 percent hits over 100 stims
# |- Target # 16: 81.0 percent hits over 100 stims
# |- Target # 17: 79.0 percent hits over 100 stims
# |- Target # 18: 48.0 percent hits over 100 stims
# |- Target # 19: 80.0 percent hits over 100 stims
# |- Target # 20: 97.0 percent hits over 100 stims
# |- Target # 21: 81.0 percent hits over 100 stims
# |- Target # 22: 39.0 percent hits over 100 stims
# |- Target # 23: 95.0 percent hits over 100 stims
# |- Target # 24: 68.0 percent hits over 100 stims
# |- Target # 25: 62.0 percent hits over 100 stims
# |- Target # 26: 98.0 percent hits over 100 stims
# |- Target # 27: 100.0 percent hits over 100 stims
# |- Target # 28: 99.0 percent hits over 100 stims
# |- Target # 29: 66.0 percent hits over 100 stims
# |- Target # 30: 100.0 percent hits over 100 stims
# |- Target # 31: 82.0 percent hits over 100 stims
# |- Target # 32: 73.0 percent hits over 100 stims
# |- Target # 33: 64.0 percent hits over 100 stims
#
# avg photostim. success rate is: 70.41 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-012/2020-12-18_t-012.pkl
#
#
# importing expobj for "2020-12-18, t-013" from: /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-013/2020-12-18_t-013.pkl
#
#
# DONE IMPORT of RL108: t-013, post 4ap 2p all optical, 5 seizures total, trial starts mid first seizure; 11 cells x 3 groups; 5mW per cell preset: 2020-11-25_PS_250ms-stim-50hz (approach #1)
# re-collecting subset frames of current trial
# baseline frames:  [0, 48237]
# current trial frames:  [117385, 133669]
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-013/2020-12-18_t-013.pkl
#
# Loading 526 traces labelled as cells
# Subtracting neuropil with a coefficient of 0.7
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-013/2020-12-18_t-013.pkl
#
#
# searching for targeted cells...
# (350, 331)
# (336, 322)
# (177, 324)
# (130, 285)
# (329, 94)
# (262, 292)
# (312, 286)
# (130, 358)
# (272, 351)
# (319, 202)
# (355, 178)
# (165, 139)
# (354, 316)
# (306, 85)
# (166, 87)
# (338, 384)
# (271, 267)
# (299, 273)
# (134, 259)
# (165, 191)
# (312, 47)
# (100, 117)
# (432, 240)
# ------- Search completed.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-013/2020-12-18_t-013.pkl
#
# Number of targeted cells found suite2p:  23
#
# Target cells found in suite2p:  [1, 2, 5, 7, 17, 27, 31, 47, 51, 54, 60, 137, 140, 143, 170, 176, 187, 274, 328, 461, 641, 1948, 2272]  -- 23 cells (out of 34 target coords)
# Retrieving s2p masks for: /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-013/2020-12-18_t-013.pkl
# s2p ROI + photostim targets masks saved in TIFF to:  /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-013/2020-12-18_t-013_s2p_masks.tif
# skipped re-collecting of raw traces from SLM targets
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-013/2020-12-18_t-013.pkl
#
# collecting stim traces for cell # 1 out of 34
# collecting stim traces for cell # 2 out of 34
# collecting stim traces for cell # 3 out of 34
# collecting stim traces for cell # 4 out of 34
# collecting stim traces for cell # 5 out of 34
# collecting stim traces for cell # 6 out of 34
# collecting stim traces for cell # 7 out of 34
# collecting stim traces for cell # 8 out of 34
# collecting stim traces for cell # 9 out of 34
# collecting stim traces for cell # 10 out of 34
# collecting stim traces for cell # 11 out of 34
# collecting stim traces for cell # 12 out of 34
# collecting stim traces for cell # 13 out of 34
# collecting stim traces for cell # 14 out of 34
# collecting stim traces for cell # 15 out of 34
# collecting stim traces for cell # 16 out of 34
# collecting stim traces for cell # 17 out of 34
# collecting stim traces for cell # 18 out of 34
# collecting stim traces for cell # 19 out of 34
# collecting stim traces for cell # 20 out of 34
# collecting stim traces for cell # 21 out of 34
# collecting stim traces for cell # 22 out of 34
# collecting stim traces for cell # 23 out of 34
# collecting stim traces for cell # 24 out of 34
# collecting stim traces for cell # 25 out of 34
# collecting stim traces for cell # 26 out of 34
# collecting stim traces for cell # 27 out of 34
# collecting stim traces for cell # 28 out of 34
# collecting stim traces for cell # 29 out of 34
# collecting stim traces for cell # 30 out of 34
# collecting stim traces for cell # 31 out of 34
# collecting stim traces for cell # 32 out of 34
# collecting stim traces for cell # 33 out of 34
# collecting stim traces for cell # 34 out of 34
# (34, 128)
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 47.69 percent hits over 65 stims
# |- Target # 1: 46.15 percent hits over 65 stims
# |- Target # 2: 66.15 percent hits over 65 stims
# |- Target # 3: 38.46 percent hits over 65 stims
# |- Target # 4: 75.38 percent hits over 65 stims
# |- Target # 5: 27.69 percent hits over 65 stims
# /home/pshah/Documents/code/PackerLab_pycharm/alloptical_utils_pj.py:3316: UserWarning: the seizure filtering by *cells* functionality is only available for s2p defined cell targets as of now
#   warnings.warn(
# |- Target # 6: 60.0 percent hits over 65 stims
# |- Target # 7: 44.62 percent hits over 65 stims
# |- Target # 8: 44.62 percent hits over 65 stims
# |- Target # 9: 26.15 percent hits over 65 stims
# |- Target # 10: 70.77 percent hits over 65 stims
# |- Target # 11: 80.0 percent hits over 65 stims
# |- Target # 12: 52.31 percent hits over 65 stims
# |- Target # 13: 55.38 percent hits over 65 stims
# |- Target # 14: 40.0 percent hits over 65 stims
# |- Target # 15: 41.54 percent hits over 65 stims
# |- Target # 16: 81.54 percent hits over 65 stims
# |- Target # 17: 76.92 percent hits over 65 stims
# |- Target # 18: 40.0 percent hits over 65 stims
# |- Target # 19: 64.62 percent hits over 65 stims
# |- Target # 20: 87.69 percent hits over 65 stims
# |- Target # 21: 73.85 percent hits over 65 stims
# |- Target # 22: 63.08 percent hits over 65 stims
# |- Target # 23: 92.31 percent hits over 65 stims
# |- Target # 24: 81.54 percent hits over 65 stims
# |- Target # 25: 58.46 percent hits over 65 stims
# |- Target # 26: 87.69 percent hits over 65 stims
# |- Target # 27: 96.92 percent hits over 65 stims
# |- Target # 28: 86.15 percent hits over 65 stims
# |- Target # 29: 76.92 percent hits over 65 stims
# |- Target # 30: 92.31 percent hits over 65 stims
# |- Target # 31: 78.46 percent hits over 65 stims
# |- Target # 32: 75.38 percent hits over 65 stims
# |- Target # 33: 63.08 percent hits over 65 stims
#
# avg photostim. success rate is: 64.52 pct.
# Calculating success rate of stims. of all stims across the trial
# |- Target # 0: 44.12 percent hits over 34 stims
# |- Target # 1: 52.94 percent hits over 34 stims
# |- Target # 2: 50.0 percent hits over 34 stims
# |- Target # 3: 47.06 percent hits over 34 stims
# |- Target # 4: 58.82 percent hits over 34 stims
# |- Target # 5: 44.12 percent hits over 34 stims
# |- Target # 6: 47.06 percent hits over 34 stims
# |- Target # 7: 58.82 percent hits over 34 stims
# |- Target # 8: 47.06 percent hits over 34 stims
# |- Target # 9: 50.0 percent hits over 34 stims
# |- Target # 10: 52.94 percent hits over 34 stims
# |- Target # 11: 58.82 percent hits over 34 stims
# |- Target # 12: 55.88 percent hits over 34 stims
# |- Target # 13: 41.18 percent hits over 34 stims
# |- Target # 14: 61.76 percent hits over 34 stims
# |- Target # 15: 64.71 percent hits over 34 stims
# |- Target # 16: 50.0 percent hits over 34 stims
# |- Target # 17: 47.06 percent hits over 34 stims
# |- Target # 18: 52.94 percent hits over 34 stims
# |- Target # 19: 44.12 percent hits over 34 stims
# |- Target # 20: 52.94 percent hits over 34 stims
# |- Target # 21: 50.0 percent hits over 34 stims
# |- Target # 22: 58.82 percent hits over 34 stims
# |- Target # 23: 55.88 percent hits over 34 stims
# |- Target # 24: 52.94 percent hits over 34 stims
# |- Target # 25: 52.94 percent hits over 34 stims
# |- Target # 26: 52.94 percent hits over 34 stims
# |- Target # 27: 58.82 percent hits over 34 stims
# |- Target # 28: 61.76 percent hits over 34 stims
# |- Target # 29: 38.24 percent hits over 34 stims
# |- Target # 30: 61.76 percent hits over 34 stims
# |- Target # 31: 44.12 percent hits over 34 stims
# |- Target # 32: 50.0 percent hits over 34 stims
# |- Target # 33: 44.12 percent hits over 34 stims
#
# avg photostim. success rate is: 51.9 pct.
#
#
# pkl saved to /home/pshah/mnt/qnap/Analysis/2020-12-18/RL108/2020-12-18_t-013/2020-12-18_t-013.pkl
